# %%
import numpy as np
import pandas as pd
import json
import os
import string
import re
from nltk.corpus import stopwords
from data_cleaning import load_data 
from evaluate import load_type_hierarchy, get_type_path
from collections import Counter
from elasticsearch import Elasticsearch, helpers

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bruna\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
INDEX_NAME = 'dbpedia_2'

# %%
es = Elasticsearch()
es.info()
train = load_data('datasets/DBpedia/smarttask_dbpedia_train.json')
#test = load_data('datasets/DBpedia/smarttask_dbpedia_test.json')
test = load_data('results/test_queries_svm_output.json')
# Out:
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)

# %%
stop_words = stopwords.words('english')

question_tags = ['who', 'what', 'when', 'where', 'which', 'whom', 'whose', 'why']
stop_words = [word for word in stop_words if word not in question_tags]

# %%
def preprocess_txt(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text).lower()
    text = re.sub(' +', ' ', text)
    word_list = [word for word in text.split() if word not in stop_words]
    text = " ".join(word_list)
    return text


def load_queries(docs):
    """
    Load queries from json file
    """

    resource_queries = {}
    count = 0
    for x in docs:
        if x['category'] != 'resource':
            count += 1
            continue
        
        if x['question'] is not None:
            q = preprocess_txt(x['question'])
        
            doc = {
                'question': q,
                'category': x['category'],
                'type': x['type']
            } 
            resource_queries.update({x['id']:doc})
        
    return resource_queries

# %%
training_queries = load_queries(train)
test_queries = load_queries(test)

# %%
def baseline_retrieval(query, field = 'abstract', index = INDEX_NAME):
    """
    Baseline retrieval using the inbuilt BM25 index from elastic search

    Arguments:
        index: string
        query: string, space separated terms
        k: integer
    
    Returns:
        List of k first entity IDs(string)
    """
    hits = es.search(index=index, size=200,
                query = {"bool": {"must": {"match": {"abstract": query}}, "must_not": {"match": {"instance": "owl:Thing"}}}})['hits']['hits']
    hit_ids = [obj['_id'] for obj in hits]
    hit_types = [es.get(index=index, id=doc)["_source"].get("instance") for doc in hit_ids]
    result = [h[0] for h in Counter(hit_types).most_common(10)]
    
    return result

# %%
def es_BM25(es, data):
    results = {} 
    for query_id, query in data.items():
        if len(query['question'])>0:
            response = baseline_retrieval(query['question'],  
                                        field = 'abstract', index = INDEX_NAME)
            results.update({query_id:{
                                "id": query_id,
                                "category": query["category"],
                                "type": response
                                }
                            })
        else:
            continue
    return results

# %%
test_res = es_BM25(es, test_queries)
# Out:
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)

# %%
test_res
# Out:
# {'dbpedia_7955': {'id': 'dbpedia_7955',
#   'category': 'resource',
#   'type': ['dbo:Language',
#    'dbo:Scientist',
#    'dbo:Country',
#    'dbo:ProgrammingLanguage',
#    'dbo:Settlement',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:MilitaryConflict',
#    'dbo:Island',
#    'dbo:City']},
#  'dbpedia_22599': {'id': 'dbpedia_22599',
#   'category': 'resource',
#   'type': ['dbo:MilitaryConflict',
#    'dbo:MilitaryUnit',
#    'dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:ArtificialSatellite',
#    'dbo:City',
#    'dbo:AdministrativeRegion',
#    'dbo:OfficeHolder']},
#  'dbpedia_19677': {'id': 'dbpedia_19677',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:Country',
#    'dbo:City',
#    'dbo:AmericanFootballTeam',
#    'dbo:PoliticalParty',
#    'dbo:MilitaryUnit',
#    'dbo:BaseballTeam',
#    'dbo:AdministrativeRegion',
#    'dbo:Person',
#    'dbo:Scientist']},
#  'dbpedia_11163': {'id': 'dbpedia_11163',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Settlement',
#    'dbo:PoliticalParty',
#    'dbo:Country',
#    'dbo:Aircraft',
#    'dbo:Person',
#    'dbo:Language',
#    'dbo:AdministrativeRegion',
#    'dbo:Venue',
#    'dbo:ArtificialSatellite']},
#  'dbpedia_18792': {'id': 'dbpedia_18792',
#   'category': 'resource',
#   'type': ['dbo:EthnicGroup',
#    'dbo:Language',
#    'dbo:City',
#    'dbo:Country',
#    'dbo:Person',
#    'dbo:MilitaryUnit',
#    'dbo:Disease',
#    'dbo:OfficeHolder',
#    'dbo:Royalty',
#    'dbo:Building']},
#  'dbpedia_11251': {'id': 'dbpedia_11251',
#   'category': 'resource',
#   'type': ['dbo:BaseballTeam',
#    'dbo:AmericanFootballTeam',
#    'dbo:MilitaryConflict',
#    'dbo:SoccerClub',
#    'dbo:MilitaryUnit',
#    'dbo:Country',
#    'dbo:BaseballPlayer',
#    'dbo:OfficeHolder',
#    'dbo:Company',
#    'dbo:City']},
#  'dbpedia_17993': {'id': 'dbpedia_17993',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Writer',
#    'dbo:Film',
#    'dbo:Game',
#    'dbo:TelevisionShow',
#    'dbo:SoccerClub',
#    'dbo:Sport',
#    'dbo:BaseballTeam',
#    'dbo:InformationAppliance',
#    'dbo:VideoGame']},
#  'dbpedia_20546': {'id': 'dbpedia_20546',
#   'category': 'resource',
#   'type': ['dbo:OfficeHolder',
#    'dbo:PoliticalParty',
#    'dbo:City',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Royalty',
#    'dbo:Country',
#    'dbo:Company',
#    'dbo:Saint',
#    'dbo:Politician']},
#  'dbpedia_17589': {'id': 'dbpedia_17589',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Writer',
#    'dbo:MusicGenre',
#    'dbo:OfficeHolder',
#    'dbo:Band',
#    'dbo:VideoGame',
#    'dbo:Game',
#    'dbo:RadioStation',
#    'dbo:MusicalArtist']},
#  'dbpedia_10307': {'id': 'dbpedia_10307',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:InformationAppliance',
#    'dbo:City',
#    'dbo:Book',
#    'dbo:Software',
#    'dbo:Organisation',
#    'dbo:Scientist',
#    'dbo:GovernmentAgency']},
#  'dbpedia_15502': {'id': 'dbpedia_15502',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:ProgrammingLanguage',
#    'dbo:Writer',
#    'dbo:Sport',
#    'dbo:Language',
#    'dbo:Person',
#    'dbo:Disease',
#    'dbo:InformationAppliance',
#    'dbo:Island',
#    'dbo:VideoGame']},
#  'dbpedia_2096': {'id': 'dbpedia_2096',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:City',
#    'dbo:Scientist',
#    'dbo:Country',
#    'dbo:Aircraft',
#    'dbo:Writer',
#    'dbo:Language',
#    'dbo:Company',
#    'dbo:Philosopher',
#    'dbo:Game']},
#  'dbpedia_15898': {'id': 'dbpedia_15898',
#   'category': 'resource',
#   'type': ['dbo:Language',
#    'dbo:ProgrammingLanguage',
#    'dbo:ArtificialSatellite',
#    'dbo:Company',
#    'dbo:Software',
#    'dbo:InformationAppliance',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:Weapon']},
#  'dbpedia_18447': {'id': 'dbpedia_18447',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Settlement',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:City',
#    'dbo:Island',
#    'dbo:AdministrativeRegion',
#    'dbo:EthnicGroup',
#    'dbo:Language']},
#  'dbpedia_21857': {'id': 'dbpedia_21857',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:River',
#    'dbo:AdministrativeRegion',
#    'dbo:MilitaryConflict',
#    'dbo:Country',
#    'dbo:Sport',
#    'dbo:Monarch',
#    'dbo:Writer',
#    'dbo:Town']},
#  'dbpedia_17145': {'id': 'dbpedia_17145',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Monarch',
#    'dbo:MusicalArtist',
#    'dbo:Person',
#    'dbo:MilitaryConflict',
#    'dbo:Writer',
#    'dbo:Weapon',
#    'dbo:Enzyme',
#    'dbo:InformationAppliance',
#    'dbo:ChristianBishop']},
#  'dbpedia_20450': {'id': 'dbpedia_20450',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:Sport',
#    'dbo:Person',
#    'dbo:AdministrativeRegion',
#    'dbo:City',
#    'dbo:Country',
#    'dbo:Writer',
#    'dbo:Company',
#    'dbo:Organisation',
#    'dbo:Language']},
#  'dbpedia_18827': {'id': 'dbpedia_18827',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Company',
#    'dbo:Film',
#    'dbo:TelevisionShow',
#    'dbo:Writer',
#    'dbo:InformationAppliance',
#    'dbo:MusicalArtist',
#    'dbo:Book',
#    'dbo:TelevisionStation',
#    'dbo:Beverage']},
#  'dbpedia_6724': {'id': 'dbpedia_6724',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Film',
#    'dbo:MusicalArtist',
#    'dbo:Scientist',
#    'dbo:MilitaryPerson',
#    'dbo:OfficeHolder',
#    'dbo:Journalist',
#    'dbo:Aircraft',
#    'dbo:Mountain']},
#  'dbpedia_17542': {'id': 'dbpedia_17542',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Royalty',
#    'dbo:Scientist',
#    'dbo:Person',
#    'dbo:InformationAppliance',
#    'dbo:Company',
#    'dbo:ArtificialSatellite',
#    'dbo:Saint',
#    'dbo:MilitaryConflict',
#    'dbo:Monarch']},
#  'dbpedia_7166': {'id': 'dbpedia_7166',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Country',
#    'dbo:Settlement',
#    'dbo:Constellation',
#    'dbo:AdministrativeRegion',
#    'dbo:Royalty',
#    'dbo:MilitaryConflict',
#    'dbo:Scientist',
#    'dbo:Person',
#    'dbo:Writer']},
#  'dbpedia_15701': {'id': 'dbpedia_15701',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:Person',
#    'dbo:Country',
#    'dbo:University',
#    'dbo:Island',
#    'dbo:Writer',
#    'dbo:AdministrativeRegion',
#    'dbo:MilitaryConflict',
#    'dbo:Building']},
#  'dbpedia_2904': {'id': 'dbpedia_2904',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:SoccerClub',
#    'dbo:Organisation',
#    'dbo:Writer',
#    'dbo:University',
#    'dbo:Disease',
#    'dbo:Company',
#    'dbo:TelevisionShow',
#    'dbo:Award',
#    'dbo:ChemicalCompound']},
#  'dbpedia_13035': {'id': 'dbpedia_13035',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Plant',
#    'dbo:Writer',
#    'dbo:Film',
#    'dbo:Scientist',
#    'dbo:Royalty',
#    'dbo:AdministrativeRegion',
#    'dbo:Island',
#    'dbo:City',
#    'dbo:Saint']},
#  'dbpedia_3743': {'id': 'dbpedia_3743',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Settlement',
#    'dbo:Royalty',
#    'dbo:Film',
#    'dbo:Constellation',
#    'dbo:MilitaryConflict',
#    'dbo:FictionalCharacter',
#    'dbo:Fish',
#    'dbo:Album',
#    'dbo:Place']},
#  'dbpedia_11441': {'id': 'dbpedia_11441',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Plant',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:Film',
#    'dbo:AdministrativeRegion',
#    'dbo:Island',
#    'dbo:Royalty',
#    'dbo:City',
#    'dbo:Saint']},
#  'dbpedia_2169': {'id': 'dbpedia_2169',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Artist',
#    'dbo:Organisation',
#    'dbo:Film',
#    'dbo:EthnicGroup',
#    'dbo:MusicalArtist',
#    'dbo:Philosopher',
#    'dbo:Software']},
#  'dbpedia_8309': {'id': 'dbpedia_8309',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:ChemicalCompound',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:MilitaryUnit',
#    'dbo:Book',
#    'dbo:Royalty',
#    'dbo:Language',
#    'dbo:University',
#    'dbo:EthnicGroup']},
#  'dbpedia_14696': {'id': 'dbpedia_14696',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:PoliticalParty',
#    'dbo:BaseballTeam',
#    'dbo:Writer',
#    'dbo:AmericanFootballTeam',
#    'dbo:Plant',
#    'dbo:Person',
#    'dbo:Organisation',
#    'dbo:OfficeHolder',
#    'dbo:Royalty']},
#  'dbpedia_20621': {'id': 'dbpedia_20621',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:River',
#    'dbo:Country',
#    'dbo:AdministrativeRegion',
#    'dbo:InformationAppliance',
#    'dbo:Town',
#    'dbo:MilitaryUnit',
#    'dbo:ArtificialSatellite',
#    'dbo:Monarch']},
#  'dbpedia_13081': {'id': 'dbpedia_13081',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Artist',
#    'dbo:Philosopher',
#    'dbo:Royalty',
#    'dbo:MusicalArtist',
#    'dbo:Mammal',
#    'dbo:ChristianBishop',
#    'dbo:Book']},
#  'dbpedia_11342': {'id': 'dbpedia_11342',
#   'category': 'resource',
#   'type': ['dbo:Disease',
#    'dbo:Language',
#    'dbo:ProgrammingLanguage',
#    'dbo:Software',
#    'dbo:OfficeHolder',
#    'dbo:Person',
#    'dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:Writer',
#    'dbo:Saint']},
#  'dbpedia_1610': {'id': 'dbpedia_1610',
#   'category': 'resource',
#   'type': ['dbo:PoliticalParty',
#    'dbo:OfficeHolder',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:BaseballPlayer',
#    'dbo:Award',
#    'dbo:Election',
#    'dbo:RugbyClub',
#    'dbo:Country',
#    'dbo:Disease']},
#  'dbpedia_5531': {'id': 'dbpedia_5531',
#   'category': 'resource',
#   'type': ['dbo:Island',
#    'dbo:Band',
#    'dbo:Person',
#    'dbo:Weapon',
#    'dbo:InformationAppliance',
#    'dbo:Aircraft',
#    'dbo:TelevisionShow',
#    'dbo:Language',
#    'dbo:AdministrativeRegion',
#    'dbo:MilitaryConflict']},
#  'dbpedia_22145': {'id': 'dbpedia_22145',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Royalty',
#    'dbo:Company',
#    'dbo:Writer',
#    'dbo:BaseballTeam',
#    'dbo:Person',
#    'dbo:AmericanFootballTeam',
#    'dbo:Sport',
#    'dbo:ArtificialSatellite',
#    'dbo:InformationAppliance']},
#  'dbpedia_5991': {'id': 'dbpedia_5991',
#   'category': 'resource',
#   'type': ['dbo:AnatomicalStructure',
#    'dbo:Settlement',
#    'dbo:City',
#    'dbo:Band',
#    'dbo:Lake',
#    'dbo:Person',
#    'dbo:Disease',
#    'dbo:Place',
#    'dbo:Sea',
#    'dbo:InformationAppliance']},
#  'dbpedia_9328': {'id': 'dbpedia_9328',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:MilitaryConflict',
#    'dbo:Writer',
#    'dbo:Saint',
#    'dbo:Scientist',
#    'dbo:City',
#    'dbo:Monarch',
#    'dbo:Building',
#    'dbo:OfficeHolder']},
#  'dbpedia_17597': {'id': 'dbpedia_17597',
#   'category': 'resource',
#   'type': ['dbo:InformationAppliance',
#    'dbo:Person',
#    'dbo:MilitaryUnit',
#    'dbo:OfficeHolder',
#    'dbo:Royalty',
#    'dbo:Country',
#    'dbo:Settlement',
#    'dbo:Company',
#    'dbo:PoliticalParty',
#    'dbo:Disease']},
#  'dbpedia_21999': {'id': 'dbpedia_21999',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:River',
#    'dbo:AdministrativeRegion',
#    'dbo:Town',
#    'dbo:Constellation',
#    'dbo:Country',
#    'dbo:Fish',
#    'dbo:Bird',
#    'dbo:Film']},
#  'dbpedia_12376': {'id': 'dbpedia_12376',
#   'category': 'resource',
#   'type': ['dbo:Person']},
#  'dbpedia_18496': {'id': 'dbpedia_18496',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Scientist',
#    'dbo:Disease',
#    'dbo:Royalty',
#    'dbo:Band',
#    'dbo:City',
#    'dbo:ChemicalCompound',
#    'dbo:Company',
#    'dbo:Writer',
#    'dbo:River']},
#  'dbpedia_19727': {'id': 'dbpedia_19727',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:University',
#    'dbo:City',
#    'dbo:Artist',
#    'dbo:Philosopher',
#    'dbo:Software',
#    'dbo:Saint',
#    'dbo:Organisation']},
#  'dbpedia_20944': {'id': 'dbpedia_20944',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Writer',
#    'dbo:InformationAppliance',
#    'dbo:BaseballTeam',
#    'dbo:Game',
#    'dbo:Royalty',
#    'dbo:Sport',
#    'dbo:AmericanFootballTeam',
#    'dbo:VideoGame',
#    'dbo:Company']},
#  'dbpedia_20180': {'id': 'dbpedia_20180',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Book',
#    'dbo:Country',
#    'dbo:Artist',
#    'dbo:Person',
#    'dbo:Film',
#    'dbo:MusicalArtist',
#    'dbo:Royalty',
#    'dbo:FictionalCharacter',
#    'dbo:Saint']},
#  'dbpedia_8843': {'id': 'dbpedia_8843',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Writer',
#    'dbo:Award',
#    'dbo:Film',
#    'dbo:Royalty',
#    'dbo:Scientist',
#    'dbo:Anime',
#    'dbo:MusicalArtist',
#    'dbo:Mineral',
#    'dbo:AmericanFootballTeam']},
#  'dbpedia_16217': {'id': 'dbpedia_16217',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Settlement',
#    'dbo:City',
#    'dbo:AdministrativeRegion',
#    'dbo:Saint',
#    'dbo:Lake',
#    'dbo:Island',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:Building']},
#  'dbpedia_10394': {'id': 'dbpedia_10394',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Settlement',
#    'dbo:Organisation',
#    'dbo:Country',
#    'dbo:BaseballTeam',
#    'dbo:AmericanFootballTeam',
#    'dbo:Island',
#    'dbo:Royalty',
#    'dbo:Person',
#    'dbo:Scientist']},
#  'dbpedia_20499': {'id': 'dbpedia_20499',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Book',
#    'dbo:Scientist',
#    'dbo:Constellation',
#    'dbo:City',
#    'dbo:OfficeHolder',
#    'dbo:MusicalArtist',
#    'dbo:Film',
#    'dbo:Settlement']},
#  'dbpedia_1201': {'id': 'dbpedia_1201',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:Plant',
#    'dbo:City',
#    'dbo:InformationAppliance',
#    'dbo:Organisation',
#    'dbo:AdministrativeRegion',
#    'dbo:ChemicalCompound',
#    'dbo:ProgrammingLanguage']},
#  'dbpedia_18580': {'id': 'dbpedia_18580',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Film',
#    'dbo:TelevisionShow',
#    'dbo:Plant',
#    'dbo:FictionalCharacter',
#    'dbo:Company',
#    'dbo:Language',
#    'dbo:Book',
#    'dbo:Royalty']},
#  'dbpedia_3527': {'id': 'dbpedia_3527',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:Person',
#    'dbo:Constellation',
#    'dbo:Building',
#    'dbo:Film',
#    'dbo:WorldHeritageSite',
#    'dbo:Star',
#    'dbo:Fish',
#    'dbo:MusicalArtist',
#    'dbo:Bird']},
#  'dbpedia_15115': {'id': 'dbpedia_15115',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:Organisation',
#    'dbo:University',
#    'dbo:BaseballTeam',
#    'dbo:Person',
#    'dbo:AmericanFootballTeam',
#    'dbo:Writer',
#    'dbo:Band',
#    'dbo:City',
#    'dbo:ChemicalCompound']},
#  'dbpedia_4528': {'id': 'dbpedia_4528',
#   'category': 'resource',
#   'type': ['dbo:Band',
#    'dbo:Person',
#    'dbo:Company',
#    'dbo:Album',
#    'dbo:Writer',
#    'dbo:Book',
#    'dbo:Saint',
#    'dbo:MusicalArtist',
#    'dbo:Film',
#    'dbo:InformationAppliance']},
#  'dbpedia_6357': {'id': 'dbpedia_6357',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Philosopher',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:AmericanFootballTeam',
#    'dbo:Economist',
#    'dbo:Saint',
#    'dbo:Disease',
#    'dbo:AdministrativeRegion',
#    'dbo:Scientist']},
#  'dbpedia_12974': {'id': 'dbpedia_12974',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:Country',
#    'dbo:Island',
#    'dbo:City',
#    'dbo:River',
#    'dbo:AdministrativeRegion',
#    'dbo:Town',
#    'dbo:Person',
#    'dbo:MilitaryConflict',
#    'dbo:Building']},
#  'dbpedia_9367': {'id': 'dbpedia_9367',
#   'category': 'resource',
#   'type': ['dbo:InformationAppliance',
#    'dbo:Writer',
#    'dbo:River',
#    'dbo:Airline',
#    'dbo:Person',
#    'dbo:Weapon',
#    'dbo:Constellation',
#    'dbo:BodyOfWater',
#    'dbo:MilitaryConflict',
#    'dbo:AdministrativeRegion']},
#  'dbpedia_18939': {'id': 'dbpedia_18939',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Sport',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:Disease',
#    'dbo:InformationAppliance',
#    'dbo:FormulaOneTeam',
#    'dbo:Island',
#    'dbo:Language']},
#  'dbpedia_23201': {'id': 'dbpedia_23201',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Disease',
#    'dbo:Saint',
#    'dbo:OfficeHolder',
#    'dbo:Writer',
#    'dbo:Monarch',
#    'dbo:Drug',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Band']},
#  'dbpedia_6892': {'id': 'dbpedia_6892',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Royalty',
#    'dbo:Mineral',
#    'dbo:Band',
#    'dbo:City',
#    'dbo:MusicalArtist',
#    'dbo:Star',
#    'dbo:AmericanFootballTeam',
#    'dbo:Scientist',
#    'dbo:Disease']},
#  'dbpedia_8002': {'id': 'dbpedia_8002',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Writer',
#    'dbo:City',
#    'dbo:OfficeHolder',
#    'dbo:Country',
#    'dbo:Scientist',
#    'dbo:Language',
#    'dbo:Organisation',
#    'dbo:Settlement',
#    'dbo:MilitaryConflict']},
#  'dbpedia_18653': {'id': 'dbpedia_18653',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow',
#    'dbo:Person',
#    'dbo:TelevisionStation',
#    'dbo:Writer',
#    'dbo:OfficeHolder',
#    'dbo:Band',
#    'dbo:EthnicGroup',
#    'dbo:Book',
#    'dbo:Plant',
#    'dbo:FictionalCharacter']},
#  'dbpedia_13276': {'id': 'dbpedia_13276',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Disease',
#    'dbo:Saint',
#    'dbo:Person',
#    'dbo:OfficeHolder',
#    'dbo:Writer',
#    'dbo:Monarch',
#    'dbo:MilitaryPerson',
#    'dbo:Drug',
#    'dbo:Film']},
#  'dbpedia_4897': {'id': 'dbpedia_4897',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:Company',
#    'dbo:Writer',
#    'dbo:MusicalArtist',
#    'dbo:InformationAppliance',
#    'dbo:Royalty',
#    'dbo:Beverage',
#    'dbo:AnatomicalStructure',
#    'dbo:Band']},
#  'dbpedia_21184': {'id': 'dbpedia_21184',
#   'category': 'resource',
#   'type': ['dbo:Disease', 'dbo:Person']},
#  'dbpedia_5424': {'id': 'dbpedia_5424',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:City',
#    'dbo:Country',
#    'dbo:InformationAppliance',
#    'dbo:Island',
#    'dbo:BaseballTeam',
#    'dbo:Company',
#    'dbo:Writer',
#    'dbo:AmericanFootballTeam']},
#  'dbpedia_12705': {'id': 'dbpedia_12705',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Award',
#    'dbo:Person',
#    'dbo:Film',
#    'dbo:Artist',
#    'dbo:Philosopher',
#    'dbo:Book',
#    'dbo:BaseballTeam',
#    'dbo:MilitaryConflict']},
#  'dbpedia_3240': {'id': 'dbpedia_3240',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Game',
#    'dbo:Person',
#    'dbo:Sport',
#    'dbo:Aircraft',
#    'dbo:Cricketer',
#    'dbo:Ship',
#    'dbo:Enzyme',
#    'dbo:Crustacean',
#    'dbo:Philosopher']},
#  'dbpedia_5736': {'id': 'dbpedia_5736',
#   'category': 'resource',
#   'type': ['dbo:ArtificialSatellite',
#    'dbo:Writer',
#    'dbo:Continent',
#    'dbo:ChemicalCompound',
#    'dbo:Scientist',
#    'dbo:Disease',
#    'dbo:InformationAppliance',
#    'dbo:Island',
#    'dbo:Star',
#    'dbo:Language']},
#  'dbpedia_183': {'id': 'dbpedia_183',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Country',
#    'dbo:OfficeHolder',
#    'dbo:AdministrativeRegion',
#    'dbo:Organisation',
#    'dbo:ArtificialSatellite',
#    'dbo:Person',
#    'dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:MilitaryUnit']},
#  'dbpedia_19905': {'id': 'dbpedia_19905',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:MilitaryUnit',
#    'dbo:Country',
#    'dbo:City',
#    'dbo:Weapon',
#    'dbo:Island',
#    'dbo:Royalty',
#    'dbo:Aircraft']},
#  'dbpedia_22987': {'id': 'dbpedia_22987',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Constellation',
#    'dbo:Book',
#    'dbo:Settlement',
#    'dbo:Company',
#    'dbo:Scientist',
#    'dbo:MilitaryUnit',
#    'dbo:Royalty',
#    'dbo:City']},
#  'dbpedia_19549': {'id': 'dbpedia_19549',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:Scientist',
#    'dbo:BaseballTeam',
#    'dbo:AmericanFootballTeam',
#    'dbo:Royalty',
#    'dbo:SoccerClub',
#    'dbo:Person',
#    'dbo:MilitaryUnit',
#    'dbo:Sport',
#    'dbo:OfficeHolder']},
#  'dbpedia_8646': {'id': 'dbpedia_8646',
#   'category': 'resource',
#   'type': ['dbo:ProgrammingLanguage',
#    'dbo:Disease',
#    'dbo:Writer',
#    'dbo:ChemicalCompound',
#    'dbo:Drug',
#    'dbo:Person',
#    'dbo:InformationAppliance',
#    'dbo:Plant',
#    'dbo:Software',
#    'dbo:Organisation']},
#  'dbpedia_1673': {'id': 'dbpedia_1673',
#   'category': 'resource',
#   'type': ['dbo:AnatomicalStructure',
#    'dbo:Disease',
#    'dbo:ChemicalCompound',
#    'dbo:Eukaryote',
#    'dbo:Plant',
#    'dbo:Person',
#    'dbo:Animal',
#    'dbo:Drug',
#    'dbo:Enzyme']},
#  'dbpedia_18238': {'id': 'dbpedia_18238',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow',
#    'dbo:Person',
#    'dbo:Disease',
#    'dbo:Film',
#    'dbo:Writer',
#    'dbo:Country',
#    'dbo:Language',
#    'dbo:MilitaryConflict',
#    'dbo:ChemicalCompound',
#    'dbo:MilitaryUnit']},
#  'dbpedia_14411': {'id': 'dbpedia_14411',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Monarch',
#    'dbo:Settlement',
#    'dbo:Person',
#    'dbo:ArtificialSatellite',
#    'dbo:Sport',
#    'dbo:MilitaryConflict',
#    'dbo:Weapon',
#    'dbo:AdministrativeRegion',
#    'dbo:Language']},
#  'dbpedia_8652': {'id': 'dbpedia_8652',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:Royalty',
#    'dbo:Star',
#    'dbo:Constellation',
#    'dbo:MusicalArtist',
#    'dbo:TelevisionShow',
#    'dbo:Saint',
#    'dbo:Book',
#    'dbo:Band']},
#  'dbpedia_15760': {'id': 'dbpedia_15760',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Writer',
#    'dbo:Book',
#    'dbo:Person',
#    'dbo:Plant',
#    'dbo:Company',
#    'dbo:Game',
#    'dbo:ProgrammingLanguage',
#    'dbo:Royalty',
#    'dbo:Film']},
#  'dbpedia_9621': {'id': 'dbpedia_9621',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Organisation',
#    'dbo:Writer',
#    'dbo:Company',
#    'dbo:Scientist',
#    'dbo:InformationAppliance',
#    'dbo:Person',
#    'dbo:MilitaryUnit',
#    'dbo:Island',
#    'dbo:MilitaryConflict']},
#  'dbpedia_3066': {'id': 'dbpedia_3066',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Language',
#    'dbo:ProgrammingLanguage',
#    'dbo:EthnicGroup',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Settlement',
#    'dbo:Software',
#    'dbo:Person',
#    'dbo:OfficeHolder']},
#  'dbpedia_10108': {'id': 'dbpedia_10108',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:Organisation',
#    'dbo:Disease',
#    'dbo:Band',
#    'dbo:Album',
#    'dbo:Book',
#    'dbo:Language',
#    'dbo:Philosopher']},
#  'dbpedia_11951': {'id': 'dbpedia_11951',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Settlement',
#    'dbo:Royalty',
#    'dbo:MilitaryConflict',
#    'dbo:Writer',
#    'dbo:AdministrativeRegion',
#    'dbo:Monarch',
#    'dbo:Country',
#    'dbo:Saint',
#    'dbo:Band']},
#  'dbpedia_3529': {'id': 'dbpedia_3529',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Philosopher',
#    'dbo:Person',
#    'dbo:Film',
#    'dbo:Monarch',
#    'dbo:Disease',
#    'dbo:MusicalArtist',
#    'dbo:Saint',
#    'dbo:Mineral',
#    'dbo:AmericanFootballTeam']},
#  'dbpedia_12827': {'id': 'dbpedia_12827',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Plant',
#    'dbo:Writer',
#    'dbo:Film',
#    'dbo:Person',
#    'dbo:Royalty',
#    'dbo:City',
#    'dbo:Saint',
#    'dbo:Island',
#    'dbo:MusicalArtist']},
#  'dbpedia_2452': {'id': 'dbpedia_2452',
#   'category': 'resource',
#   'type': ['dbo:ProgrammingLanguage',
#    'dbo:InformationAppliance',
#    'dbo:Person']},
#  'dbpedia_19213': {'id': 'dbpedia_19213',
#   'category': 'resource',
#   'type': ['dbo:PoliticalParty',
#    'dbo:OfficeHolder',
#    'dbo:Politician',
#    'dbo:Person',
#    'dbo:Philosopher',
#    'dbo:Saint',
#    'dbo:Country',
#    'dbo:PrimeMinister',
#    'dbo:Settlement',
#    'dbo:FictionalCharacter']},
#  'dbpedia_23102': {'id': 'dbpedia_23102',
#   'category': 'resource',
#   'type': ['dbo:OfficeHolder',
#    'dbo:Company',
#    'dbo:Settlement',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:Saint',
#    'dbo:ChemicalCompound',
#    'dbo:AnatomicalStructure',
#    'dbo:ChristianBishop',
#    'dbo:Disease']},
#  'dbpedia_20082': {'id': 'dbpedia_20082',
#   'category': 'resource',
#   'type': ['dbo:BaseballTeam',
#    'dbo:Sport',
#    'dbo:AmericanFootballTeam',
#    'dbo:Person',
#    'dbo:ProgrammingLanguage',
#    'dbo:Plant',
#    'dbo:Disease',
#    'dbo:MusicalArtist',
#    'dbo:Mineral',
#    'dbo:SoccerClub']},
#  'dbpedia_15307': {'id': 'dbpedia_15307',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:SoccerClub',
#    'dbo:Drug',
#    'dbo:Disease',
#    'dbo:Organisation',
#    'dbo:University',
#    'dbo:Writer',
#    'dbo:Company',
#    'dbo:TelevisionShow',
#    'dbo:Award']},
#  'dbpedia_19674': {'id': 'dbpedia_19674',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:MilitaryConflict',
#    'dbo:Plant',
#    'dbo:Writer',
#    'dbo:City',
#    'dbo:AdministrativeRegion',
#    'dbo:Royalty',
#    'dbo:Film',
#    'dbo:Saint',
#    'dbo:Island']},
#  'dbpedia_3815': {'id': 'dbpedia_3815',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Constellation',
#    'dbo:Person',
#    'dbo:Royalty',
#    'dbo:MilitaryConflict',
#    'dbo:Plant',
#    'dbo:Scientist',
#    'dbo:InformationAppliance',
#    'dbo:Saint',
#    'dbo:Book']},
#  'dbpedia_17575': {'id': 'dbpedia_17575',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:Scientist',
#    'dbo:Book',
#    'dbo:MusicalArtist',
#    'dbo:Award',
#    'dbo:Writer',
#    'dbo:SoccerManager',
#    'dbo:CollegeCoach',
#    'dbo:OfficeHolder']},
#  'dbpedia_19633': {'id': 'dbpedia_19633',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Settlement',
#    'dbo:MilitaryConflict',
#    'dbo:City',
#    'dbo:Company',
#    'dbo:AdministrativeRegion',
#    'dbo:MilitaryUnit',
#    'dbo:Building',
#    'dbo:Language',
#    'dbo:Holiday']},
#  'dbpedia_14301': {'id': 'dbpedia_14301',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:BaseballTeam',
#    'dbo:AmericanFootballTeam',
#    'dbo:ProgrammingLanguage',
#    'dbo:Band',
#    'dbo:Royalty',
#    'dbo:Star',
#    'dbo:Organisation',
#    'dbo:Writer',
#    'dbo:Aircraft']},
#  'dbpedia_21450': {'id': 'dbpedia_21450',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:TelevisionShow',
#    'dbo:Artist',
#    'dbo:FictionalCharacter',
#    'dbo:Philosopher',
#    'dbo:MusicalArtist',
#    'dbo:Royalty',
#    'dbo:Software']},
#  'dbpedia_15086': {'id': 'dbpedia_15086',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:InformationAppliance',
#    'dbo:MusicalArtist',
#    'dbo:TelevisionShow',
#    'dbo:Award',
#    'dbo:Book',
#    'dbo:ArtificialSatellite',
#    'dbo:Film']},
#  'dbpedia_13088': {'id': 'dbpedia_13088',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:ProgrammingLanguage',
#    'dbo:MilitaryUnit',
#    'dbo:Software',
#    'dbo:Royalty',
#    'dbo:Monarch',
#    'dbo:Plant']},
#  'dbpedia_13022': {'id': 'dbpedia_13022',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Royalty',
#    'dbo:Writer',
#    'dbo:Settlement',
#    'dbo:MusicalArtist',
#    'dbo:Scientist',
#    'dbo:OfficeHolder',
#    'dbo:Monarch',
#    'dbo:City',
#    'dbo:Artist']},
#  'dbpedia_7186': {'id': 'dbpedia_7186',
#   'category': 'resource',
#   'type': ['dbo:MilitaryConflict',
#    'dbo:Monarch',
#    'dbo:Language',
#    'dbo:Island',
#    'dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:Building',
#    'dbo:Company',
#    'dbo:OfficeHolder',
#    'dbo:ChristianBishop']},
#  'dbpedia_7787': {'id': 'dbpedia_7787',
#   'category': 'resource',
#   'type': ['dbo:MilitaryConflict',
#    'dbo:TennisPlayer',
#    'dbo:Royalty',
#    'dbo:OfficeHolder',
#    'dbo:Monarch',
#    'dbo:AmericanFootballTeam',
#    'dbo:InformationAppliance',
#    'dbo:Bacteria',
#    'dbo:MusicalArtist',
#    'dbo:Company']},
#  'dbpedia_9131': {'id': 'dbpedia_9131',
#   'category': 'resource',
#   'type': ['dbo:ArtificialSatellite',
#    'dbo:MilitaryUnit',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Country',
#    'dbo:Building',
#    'dbo:Island',
#    'dbo:Disease',
#    'dbo:Person',
#    'dbo:ProgrammingLanguage']},
#  'dbpedia_624': {'id': 'dbpedia_624',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Person',
#    'dbo:Saint',
#    'dbo:AdministrativeRegion',
#    'dbo:Film',
#    'dbo:Scientist',
#    'dbo:MusicalArtist',
#    'dbo:Planet',
#    'dbo:Mineral',
#    'dbo:AmericanFootballTeam']},
#  'dbpedia_22104': {'id': 'dbpedia_22104',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Settlement',
#    'dbo:PoliticalParty',
#    'dbo:OfficeHolder',
#    'dbo:City',
#    'dbo:Company',
#    'dbo:Royalty',
#    'dbo:Language',
#    'dbo:MilitaryUnit',
#    'dbo:Scientist']},
#  'dbpedia_15008': {'id': 'dbpedia_15008',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:Person',
#    'dbo:MilitaryConflict',
#    'dbo:Settlement',
#    'dbo:Saint',
#    'dbo:InformationAppliance',
#    'dbo:Country',
#    'dbo:Plant']},
#  'dbpedia_5033': {'id': 'dbpedia_5033',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Book',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Band',
#    'dbo:InformationAppliance',
#    'dbo:Musical',
#    'dbo:MusicGenre',
#    'dbo:FictionalCharacter',
#    'dbo:Software']},
#  'dbpedia_17832': {'id': 'dbpedia_17832',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Person',
#    'dbo:Monarch',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Band',
#    'dbo:Religious',
#    'dbo:TelevisionShow',
#    'dbo:MusicalArtist',
#    'dbo:AmericanFootballTeam']},
#  'dbpedia_20589': {'id': 'dbpedia_20589',
#   'category': 'resource',
#   'type': ['dbo:Comedian',
#    'dbo:Noble',
#    'dbo:OfficeHolder',
#    'dbo:Person',
#    'dbo:Painter',
#    'dbo:Writer',
#    'dbo:Film']},
#  'dbpedia_14563': {'id': 'dbpedia_14563',
#   'category': 'resource',
#   'type': ['dbo:Book',
#    'dbo:Writer',
#    'dbo:Company',
#    'dbo:Game',
#    'dbo:Person',
#    'dbo:FictionalCharacter',
#    'dbo:Settlement',
#    'dbo:Comic',
#    'dbo:Island',
#    'dbo:ComicsCharacter']},
#  'dbpedia_10964': {'id': 'dbpedia_10964',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Book',
#    'dbo:University',
#    'dbo:Film',
#    'dbo:Philosopher',
#    'dbo:Protein',
#    'dbo:Band',
#    'dbo:VideoGame']},
#  'dbpedia_20263': {'id': 'dbpedia_20263',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:OfficeHolder',
#    'dbo:City',
#    'dbo:Film',
#    'dbo:Writer',
#    'dbo:InformationAppliance',
#    'dbo:Disease',
#    'dbo:MilitaryConflict']},
#  'dbpedia_10652': {'id': 'dbpedia_10652',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:Book',
#    'dbo:Award',
#    'dbo:Organisation',
#    'dbo:MusicalArtist',
#    'dbo:Band',
#    'dbo:InformationAppliance']},
#  'dbpedia_17518': {'id': 'dbpedia_17518',
#   'category': 'resource',
#   'type': ['dbo:Language',
#    'dbo:Scientist',
#    'dbo:ProgrammingLanguage',
#    'dbo:Writer',
#    'dbo:Country',
#    'dbo:Person',
#    'dbo:Settlement',
#    'dbo:MilitaryConflict',
#    'dbo:EthnicGroup',
#    'dbo:Artist']},
#  'dbpedia_19380': {'id': 'dbpedia_19380',
#   'category': 'resource',
#   'type': ['dbo:OfficeHolder',
#    'dbo:Royalty',
#    'dbo:PoliticalParty',
#    'dbo:City',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:Disease',
#    'dbo:Saint',
#    'dbo:InformationAppliance']},
#  'dbpedia_388': {'id': 'dbpedia_388',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:Country',
#    'dbo:Writer',
#    'dbo:Settlement',
#    'dbo:MilitaryConflict',
#    'dbo:Artist',
#    'dbo:Language',
#    'dbo:Person',
#    'dbo:MilitaryUnit',
#    'dbo:Island']},
#  'dbpedia_17932': {'id': 'dbpedia_17932',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Settlement',
#    'dbo:Country',
#    'dbo:Island',
#    'dbo:AdministrativeRegion',
#    'dbo:University',
#    'dbo:EthnicGroup',
#    'dbo:Organisation',
#    'dbo:Person',
#    'dbo:Scientist']},
#  'dbpedia_11988': {'id': 'dbpedia_11988',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Person',
#    'dbo:InformationAppliance',
#    'dbo:MilitaryUnit',
#    'dbo:BaseballPlayer',
#    'dbo:OfficeHolder',
#    'dbo:City',
#    'dbo:Bank',
#    'dbo:TelevisionShow',
#    'dbo:Band']},
#  'dbpedia_22595': {'id': 'dbpedia_22595',
#   'category': 'resource',
#   'type': ['dbo:Language',
#    'dbo:ProgrammingLanguage',
#    'dbo:ArtificialSatellite',
#    'dbo:Software',
#    'dbo:EthnicGroup',
#    'dbo:Scientist',
#    'dbo:Company',
#    'dbo:InformationAppliance',
#    'dbo:Writer',
#    'dbo:Country']},
#  'dbpedia_12448': {'id': 'dbpedia_12448',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:Royalty',
#    'dbo:Person',
#    'dbo:ProgrammingLanguage',
#    'dbo:Scientist',
#    'dbo:Constellation',
#    'dbo:Star',
#    'dbo:Holiday',
#    'dbo:Aircraft',
#    'dbo:MilitaryConflict']},
#  'dbpedia_2745': {'id': 'dbpedia_2745',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Scientist',
#    'dbo:Disease',
#    'dbo:InformationAppliance',
#    'dbo:Island',
#    'dbo:Language']},
#  'dbpedia_5561': {'id': 'dbpedia_5561',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Person',
#    'dbo:Philosopher',
#    'dbo:MusicalArtist',
#    'dbo:Saint',
#    'dbo:Artist',
#    'dbo:OfficeHolder',
#    'dbo:Disease',
#    'dbo:Mineral',
#    'dbo:AmericanFootballTeam']},
#  'dbpedia_19930': {'id': 'dbpedia_19930',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Settlement',
#    'dbo:City',
#    'dbo:Island',
#    'dbo:Language',
#    'dbo:AdministrativeRegion',
#    'dbo:Royalty',
#    'dbo:Company',
#    'dbo:MilitaryUnit',
#    'dbo:EthnicGroup']},
#  'dbpedia_4989': {'id': 'dbpedia_4989',
#   'category': 'resource',
#   'type': ['dbo:AmericanFootballTeam',
#    'dbo:BaseballTeam',
#    'dbo:SoccerClub',
#    'dbo:Settlement',
#    'dbo:Royalty',
#    'dbo:Person',
#    'dbo:Building',
#    'dbo:AustralianFootballTeam',
#    'dbo:RugbyClub',
#    'dbo:Park']},
#  'dbpedia_21566': {'id': 'dbpedia_21566',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Constellation',
#    'dbo:Person',
#    'dbo:TelevisionShow',
#    'dbo:Writer',
#    'dbo:Plant',
#    'dbo:InformationAppliance',
#    'dbo:MilitaryConflict',
#    'dbo:ProgrammingLanguage',
#    'dbo:AdministrativeRegion']},
#  'dbpedia_9117': {'id': 'dbpedia_9117',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:Country',
#    'dbo:Company',
#    'dbo:Island',
#    'dbo:Organisation',
#    'dbo:University',
#    'dbo:Building',
#    'dbo:Constellation',
#    'dbo:AdministrativeRegion']},
#  'dbpedia_18553': {'id': 'dbpedia_18553',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:MilitaryConflict',
#    'dbo:Writer',
#    'dbo:Disease',
#    'dbo:Royalty',
#    'dbo:City',
#    'dbo:Scientist',
#    'dbo:Person',
#    'dbo:Settlement',
#    'dbo:Island']},
#  'dbpedia_11474': {'id': 'dbpedia_11474',
#   'category': 'resource',
#   'type': ['dbo:Film',
#    'dbo:FictionalCharacter',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:TelevisionShow',
#    'dbo:Royalty',
#    'dbo:MusicalArtist',
#    'dbo:ArtificialSatellite',
#    'dbo:Mineral',
#    'dbo:ComicsCharacter']},
#  'dbpedia_6558': {'id': 'dbpedia_6558',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Person',
#    'dbo:Monarch',
#    'dbo:Saint',
#    'dbo:Film',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:ChristianBishop',
#    'dbo:Country',
#    'dbo:MusicalArtist']},
#  'dbpedia_20440': {'id': 'dbpedia_20440',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Country',
#    'dbo:Island',
#    'dbo:Settlement',
#    'dbo:Plant',
#    'dbo:Writer',
#    'dbo:City',
#    'dbo:AdministrativeRegion',
#    'dbo:Person',
#    'dbo:MilitaryConflict']},
#  'dbpedia_6847': {'id': 'dbpedia_6847',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:Country',
#    'dbo:Constellation',
#    'dbo:AdministrativeRegion',
#    'dbo:MilitaryConflict',
#    'dbo:Island',
#    'dbo:Band',
#    'dbo:MilitaryUnit',
#    'dbo:PoliticalParty']},
#  'dbpedia_22037': {'id': 'dbpedia_22037',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Scientist',
#    'dbo:Organisation',
#    'dbo:Person',
#    'dbo:OfficeHolder',
#    'dbo:University',
#    'dbo:City',
#    'dbo:Royalty',
#    'dbo:BaseballTeam',
#    'dbo:SoccerClub']},
#  'dbpedia_4801': {'id': 'dbpedia_4801',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Settlement',
#    'dbo:Writer',
#    'dbo:MusicalArtist',
#    'dbo:Scientist',
#    'dbo:City',
#    'dbo:MilitaryConflict',
#    'dbo:Royalty',
#    'dbo:OfficeHolder',
#    'dbo:Star']},
#  'dbpedia_4760': {'id': 'dbpedia_4760',
#   'category': 'resource',
#   'type': ['dbo:Disease',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:SoccerClub',
#    'dbo:Drug',
#    'dbo:Organisation',
#    'dbo:University',
#    'dbo:Band',
#    'dbo:Company',
#    'dbo:TelevisionShow']},
#  'dbpedia_3519': {'id': 'dbpedia_3519',
#   'category': 'resource',
#   'type': ['dbo:Game',
#    'dbo:Book',
#    'dbo:Saint',
#    'dbo:Scientist',
#    'dbo:AcademicJournal',
#    'dbo:Comic',
#    'dbo:Company',
#    'dbo:Person']},
#  'dbpedia_18430': {'id': 'dbpedia_18430',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Writer',
#    'dbo:Plant',
#    'dbo:Person',
#    'dbo:Saint',
#    'dbo:Scientist',
#    'dbo:Royalty',
#    'dbo:Film',
#    'dbo:Island',
#    'dbo:Disease']},
#  'dbpedia_6993': {'id': 'dbpedia_6993',
#   'category': 'resource',
#   'type': ['dbo:MusicalArtist',
#    'dbo:MusicGenre',
#    'dbo:Band',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:Musical',
#    'dbo:VideoGame',
#    'dbo:RadioStation',
#    'dbo:Mineral',
#    'dbo:Constellation']},
#  'dbpedia_14516': {'id': 'dbpedia_14516',
#   'category': 'resource',
#   'type': ['dbo:InformationAppliance',
#    'dbo:Software',
#    'dbo:Person',
#    'dbo:ProgrammingLanguage',
#    'dbo:Game',
#    'dbo:Company',
#    'dbo:VideoGame',
#    'dbo:Scientist',
#    'dbo:Weapon',
#    'dbo:Organisation']},
#  'dbpedia_19117': {'id': 'dbpedia_19117',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Country',
#    'dbo:Settlement',
#    'dbo:MilitaryConflict',
#    'dbo:Language',
#    'dbo:OfficeHolder',
#    'dbo:EthnicGroup',
#    'dbo:Person',
#    'dbo:MilitaryUnit',
#    'dbo:PoliticalParty']},
#  'dbpedia_22787': {'id': 'dbpedia_22787',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Country',
#    'dbo:City',
#    'dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Constellation',
#    'dbo:BaseballTeam',
#    'dbo:AdministrativeRegion']},
#  'dbpedia_20306': {'id': 'dbpedia_20306',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:BaseballTeam',
#    'dbo:Writer',
#    'dbo:Game',
#    'dbo:AmericanFootballTeam',
#    'dbo:Plant',
#    'dbo:Sport',
#    'dbo:Scientist',
#    'dbo:Person',
#    'dbo:Royalty']},
#  'dbpedia_12859': {'id': 'dbpedia_12859',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:Royalty',
#    'dbo:MusicalArtist',
#    'dbo:Mineral',
#    'dbo:AmericanFootballTeam',
#    'dbo:Band',
#    'dbo:Sport',
#    'dbo:Book',
#    'dbo:Artery']},
#  'dbpedia_8122': {'id': 'dbpedia_8122',
#   'category': 'resource',
#   'type': ['dbo:OfficeHolder',
#    'dbo:MilitaryUnit',
#    'dbo:Organisation',
#    'dbo:City',
#    'dbo:Constellation',
#    'dbo:Person',
#    'dbo:InformationAppliance',
#    'dbo:AdministrativeRegion',
#    'dbo:PoliticalParty',
#    'dbo:Scientist']},
#  'dbpedia_2457': {'id': 'dbpedia_2457',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:Country',
#    'dbo:Organisation',
#    'dbo:Company',
#    'dbo:Island',
#    'dbo:AmericanFootballTeam',
#    'dbo:ChemicalCompound',
#    'dbo:University',
#    'dbo:BaseballTeam']},
#  'dbpedia_14045': {'id': 'dbpedia_14045',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Settlement',
#    'dbo:Country',
#    'dbo:AdministrativeRegion',
#    'dbo:Company',
#    'dbo:Royalty',
#    'dbo:Monarch',
#    'dbo:Person',
#    'dbo:Building',
#    'dbo:Film']},
#  'dbpedia_18296': {'id': 'dbpedia_18296',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Software',
#    'dbo:Scientist',
#    'dbo:InformationAppliance',
#    'dbo:Person',
#    'dbo:Aircraft',
#    'dbo:ProgrammingLanguage',
#    'dbo:Philosopher',
#    'dbo:Constellation',
#    'dbo:Organisation']},
#  'dbpedia_12959': {'id': 'dbpedia_12959',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:InformationAppliance',
#    'dbo:Plant',
#    'dbo:Writer',
#    'dbo:AdministrativeRegion',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:City',
#    'dbo:Saint',
#    'dbo:Island']},
#  'dbpedia_14915': {'id': 'dbpedia_14915',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Band',
#    'dbo:MusicalArtist',
#    'dbo:Album',
#    'dbo:TelevisionShow',
#    'dbo:MusicGenre',
#    'dbo:InformationAppliance',
#    'dbo:ProgrammingLanguage',
#    'dbo:Aircraft',
#    'dbo:Film']},
#  'dbpedia_19704': {'id': 'dbpedia_19704',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:MilitaryUnit',
#    'dbo:Royalty',
#    'dbo:City',
#    'dbo:Saint',
#    'dbo:Person',
#    'dbo:University',
#    'dbo:ArtificialSatellite',
#    'dbo:Organisation',
#    'dbo:TelevisionStation']},
#  'dbpedia_1999': {'id': 'dbpedia_1999',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Writer',
#    'dbo:Saint',
#    'dbo:Plant',
#    'dbo:City',
#    'dbo:Scientist',
#    'dbo:Film',
#    'dbo:Island',
#    'dbo:MilitaryConflict',
#    'dbo:InformationAppliance']},
#  'dbpedia_19364': {'id': 'dbpedia_19364',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:Person',
#    'dbo:Royalty',
#    'dbo:Writer',
#    'dbo:City',
#    'dbo:Disease',
#    'dbo:Saint',
#    'dbo:Book',
#    'dbo:AdministrativeRegion',
#    'dbo:Plant']},
#  'dbpedia_8664': {'id': 'dbpedia_8664',
#   'category': 'resource',
#   'type': ['dbo:Plant', 'dbo:Mammal', 'dbo:Person']},
#  'dbpedia_22194': {'id': 'dbpedia_22194',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:City',
#    'dbo:Settlement',
#    'dbo:AdministrativeRegion',
#    'dbo:Drug',
#    'dbo:EthnicGroup',
#    'dbo:Company',
#    'dbo:Plant',
#    'dbo:ProgrammingLanguage',
#    'dbo:Organisation']},
#  'dbpedia_23548': {'id': 'dbpedia_23548',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Building',
#    'dbo:River',
#    'dbo:ChemicalCompound',
#    'dbo:Constellation',
#    'dbo:Language',
#    'dbo:Religious',
#    'dbo:Weapon',
#    'dbo:MilitaryUnit',
#    'dbo:Company']},
#  'dbpedia_22137': {'id': 'dbpedia_22137',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Saint',
#    'dbo:Person',
#    'dbo:MusicalArtist',
#    'dbo:University',
#    'dbo:Royalty',
#    'dbo:Constellation',
#    'dbo:Settlement',
#    'dbo:ChristianBishop']},
#  'dbpedia_20711': {'id': 'dbpedia_20711',
#   'category': 'resource',
#   'type': ['dbo:TelevisionShow',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:Disease',
#    'dbo:TelevisionStation',
#    'dbo:Scientist',
#    'dbo:Film',
#    'dbo:Country',
#    'dbo:MilitaryConflict',
#    'dbo:ChemicalCompound']},
#  'dbpedia_10716': {'id': 'dbpedia_10716',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Country',
#    'dbo:OfficeHolder',
#    'dbo:Settlement',
#    'dbo:AdministrativeRegion',
#    'dbo:Person',
#    'dbo:MilitaryUnit',
#    'dbo:ArtificialSatellite',
#    'dbo:Royalty',
#    'dbo:Organisation']},
#  'dbpedia_12820': {'id': 'dbpedia_12820',
#   'category': 'resource',
#   'type': ['dbo:Philosopher',
#    'dbo:Scientist',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:Royalty',
#    'dbo:Politician',
#    'dbo:MusicalArtist',
#    'dbo:Mineral',
#    'dbo:AmericanFootballTeam',
#    'dbo:Band']},
#  'dbpedia_5338': {'id': 'dbpedia_5338',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:InformationAppliance',
#    'dbo:ProgrammingLanguage',
#    'dbo:Person',
#    'dbo:Software',
#    'dbo:Weapon',
#    'dbo:Game',
#    'dbo:Aircraft',
#    'dbo:Organisation',
#    'dbo:AnatomicalStructure']},
#  'dbpedia_22226': {'id': 'dbpedia_22226',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:River',
#    'dbo:AdministrativeRegion',
#    'dbo:Person',
#    'dbo:Country',
#    'dbo:Software',
#    'dbo:Town',
#    'dbo:Plant',
#    'dbo:EthnicGroup']},
#  'dbpedia_13472': {'id': 'dbpedia_13472',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Scientist',
#    'dbo:Aircraft',
#    'dbo:Company',
#    'dbo:Ship',
#    'dbo:MilitaryPerson',
#    'dbo:Software',
#    'dbo:InformationAppliance',
#    'dbo:Writer',
#    'dbo:ArtificialSatellite']},
#  'dbpedia_23390': {'id': 'dbpedia_23390',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Software',
#    'dbo:Scientist',
#    'dbo:InformationAppliance',
#    'dbo:Person',
#    'dbo:Aircraft',
#    'dbo:Royalty',
#    'dbo:Organisation',
#    'dbo:ProgrammingLanguage',
#    'dbo:Weapon']},
#  'dbpedia_21821': {'id': 'dbpedia_21821',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Company',
#    'dbo:Settlement',
#    'dbo:Constellation',
#    'dbo:Person',
#    'dbo:Writer',
#    'dbo:University',
#    'dbo:Country',
#    'dbo:AdministrativeRegion',
#    'dbo:Film']},
#  'dbpedia_18065': {'id': 'dbpedia_18065',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Settlement',
#    'dbo:Country',
#    'dbo:Island',
#    'dbo:Language',
#    'dbo:AdministrativeRegion',
#    'dbo:Artist']},
#  'dbpedia_7669': {'id': 'dbpedia_7669',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Monarch',
#    'dbo:Person',
#    'dbo:Film',
#    'dbo:FictionalCharacter',
#    'dbo:Writer',
#    'dbo:TelevisionShow',
#    'dbo:Scientist',
#    'dbo:Language',
#    'dbo:MilitaryConflict']},
#  'dbpedia_13896': {'id': 'dbpedia_13896',
#   'category': 'resource',
#   'type': ['dbo:MilitaryConflict',
#    'dbo:ArtificialSatellite',
#    'dbo:MilitaryUnit',
#    'dbo:Royalty',
#    'dbo:Software',
#    'dbo:Writer',
#    'dbo:OfficeHolder',
#    'dbo:Scientist',
#    'dbo:Disease',
#    'dbo:InformationAppliance']},
#  'dbpedia_8402': {'id': 'dbpedia_8402',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Person',
#    'dbo:University',
#    'dbo:MilitaryUnit',
#    'dbo:City',
#    'dbo:ChemicalCompound',
#    'dbo:TelevisionShow',
#    'dbo:Royalty',
#    'dbo:Organisation',
#    'dbo:Anime']},
#  'dbpedia_23074': {'id': 'dbpedia_23074',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Settlement',
#    'dbo:City',
#    'dbo:River',
#    'dbo:AdministrativeRegion',
#    'dbo:Company',
#    'dbo:Language',
#    'dbo:MilitaryUnit',
#    'dbo:EthnicGroup',
#    'dbo:Town']},
#  'dbpedia_3035': {'id': 'dbpedia_3035',
#   'category': 'resource',
#   'type': ['dbo:Game',
#    'dbo:Sport',
#    'dbo:VideoGame',
#    'dbo:InformationAppliance',
#    'dbo:Company',
#    'dbo:BaseballTeam',
#    'dbo:AmericanFootballTeam',
#    'dbo:BaseballPlayer',
#    'dbo:TennisPlayer',
#    'dbo:Person']},
#  'dbpedia_13370': {'id': 'dbpedia_13370',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:Award',
#    'dbo:MusicalArtist',
#    'dbo:Film',
#    'dbo:Artist',
#    'dbo:Book',
#    'dbo:Philosopher',
#    'dbo:Software']},
#  'dbpedia_6434': {'id': 'dbpedia_6434',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:Company',
#    'dbo:MusicalArtist',
#    'dbo:Band',
#    'dbo:Writer',
#    'dbo:InformationAppliance',
#    'dbo:Album',
#    'dbo:Monarch',
#    'dbo:Royalty']},
#  'dbpedia_5897': {'id': 'dbpedia_5897',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:City',
#    'dbo:Country',
#    'dbo:Island',
#    'dbo:Writer',
#    'dbo:Disease',
#    'dbo:Saint',
#    'dbo:University',
#    'dbo:Person']},
#  'dbpedia_11496': {'id': 'dbpedia_11496',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:MusicalArtist',
#    'dbo:Band',
#    'dbo:MusicGenre',
#    'dbo:Royalty',
#    'dbo:Artist',
#    'dbo:Writer',
#    'dbo:Musical',
#    'dbo:Company']},
#  'dbpedia_21952': {'id': 'dbpedia_21952',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Royalty',
#    'dbo:Philosopher',
#    'dbo:Scientist',
#    'dbo:MusicalArtist',
#    'dbo:Mineral',
#    'dbo:Film',
#    'dbo:AmericanFootballTeam',
#    'dbo:Band']},
#  'dbpedia_22498': {'id': 'dbpedia_22498',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Royalty',
#    'dbo:Writer',
#    'dbo:City',
#    'dbo:TelevisionShow',
#    'dbo:Band',
#    'dbo:Scientist',
#    'dbo:Constellation',
#    'dbo:Country',
#    'dbo:Settlement']},
#  'dbpedia_14453': {'id': 'dbpedia_14453',
#   'category': 'resource',
#   'type': ['dbo:Disease',
#    'dbo:InformationAppliance',
#    'dbo:ArtificialSatellite',
#    'dbo:Scientist',
#    'dbo:AnatomicalStructure',
#    'dbo:Writer',
#    'dbo:Book',
#    'dbo:Island',
#    'dbo:Person',
#    'dbo:Artery']},
#  'dbpedia_3644': {'id': 'dbpedia_3644',
#   'category': 'resource',
#   'type': ['dbo:Disease',
#    'dbo:Writer',
#    'dbo:Island',
#    'dbo:Settlement',
#    'dbo:Royalty',
#    'dbo:RugbyClub',
#    'dbo:Scientist',
#    'dbo:TelevisionShow',
#    'dbo:InformationAppliance',
#    'dbo:Language']},
# ...
#    'dbo:MusicalArtist',
#    'dbo:Artist',
#    'dbo:Company',
#    'dbo:Organisation']},
#  'dbpedia_20542': {'id': 'dbpedia_20542',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:Royalty',
#    'dbo:Sport',
#    'dbo:Company',
#    'dbo:Settlement',
#    'dbo:MusicalArtist',
#    'dbo:Saint',
#    'dbo:MilitaryConflict']},
#  'dbpedia_23292': {'id': 'dbpedia_23292',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:TelevisionShow',
#    'dbo:Writer',
#    'dbo:MusicalArtist',
#    'dbo:TelevisionStation',
#    'dbo:InformationAppliance',
#    'dbo:MilitaryConflict',
#    'dbo:FictionalCharacter',
#    'dbo:GovernmentAgency',
#    'dbo:Colour']},
#  'dbpedia_5188': {'id': 'dbpedia_5188',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:ProgrammingLanguage',
#    'dbo:MilitaryUnit',
#    'dbo:Software',
#    'dbo:Company',
#    'dbo:Royalty',
#    'dbo:Weapon',
#    'dbo:Aircraft',
#    'dbo:MilitaryPerson',
#    'dbo:MilitaryConflict']},
#  'dbpedia_15282': {'id': 'dbpedia_15282',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:MusicalArtist',
#    'dbo:Band',
#    'dbo:Film',
#    'dbo:Game',
#    'dbo:OfficeHolder',
#    'dbo:Company',
#    'dbo:Royalty',
#    'dbo:Saint',
#    'dbo:TelevisionShow']},
#  'dbpedia_22902': {'id': 'dbpedia_22902',
#   'category': 'resource',
#   'type': ['dbo:Scientist',
#    'dbo:Royalty',
#    'dbo:Person',
#    'dbo:Disease',
#    'dbo:Organisation',
#    'dbo:ChemicalCompound',
#    'dbo:City',
#    'dbo:Writer',
#    'dbo:Company',
#    'dbo:Saint']},
#  'dbpedia_23075': {'id': 'dbpedia_23075',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Book',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Saint',
#    'dbo:Musical',
#    'dbo:Philosopher',
#    'dbo:Film',
#    'dbo:FictionalCharacter',
#    'dbo:ProgrammingLanguage']},
#  'dbpedia_19776': {'id': 'dbpedia_19776',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Scientist',
#    'dbo:Royalty',
#    'dbo:Film',
#    'dbo:Writer',
#    'dbo:Company',
#    'dbo:InformationAppliance',
#    'dbo:Disease',
#    'dbo:City',
#    'dbo:EthnicGroup']},
#  'dbpedia_7752': {'id': 'dbpedia_7752',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Country',
#    'dbo:Writer',
#    'dbo:MusicalArtist',
#    'dbo:Scientist',
#    'dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:AdministrativeRegion',
#    'dbo:City',
#    'dbo:Artist']},
#  'dbpedia_8937': {'id': 'dbpedia_8937',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Royalty', 'dbo:TelevisionStation']},
#  'dbpedia_15791': {'id': 'dbpedia_15791',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Book',
#    'dbo:Museum',
#    'dbo:Person',
#    'dbo:Film',
#    'dbo:Musical',
#    'dbo:Play',
#    'dbo:Scientist',
#    'dbo:Disease',
#    'dbo:InformationAppliance']},
#  'dbpedia_5009': {'id': 'dbpedia_5009',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Island',
#    'dbo:Band',
#    'dbo:Person',
#    'dbo:AdministrativeRegion',
#    'dbo:InformationAppliance',
#    'dbo:Constellation',
#    'dbo:Colour',
#    'dbo:Mineral',
#    'dbo:River']},
#  'dbpedia_19474': {'id': 'dbpedia_19474',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:MilitaryUnit',
#    'dbo:Writer',
#    'dbo:Royalty',
#    'dbo:Person',
#    'dbo:Plant',
#    'dbo:Film',
#    'dbo:MilitaryPerson',
#    'dbo:City',
#    'dbo:Scientist']},
#  'dbpedia_6085': {'id': 'dbpedia_6085',
#   'category': 'resource',
#   'type': ['dbo:MusicalArtist',
#    'dbo:Person',
#    'dbo:VideoGame',
#    'dbo:Band',
#    'dbo:Film',
#    'dbo:Royalty',
#    'dbo:Writer',
#    'dbo:Mineral',
#    'dbo:AmericanFootballTeam']},
#  'dbpedia_10241': {'id': 'dbpedia_10241',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Country',
#    'dbo:Settlement',
#    'dbo:ArtificialSatellite',
#    'dbo:Organisation',
#    'dbo:AdministrativeRegion',
#    'dbo:MilitaryConflict',
#    'dbo:OfficeHolder',
#    'dbo:Person',
#    'dbo:Language']},
#  'dbpedia_20229': {'id': 'dbpedia_20229',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Scientist',
#    'dbo:University',
#    'dbo:Person',
#    'dbo:City',
#    'dbo:OfficeHolder',
#    'dbo:Band',
#    'dbo:InformationAppliance',
#    'dbo:Writer',
#    'dbo:BaseballPlayer']},
#  'dbpedia_22914': {'id': 'dbpedia_22914',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Writer',
#    'dbo:Person',
#    'dbo:Royalty',
#    'dbo:BaseballTeam',
#    'dbo:AmericanFootballTeam',
#    'dbo:Sport',
#    'dbo:Game',
#    'dbo:SoccerClub',
#    'dbo:Scientist']},
#  'dbpedia_17520': {'id': 'dbpedia_17520',
#   'category': 'resource',
#   'type': ['dbo:Weapon',
#    'dbo:MusicalArtist',
#    'dbo:Royalty',
#    'dbo:Aircraft',
#    'dbo:Island',
#    'dbo:Mineral',
#    'dbo:TelevisionStation',
#    'dbo:Software',
#    'dbo:Game',
#    'dbo:AmericanFootballTeam']},
#  'dbpedia_59': {'id': 'dbpedia_59',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Award',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:MusicalArtist',
#    'dbo:Film',
#    'dbo:Book',
#    'dbo:Royalty',
#    'dbo:BaseballPlayer',
#    'dbo:Newspaper']},
#  'dbpedia_2767': {'id': 'dbpedia_2767',
#   'category': 'resource',
#   'type': ['dbo:Country',
#    'dbo:Settlement',
#    'dbo:City',
#    'dbo:AdministrativeRegion',
#    'dbo:Island',
#    'dbo:Person',
#    'dbo:Royalty',
#    'dbo:Saint',
#    'dbo:University',
#    'dbo:EthnicGroup']},
#  'dbpedia_4361': {'id': 'dbpedia_4361',
#   'category': 'resource',
#   'type': ['dbo:Band',
#    'dbo:Person',
#    'dbo:Album',
#    'dbo:AmericanFootballTeam',
#    'dbo:City',
#    'dbo:MusicGenre',
#    'dbo:Sport',
#    'dbo:Building',
#    'dbo:Settlement',
#    'dbo:AdministrativeRegion']},
#  'dbpedia_3879': {'id': 'dbpedia_3879',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:Country',
#    'dbo:AdministrativeRegion',
#    'dbo:MilitaryConflict',
#    'dbo:Organisation',
#    'dbo:Royalty',
#    'dbo:Writer',
#    'dbo:Film',
#    'dbo:SoccerClub']},
#  'dbpedia_21236': {'id': 'dbpedia_21236',
#   'category': 'resource',
#   'type': ['dbo:OfficeHolder',
#    'dbo:MilitaryUnit',
#    'dbo:Saint',
#    'dbo:Royalty',
#    'dbo:PrimeMinister',
#    'dbo:Company',
#    'dbo:Settlement',
#    'dbo:ChemicalCompound',
#    'dbo:Writer',
#    'dbo:AnatomicalStructure']},
#  'dbpedia_22129': {'id': 'dbpedia_22129',
#   'category': 'resource',
#   'type': ['dbo:Language',
#    'dbo:City',
#    'dbo:EthnicGroup',
#    'dbo:Royalty',
#    'dbo:Country',
#    'dbo:Constellation',
#    'dbo:Company',
#    'dbo:Island',
#    'dbo:Band',
#    'dbo:Monarch']},
#  'dbpedia_1896': {'id': 'dbpedia_1896',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Town',
#    'dbo:Artist',
#    'dbo:Sport',
#    'dbo:MusicalArtist',
#    'dbo:Medician',
#    'dbo:Mineral',
#    'dbo:AmericanFootballTeam',
#    'dbo:Band']},
#  'dbpedia_4255': {'id': 'dbpedia_4255',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:MilitaryConflict',
#    'dbo:Star',
#    'dbo:Holiday',
#    'dbo:Writer',
#    'dbo:Constellation',
#    'dbo:TelevisionShow',
#    'dbo:Royalty',
#    'dbo:Settlement']},
#  'dbpedia_9931': {'id': 'dbpedia_9931',
#   'category': 'resource',
#   'type': ['dbo:Saint',
#    'dbo:Royalty',
#    'dbo:OfficeHolder',
#    'dbo:Person',
#    'dbo:Organisation',
#    'dbo:MilitaryUnit',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:Monarch',
#    'dbo:Company']},
#  'dbpedia_11815': {'id': 'dbpedia_11815',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:InformationAppliance',
#    'dbo:Software',
#    'dbo:Scientist',
#    'dbo:Person',
#    'dbo:Aircraft',
#    'dbo:Writer',
#    'dbo:ProgrammingLanguage',
#    'dbo:Organisation',
#    'dbo:Weapon']},
#  'dbpedia_1171': {'id': 'dbpedia_1171',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:ProgrammingLanguage',
#    'dbo:ArtificialSatellite',
#    'dbo:Person',
#    'dbo:TelevisionShow',
#    'dbo:Software',
#    'dbo:InformationAppliance',
#    'dbo:Film',
#    'dbo:Scientist',
#    'dbo:TelevisionStation']},
#  'dbpedia_5729': {'id': 'dbpedia_5729',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Artist',
#    'dbo:Game',
#    'dbo:Book',
#    'dbo:Philosopher',
#    'dbo:Software',
#    'dbo:Saint',
#    'dbo:Organisation']},
#  'dbpedia_6659': {'id': 'dbpedia_6659',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Disease',
#    'dbo:Band',
#    'dbo:Language',
#    'dbo:Royalty',
#    'dbo:Book',
#    'dbo:TelevisionShow',
#    'dbo:Organisation',
#    'dbo:MilitaryConflict',
#    'dbo:Album']},
#  'dbpedia_14840': {'id': 'dbpedia_14840',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Person',
#    'dbo:SoccerClub',
#    'dbo:Film',
#    'dbo:Monarch',
#    'dbo:Scientist',
#    'dbo:Writer',
#    'dbo:Game',
#    'dbo:ChessPlayer',
#    'dbo:Book']},
#  'dbpedia_4658': {'id': 'dbpedia_4658',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Monarch',
#    'dbo:Saint',
#    'dbo:Weapon',
#    'dbo:Country',
#    'dbo:MilitaryConflict',
#    'dbo:MusicalArtist',
#    'dbo:Politician',
#    'dbo:Aircraft',
#    'dbo:Language']},
#  'dbpedia_8736': {'id': 'dbpedia_8736',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Sport',
#    'dbo:BaseballTeam',
#    'dbo:AmericanFootballTeam',
#    'dbo:Band',
#    'dbo:SoccerClub',
#    'dbo:Organisation',
#    'dbo:Royalty',
#    'dbo:Writer',
#    'dbo:Plant']},
#  'dbpedia_1220': {'id': 'dbpedia_1220',
#   'category': 'resource',
#   'type': ['dbo:Island',
#    'dbo:Country',
#    'dbo:Language',
#    'dbo:Sport',
#    'dbo:Band',
#    'dbo:Person',
#    'dbo:City',
#    'dbo:InformationAppliance',
#    'dbo:Constellation',
#    'dbo:Writer']},
#  'dbpedia_21728': {'id': 'dbpedia_21728',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:BaseballTeam',
#    'dbo:AmericanFootballTeam',
#    'dbo:Sport',
#    'dbo:Game',
#    'dbo:Band',
#    'dbo:SoccerClub',
#    'dbo:Organisation',
#    'dbo:Language']},
#  'dbpedia_14639': {'id': 'dbpedia_14639',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Person',
#    'dbo:ProgrammingLanguage',
#    'dbo:Country',
#    'dbo:Star',
#    'dbo:Royalty',
#    'dbo:City',
#    'dbo:Settlement',
#    'dbo:OfficeHolder',
#    'dbo:Island']},
#  'dbpedia_9326': {'id': 'dbpedia_9326',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:MusicalArtist',
#    'dbo:Award',
#    'dbo:Book',
#    'dbo:Film',
#    'dbo:Band',
#    'dbo:Aircraft',
#    'dbo:Company']},
#  'dbpedia_12177': {'id': 'dbpedia_12177',
#   'category': 'resource',
#   'type': ['dbo:ChemicalCompound',
#    'dbo:Scientist',
#    'dbo:AnatomicalStructure',
#    'dbo:Country',
#    'dbo:Settlement',
#    'dbo:InformationAppliance',
#    'dbo:Constellation',
#    'dbo:Writer',
#    'dbo:Mineral',
#    'dbo:Island']},
#  'dbpedia_13480': {'id': 'dbpedia_13480',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Writer',
#    'dbo:Plant',
#    'dbo:Island',
#    'dbo:Royalty',
#    'dbo:Person',
#    'dbo:Organisation',
#    'dbo:ProgrammingLanguage',
#    'dbo:ChemicalCompound',
#    'dbo:Film']},
#  'dbpedia_1644': {'id': 'dbpedia_1644',
#   'category': 'resource',
#   'type': ['dbo:Plant',
#    'dbo:Royalty',
#    'dbo:Mammal',
#    'dbo:Writer',
#    'dbo:Fish',
#    'dbo:ProgrammingLanguage',
#    'dbo:Person',
#    'dbo:Language',
#    'dbo:Bird',
#    'dbo:Monarch']},
#  'dbpedia_17541': {'id': 'dbpedia_17541',
#   'category': 'resource',
#   'type': ['dbo:ArtificialSatellite',
#    'dbo:Person',
#    'dbo:AnatomicalStructure',
#    'dbo:Scientist',
#    'dbo:Disease',
#    'dbo:Book',
#    'dbo:Museum',
#    'dbo:Mammal',
#    'dbo:Artery',
#    'dbo:GovernmentAgency']},
#  'dbpedia_4122': {'id': 'dbpedia_4122',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:Award',
#    'dbo:Book',
#    'dbo:MusicalArtist',
#    'dbo:Writer',
#    'dbo:TelevisionShow',
#    'dbo:Scientist',
#    'dbo:Company',
#    'dbo:BaseballPlayer']},
#  'dbpedia_4504': {'id': 'dbpedia_4504',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:City',
#    'dbo:Settlement',
#    'dbo:Film',
#    'dbo:Country',
#    'dbo:Island',
#    'dbo:University',
#    'dbo:Building',
#    'dbo:Constellation',
#    'dbo:Company']},
#  'dbpedia_9332': {'id': 'dbpedia_9332',
#   'category': 'resource',
#   'type': ['dbo:InformationAppliance',
#    'dbo:Person',
#    'dbo:Company',
#    'dbo:Royalty',
#    'dbo:MusicalArtist',
#    'dbo:Disease',
#    'dbo:Software',
#    'dbo:Mineral',
#    'dbo:AmericanFootballTeam',
#    'dbo:Band']},
#  'dbpedia_18385': {'id': 'dbpedia_18385',
#   'category': 'resource',
#   'type': ['dbo:Band',
#    'dbo:Person',
#    'dbo:Company',
#    'dbo:Software',
#    'dbo:MusicalArtist',
#    'dbo:TelevisionShow',
#    'dbo:ProgrammingLanguage',
#    'dbo:Award',
#    'dbo:Book',
#    'dbo:Game']},
#  'dbpedia_2781': {'id': 'dbpedia_2781',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Person',
#    'dbo:Philosopher',
#    'dbo:Saint',
#    'dbo:MilitaryPerson',
#    'dbo:Book',
#    'dbo:FigureSkater',
#    'dbo:Ship',
#    'dbo:Disease',
#    'dbo:MusicalArtist']},
#  'dbpedia_3137': {'id': 'dbpedia_3137',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:City',
#    'dbo:River',
#    'dbo:AdministrativeRegion',
#    'dbo:Drug',
#    'dbo:Town',
#    'dbo:Country',
#    'dbo:MilitaryConflict',
#    'dbo:Building',
#    'dbo:Sport']},
#  'dbpedia_21354': {'id': 'dbpedia_21354',
#   'category': 'resource',
#   'type': ['dbo:Company',
#    'dbo:Band',
#    'dbo:Person',
#    'dbo:InformationAppliance',
#    'dbo:Organisation',
#    'dbo:Software',
#    'dbo:Aircraft',
#    'dbo:TelevisionStation',
#    'dbo:TelevisionShow',
#    'dbo:AnatomicalStructure']},
#  'dbpedia_14391': {'id': 'dbpedia_14391',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:Artist',
#    'dbo:Organisation',
#    'dbo:Disease',
#    'dbo:Band',
#    'dbo:Philosopher',
#    'dbo:Software',
#    'dbo:Saint']},
#  'dbpedia_1526': {'id': 'dbpedia_1526',
#   'category': 'resource',
#   'type': ['dbo:Writer',
#    'dbo:Person',
#    'dbo:MilitaryConflict',
#    'dbo:Royalty',
#    'dbo:Film',
#    'dbo:Building',
#    'dbo:Scientist',
#    'dbo:OfficeHolder',
#    'dbo:Sport',
#    'dbo:City']},
#  'dbpedia_5644': {'id': 'dbpedia_5644',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Film',
#    'dbo:BaseballTeam',
#    'dbo:AmericanFootballTeam',
#    'dbo:Writer',
#    'dbo:Royalty',
#    'dbo:Band',
#    'dbo:ArtificialSatellite',
#    'dbo:Organisation',
#    'dbo:Scientist']},
#  'dbpedia_6121': {'id': 'dbpedia_6121',
#   'category': 'resource',
#   'type': ['dbo:Person', 'dbo:Monarch', 'dbo:MilitaryConflict']},
#  'dbpedia_13286': {'id': 'dbpedia_13286',
#   'category': 'resource',
#   'type': ['dbo:Settlement',
#    'dbo:AdministrativeRegion',
#    'dbo:Country',
#    'dbo:City',
#    'dbo:Language',
#    'dbo:Royalty',
#    'dbo:River',
#    'dbo:Island',
#    'dbo:Organisation',
#    'dbo:Writer']},
#  'dbpedia_20931': {'id': 'dbpedia_20931',
#   'category': 'resource',
#   'type': ['dbo:Constellation',
#    'dbo:Writer',
#    'dbo:Plant',
#    'dbo:Person',
#    'dbo:Royalty',
#    'dbo:Film',
#    'dbo:City',
#    'dbo:Saint',
#    'dbo:Island',
#    'dbo:Company']},
#  'dbpedia_9063': {'id': 'dbpedia_9063',
#   'category': 'resource',
#   'type': ['dbo:Film',
#    'dbo:Person',
#    'dbo:Band',
#    'dbo:Writer',
#    'dbo:MusicGenre',
#    'dbo:MusicalArtist',
#    'dbo:TelevisionShow',
#    'dbo:Monarch',
#    'dbo:Book',
#    'dbo:University']},
#  'dbpedia_4664': {'id': 'dbpedia_4664',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Saint',
#    'dbo:Person',
#    'dbo:Monarch',
#    'dbo:Organisation',
#    'dbo:ProgrammingLanguage',
#    'dbo:Philosopher',
#    'dbo:Scientist',
#    'dbo:SoccerClub',
#    'dbo:ChristianBishop']},
#  'dbpedia_19961': {'id': 'dbpedia_19961',
#   'category': 'resource',
#   'type': ['dbo:City',
#    'dbo:Royalty',
#    'dbo:Settlement',
#    'dbo:MilitaryConflict',
#    'dbo:AdministrativeRegion',
#    'dbo:Monarch',
#    'dbo:Country',
#    'dbo:PoliticalParty',
#    'dbo:Person',
#    'dbo:ChristianBishop']},
#  'dbpedia_8715': {'id': 'dbpedia_8715',
#   'category': 'resource',
#   'type': ['dbo:Royalty',
#    'dbo:Monarch',
#    'dbo:Saint',
#    'dbo:Person',
#    'dbo:Scientist',
#    'dbo:Country',
#    'dbo:TelevisionShow',
#    'dbo:Band',
#    'dbo:Island',
#    'dbo:AdministrativeRegion']},
#  'dbpedia_23035': {'id': 'dbpedia_23035',
#   'category': 'resource',
#   'type': ['dbo:Person',
#    'dbo:Country',
#    'dbo:Writer',
#    'dbo:Scientist',
#    'dbo:MusicalArtist',
#    'dbo:Royalty',
#    'dbo:City',
#    'dbo:Artist',
#    'dbo:OfficeHolder',
#    'dbo:Settlement']},
#  ...}

# %%
test_res['dbpedia_7955']
# Out:
# {'id': 'dbpedia_7955',
#  'category': 'resource',
#  'type': ['dbo:Language',
#   'dbo:Scientist',
#   'dbo:Country',
#   'dbo:ProgrammingLanguage',
#   'dbo:Settlement',
#   'dbo:Writer',
#   'dbo:Person',
#   'dbo:MilitaryConflict',
#   'dbo:Island',
#   'dbo:City']}

# %%
tt['dbpedia_16015']['type']
# Out:
# ['number']

# %%
tt = {}
for x in test:
    tt.update({x['id']:{
                'id': x['id'],
                'category': x['category'],
                'type': x['type']}
            })

# %%
for key, value in tt.items():
    try:
        tt[key]['type'] = test_res[key]['type']
    except:
        continue

# %%
f = open(f"results/bm25_es_system_output.json", "w")
json.dump(list(tt.values()), f)
f.close()

# %%
from evaluate import load_ground_truth, load_system_output, evaluate

type_hierarchy, max_depth = load_type_hierarchy('evaluation/dbpedia/dbpedia_types.tsv')
ground_truth = load_ground_truth('datasets/DBpedia/smarttask_dbpedia_test.json', type_hierarchy)
system_output = load_system_output('results/bm25_es_system_output.json')
evaluate(system_output, ground_truth, type_hierarchy, max_depth)
# Out:
# Loading type hierarchy from evaluation/dbpedia/dbpedia_types.tsv... 761 types loaded (max depth: 7)
# Loading ground truth from datasets/DBpedia/smarttask_dbpedia_test.json...
#    4369 questions loaded
# Loading system predictions from results/bm25_es_system_output.json...
#    4369 predictions loaded
#
#
# Evaluation results:
# -------------------
# Category prediction (based on 4369 questions)
#   Accuracy: 0.925
# Type ranking (based on 4369 questions)
#   NDCG@5:  0.527
#   NDCG@10: 0.522

# %%
def evaluate_simple(es, k=100, amount=0, index=INDEX_NAME):
    """
    A test evaluation, simply re-rank using relevancy,
    0 = Not relevant
    1 = Partially relevant
    2 = Relevant
    
    Arguments:
        es: Elasticsearch object instance.
        k: How many documents to handle per query.
        amount: How many queries to run, 0 = all.
        index: Name of the index with respect to which the query is analyzed.  
    
    Returns:
        A dictionary containing the queryIDs - list of retrieved instance types.
    """
    progress, N = 0, len(training_queries)
    type_hierarchy, max_depth = load_type_hierarchy("evaluation\dbpedia\dbpedia_types.tsv")
    results = {}
    for qId, queryObject in training_queries.items():
        type_relevancy = {}
        for typ in queryObject['type']:
            if not typ in type_hierarchy:
                continue
            hierarchy = get_type_path(type_hierarchy, typ)[::-1]
            for v in hierarchy:
                type_relevancy[v] = 1 # Relevant, its in the same hierarchy but in a diff pos.            

        for typ in queryObject['type']:
            type_relevancy[typ] = 2 # This is the type we want. Give it the highest weight.
            
        if len(type_relevancy) == 0:
            continue

        query = queryObject['question']
        hits = es.search(index=index, _source=True, size=k, 
            body={"query": {"bool": {"must": {"match": {"abstract": query}}, "must_not": {"match": {"instance": "thing"}}}}}
        )['hits']['hits']

        rerank = []
        for obj in hits:
            instanceType = obj['_source']['instance']
            if not instanceType in type_hierarchy:
                rerank.append((instanceType, 0))
                continue
            if instanceType in type_relevancy:                
                rerank.append((instanceType, type_relevancy[instanceType]))
                continue                
            weight = get_type_path(type_hierarchy, instanceType)
            weight = [(1 if (t in type_relevancy) else 0) for t in weight] + [0]
            rerank.append((instanceType, max(weight)))

        rerank.sort(key=lambda x:x[-1], reverse=True) # Re-rank the initial hits based on their relevancy.
        results[qId] = [v for v,_ in rerank[:10]]

        progress += 1
        if (progress % 1000) == 0:
            print('Progress - {}/{} queries handled.'.format(progress, N))

        if amount and (progress >= amount):
            break

    return results
