# %%
from audioop import avg
import json
from typing import Callable, Dict, List, Set, Tuple

import numpy as np
from elasticsearch import Elasticsearch
import re
import math
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import HuberRegressor
import csv
from nltk.corpus import stopwords
import re
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity
from evaluate import load_type_hierarchy, get_type_path
from data_cleaning import preprocess_txt, load_data, load_queries

# %%
INDEX_NAME = 'dbpedia_2'
INDEX_SETTINGS = {
    'mappings': {
            'properties': {
                'abstract': {
                    'type': 'text',
                    'term_vector': 'yes',
                    'analyzer': 'english'
                },
                'instance': {
                    'type': 'text',
                    'term_vector': 'yes',
                    'analyzer': 'english'
                }
            }
        }
    }

# %%
es = Elasticsearch()
es.info()
# Out:
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# {'name': 'EAS-CZTWRQ3',
#  'cluster_name': 'elasticsearch',
#  'cluster_uuid': 'S7F79Gj_R92-RoVRmUCaGw',
#  'version': {'number': '7.17.6',
#   'build_flavor': 'default',
#   'build_type': 'zip',
#   'build_hash': 'f65e9d338dc1d07b642e14a27f338990148ee5b6',
#   'build_date': '2022-08-23T11:08:48.893373482Z',
#   'build_snapshot': False,
#   'lucene_version': '8.11.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
train = load_data('datasets/DBpedia/smarttask_dbpedia_train.json')
#test = load_data('datasets/DBpedia/smarttask_dbpedia_test.json')
test = load_data('results/test_queries_svm_output.json')

# %%
type_hierarchy, max_depth = load_type_hierarchy("evaluation\dbpedia\dbpedia_types.tsv")
# Out:
# Loading type hierarchy from evaluation\dbpedia\dbpedia_types.tsv... 761 types loaded (max depth: 7)

# %%
training_queries = load_queries(train)
test_queries = load_queries(test)

# %%
test_queries
# Out:
# {'dbpedia_7955': {'question': 'what sound pig make french language',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_22599': {'question': 'where war take place where one commander zuo zongtang',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_19677': {'question': 'which mountains contained inyo national forest',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_11163': {'question': 'what seat frankfurter allgemeine zeitung adjacent wetteraukreis',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_18792': {'question': 'what people buried toronto die',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_11251': {'question': 'what league major league lacrosse',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_17993': {'question': 'what series robert guillaume play robert',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_20546': {'question': 'which political party arunachal pradesh legislative assembly election 2014 leader rishikesh',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_17589': {'question': 'what janet jackson genre',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_10307': {'question': 'what public company which start letter',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_15502': {'question': 'which trans neptunian object argument periapsis',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_2096': {'question': 'which chinese han studied engineering lowest estimated net worth',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_15898': {'question': 'which operating system assembly language programming language which starts letter v',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_18447': {'question': 'which composer girl north country subsequent work moondog matinee',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_21857': {'question': 'where river end which rakitnica flows',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_17145': {'question': 'what sibling john iii sobieski employed',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_20450': {'question': 'what regional radio sports network associated',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_18827': {'question': 'list tv shows producer erik bork company dreamworks television',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_6724': {'question': 'what william shakespeare occupation',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_17542': {'question': 'what gravitational wave detector which start letter v',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_7166': {'question': 'name sparkasse highest tier 1 capital ratio',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_15701': {'question': 'what college town located utc time zone starts letter z',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_2904': {'question': 'what genetic association regulates molecular biology hsa mir 6887 5p',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_13035': {'question': 'tell intelligence agency whose name word stations',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_

#   'category': 'resource',
#   'type': ''},
#  'dbpedia_8715': {'question': 'what brother kids llywelyn great',
#   'category': 'resource',
#   'type': ''},
#  'dbpedia_23035': {'question': 'which country bill gates born',
#   'category': 'resource',
#   'type': ''},
#  ...}

# %%
def analyze_query(
    es: Elasticsearch, query: str, field: str, index: str = INDEX_NAME
) -> List[str]:
    """Analyzes a query with respect to the relevant index.

    Args:
        es: Elasticsearch object instance.
        query: String of query terms.
        field: The field with respect to which the query is analyzed.
        index: Name of the index with respect to which the query is analyzed.

    Returns:
        A list of query terms that exist in the specified field among the
        documents in the index.
    """
    tokens = es.indices.analyze(index=index, body={"text": query})["tokens"]
    query_terms = []
    for t in sorted(tokens, key=lambda x: x["position"]):
        # Use a boolean query to find at least one document that contains the
        # term.
        hits = (
            es.search(
                index=index,
                query={"match": {field: t["token"]}},
                _source=False,
                size=1,
            )
            .get("hits", {})
            .get("hits", {})
        )
        doc_id = hits[0]["_id"] if len(hits) > 0 else None
        if doc_id is None:
            continue
        query_terms.append(t["token"])
    return query_terms

# %%
# GLOB_TERM_DOC_FREQ = {}
# NUM_DOCS = es.count(index=INDEX_NAME)['count']
# Out:
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)

# %%
def create_query_terms(query_dict: Dict, es: Elasticsearch):
    """Analyze all queries and add terms to dictionary
    Args: 
        query_dict: a dictionary containing {
                                        'query_id': {
                                            'question': 'some question',
                                            'category': 'some category',
                                            'type': 'some type'
                                        }
                                    }
        es: Elasticsearch object instance.
    Returns: 
        A dictionary with query_ids as keys, question, category, 
        type and analized query_terms as values.
    """
    for query_id, query_features in query_dict.items():
        query_dict[query_id]['query_terms'] = analyze_query(es, 
                                            query_features['question'], 
                                            'abstract')
    
    return query_dict

# %%
training_queries = create_query_terms(training_queries, es)
test_queries = create_query_terms(test_queries, es)
# Out:
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)

# %%
def extract_features(query_terms, doc_id, es, index=INDEX_NAME):
    """
    Extracts query features, document features and query-document features of a query and document pair.
    
        Arguments:
            query_terms: List of analyzed query terms.
            doc_id: Document identifier of indexed document.
            es: Elasticsearch object instance.
            index: Name of relevant index on the running Elasticsearch service. 
            
        Returns:
            List of extracted feature values in a fixed order.
    """

    total_docs = es.count(index=INDEX_NAME)['count']
    term_doc_freq_dict = {}
    query = dict(Counter(query_terms))    
    doc_term_freqs = {} 
    tv = es.termvectors(index=index, id=doc_id, fields='abstract', term_statistics=False)    
    for term, term_stat in tv['term_vectors']['abstract']['terms'].items():
        doc_term_freqs[term] = term_stat['term_freq']
    
    idf = []
    for term in query_terms:
        if not term in term_doc_freq_dict:
            n = 0
            hits = es.search(
                index=index, 
                query = {"bool": {"must": {"match": {"abstract": term}}, "must_not": {"match": {"instance": "owl:Thing"}}}}, 
                _source=False, size=1).get('hits',{}).get('hits',{})
            doc_id = (hits[0]['_id'] if (len(hits) > 0) else None)
            if doc_id is not None:
                tv = es.termvectors(index=index, id=doc_id, fields='abstract', term_statistics=True)['term_vectors']['abstract']['terms']
                if term in tv:
                    n = tv[term]['doc_freq']                    
            term_doc_freq_dict[term] = n
            
        n = term_doc_freq_dict[term]
        if n: 
            idf.append(math.log(total_docs/n))

    terms_doc_unique = [v for k,v in doc_term_freqs.items() if k in query] 
    
    return [
        len(query_terms),
        sum(idf),
        max([0] + idf),
        (sum(idf) / max(len(idf),1)),
        sum(doc_term_freqs.values()),
        len(terms_doc_unique),
        sum(terms_doc_unique),
        max([0] + terms_doc_unique),
        (sum(terms_doc_unique) / max(len(query.keys()),1))
    ]

# %%
def ltr_feature_vectors(es, training_queries, k=200, index=INDEX_NAME):
    """
    LTR model, generates the feature vectors X and the 
    relevance labels y.
    
    Relevancy scores are defined as:
        0 = Not relevant
        1 = Partially relevant
        2 = Relevant
    
    Arguments:
        es: Elasticsearch object instance.
        k: How many documents to be retrieved from elasticsearch.
        training_queries: training queries.
        index: Name of the index with respect to which the query is analyzed.  
    
    Returns:
        Returns a list of feature vectors, a list of their respective labels (relevance) and a list of 
        instances (type instances) noted from every retrieved doc.
    """
    progress, N = 0, len(training_queries)
    X=[]
    y=[] 
    instances = []
    type_hierarchy, _ = load_type_hierarchy("evaluation\dbpedia\dbpedia_types.tsv")

    for query_id, query_features in training_queries.items():
        type_relevancy = {}        
        for typ in query_features['type']:
            if not typ in type_hierarchy:
                continue
            hierarchy = get_type_path(typ, type_hierarchy)[::-1]
            for v in hierarchy:
                type_relevancy[v] = 1 # Relevant, its in the same hierarchy but in a diff pos.            
                
        for typ in query_features['type']:
            type_relevancy[typ] = 2 # This is the type we want. Give it the highest weight.
            
        if len(type_relevancy) == 0:
            continue

        query = query_features['query_terms']
        if len(query) == 0:
            continue
        hits = es.search(index=index, _source=True, size=k, 
           query = {"bool": {"must": {"match": {"abstract": ' '.join(query)}}, 
           "must_not": {"match": {"instance": "owl:Thing"}}}}
        )['hits']['hits']

        for hit in hits:
            X.append(extract_features(query, hit['_id'], es, index))
            relevancy = 0 # Default = not relevant
            instance_type = hit['_source']['instance']
            if instance_type in type_relevancy:
                relevancy = type_relevancy[instance_type]
            elif instance_type in type_hierarchy:                
                relevancy = get_type_path(instance_type, type_hierarchy)[::-1]
                relevancy = max([(1 if (t in type_relevancy) else 0) for t in relevancy] + [0])
            y.append(relevancy)
            instances.append(instance_type)

        progress += 1
        print(
            "Processing query {}/{} ID {}".format(
                progress, len(training_queries), query_id
            )
        )
        if progress==N:
            break

    return X, y

# %%
def ltr_predict(es, test_queries, model, k=100, index=INDEX_NAME):
    """
    Predicts the category types for test queries. 
    Re-ranks the first k documents from elasticsearch.
    
    Args:
        es: Elasticsearch object instance.
        model: L2R classifier.
        k: How many documents to be retrieved from elasticsearch.
        index: Name of the index with respect to which the query is analyzed.  
    
    Returns:
        A dictionary containing the query_ids and the top 10 predicted types.
    """
    progress, N = 0, len(test_queries)
    results = {}
    for query_id, query_features in test_queries.items():
        query = query_features['query_terms']
        hits = es.search(index=index, _source=True, size=k, 
            query = {"bool": {"must": {"match": {"abstract": ' '.join(query)}}, "must_not": {"match": {"instance": "owl:Thing"}}}}
        )['hits']['hits']
        feat_vecs, instances = [], []
        for hit in hits:
            feat_vecs.append(extract_features(query, hit['_id'], es, index))
            instances.append(hit['_source']['instance'])
        if len(instances) == 0: # No hits!
            results[query_id] = 'N/A'
            continue
        instances_rerank = [instances[idx] for idx in np.argsort(model.predict(feat_vecs))[::-1]]
        results[query_id] = [x[0] for x in Counter(instances_rerank).most_common(10)]

        progress += 1
        print(
            "Processing query {}/{} ID {}".format(
                progress, len(test_queries), query_id
            )
        )

    return results

# %%
from sklearn.ensemble import RandomForestClassifier
l2r_model = RandomForestClassifier(n_estimators = 100)
X, y = ltr_feature_vectors(es, training_queries, k=10, index=INDEX_NAME)
l2r_model.fit(X, y)
# Out:
# Loading type hierarchy from evaluation\dbpedia\dbpedia_types.tsv... 761 types loaded (max depth: 7)
# Processing query 1/9573 ID dbpedia_14427
# Processing query 2/9573 ID dbpedia_3681
# Processing query 3/9573 ID dbpedia_12020
# Processing query 4/9573 ID dbpedia_10315
# Processing query 5/9573 ID dbpedia_1335
# Processing query 6/9573 ID dbpedia_6016
# Processing query 7/9573 ID dbpedia_3432
# Processing query 8/9573 ID dbpedia_16006
# Processing query 9/9573 ID dbpedia_278
# Processing query 10/9573 ID dbpedia_7661
# Processing query 11/9573 ID dbpedia_11196
# Processing query 12/9573 ID dbpedia_9060
# Processing query 13/9573 ID dbpedia_14631
# Processing query 14/9573 ID dbpedia_6019
# Processing query 15/9573 ID dbpedia_21638
# Processing query 16/9573 ID dbpedia_4600
# Processing query 17/9573 ID dbpedia_20525
# Processing query 18/9573 ID dbpedia_22649
# Processing query 19/9573 ID dbpedia_14877
# Processing query 20/9573 ID dbpedia_22706
# Processing query 21/9573 ID dbpedia_20349
# Processing query 22/9573 ID dbpedia_5165
# Processing query 23/9573 ID dbpedia_16157
# Processing query 24/9573 ID dbpedia_10722
# Processing query 25/9573 ID dbpedia_3860
# Processing query 26/9573 ID dbpedia_6003
# Processing query 27/9573 ID dbpedia_8347
# Processing query 28/9573 ID dbpedia_7283
# Processing query 29/9573 ID dbpedia_6797
# Processing query 30/9573 ID dbpedia_4735
# Processing query 31/9573 ID dbpedia_8989
# Processing query 32/9573 ID dbpedia_378
# Processing query 33/9573 ID dbpedia_21199
# Processing query 34/9573 ID dbpedia_9088
# Processing query 35/9573 ID dbpedia_13222
# Processing query 36/9573 ID dbpedia_16208
# Processing query 37/9573 ID dbpedia_5351
# Processing query 38/9573 ID dbpedia_4947
# Processing query 39/9573 ID dbpedia_4069
# Processing query 40/9573 ID dbpedia_4908
# Processing query 41/9573 ID dbpedia_21148
# Processing query 42/9573 ID dbpedia_12607
# Processing query 43/9573 ID dbpedia_14616
# Processing query 44/9573 ID dbpedia_3912
# Processing query 45/9573 ID dbpedia_23314
# Processing query 46/9573 ID dbpedia_19823
# Processing query 47/9573 ID dbpedia_21397
# Processing query 48/9573 ID dbpedia_3191
# Processing query 49/9573 ID dbpedia_18563
# Processing query 50/9573 ID dbpedia_19114
# Processing query 51/9573 ID dbpedia_13642
# Processing query 52/9573 ID dbpedia_20239
# Processing query 53/9573 ID dbpedia_20570
# Processing query 54/9573 ID dbpedia_17323
# Processing query 55/9573 ID dbpedia_12220
# Processing query 56/9573 ID dbpedia_13314
# Processing query 57/9573 ID dbpedia_3047
# Processing query 58/9573 ID dbpedia_9126
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2540/2562 ID dbpedia_6815
# Processing query 2541/2562 ID dbpedia_12383
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2542/2562 ID dbpedia_14699
# Processing query 2543/2562 ID dbpedia_13029
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2544/2562 ID dbpedia_2109
# Processing query 2545/2562 ID dbpedia_23468
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2546/2562 ID dbpedia_10362
# Processing query 2547/2562 ID dbpedia_4754
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2548/2562 ID dbpedia_15745
# Processing query 2549/2562 ID dbpedia_19032
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2550/2562 ID dbpedia_20637
# Processing query 2551/2562 ID dbpedia_23028
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2552/2562 ID dbpedia_1028
# Processing query 2553/2562 ID dbpedia_6821
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2554/2562 ID dbpedia_17315
# Processing query 2555/2562 ID dbpedia_6674
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2556/2562 ID dbpedia_10043
# Processing query 2557/2562 ID dbpedia_19889
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2558/2562 ID dbpedia_7928
# Processing query 2559/2562 ID dbpedia_22949
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2560/2562 ID dbpedia_8479
# Processing query 2561/2562 ID dbpedia_4571
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\Users\bruna\anaconda3\envs\dat640\lib\site-packages\elasticsearch\connection\base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Processing query 2562/2562 ID dbpedia_21070

# %%
test_advanced_pointwise
# Out:
# {'dbpedia_7955': ['dbo:Language',
#   'dbo:ProgrammingLanguage',
#   'dbo:AdministrativeRegion',
#   'dbo:Island',
#   'dbo:Organisation',
#   'dbo:Band',
#   'dbo:EthnicGroup',
#   'dbo:Country',
#   'dbo:Food',
#   'dbo:Writer'],
#  'dbpedia_22599': ['dbo:MilitaryConflict',
#   'dbo:MilitaryUnit',
#   'dbo:OfficeHolder',
#   'dbo:MilitaryPerson',
#   'dbo:Royalty',
#   'dbo:Settlement',
#   'dbo:AdministrativeRegion',
#   'dbo:Language',
#   'dbo:Sport',
#   'dbo:Building'],
#  'dbpedia_19677': ['dbo:Settlement',
#   'dbo:MountainRange',
#   'dbo:Island',
#   'dbo:Constellation',
#   'dbo:Mountain',
#   'dbo:Person',
#   'dbo:AdministrativeRegion',
#   'dbo:Scientist',
#   'dbo:Award',
#   'dbo:Place'],
#  'dbpedia_11163': ['dbo:City',
#   'dbo:PoliticalParty',
#   'dbo:Country',
#   'dbo:AdministrativeRegion',
#   'dbo:Settlement',
#   'dbo:Venue',
#   'dbo:Language',
#   'dbo:Person',
#   'dbo:ArtificialSatellite'],
#  'dbpedia_18792': ['dbo:EthnicGroup',
#   'dbo:Language',
#   'dbo:Person',
#   'dbo:Monument',
#   'dbo:Disease',
#   'dbo:Island',
#   'dbo:Film',
#   'dbo:City',
#   'dbo:Game',
#   'dbo:Sport'],
#  'dbpedia_11251': ['dbo:BaseballTeam',
#   'dbo:AmericanFootballTeam',
#   'dbo:Award',
#   'dbo:SoccerClub',
#   'dbo:University',
#   'dbo:AmericanFootballLeague',
#   'dbo:Sport'],
#  'dbpedia_17993': ['dbo:Person',
#   'dbo:Film',
#   'dbo:SoccerManager',
#   'dbo:MusicalArtist',
#   'dbo:CollegeCoach',
#   'dbo:OfficeHolder',
#   'dbo:Writer',
#   'dbo:SoccerClub',
#   'dbo:MilitaryPerson',
#   'dbo:TelevisionShow'],
#  'dbpedia_20546': ['dbo:PoliticalParty',
#   'dbo:OfficeHolder',
#   'dbo:Politician',
#   'dbo:FictionalCharacter',
#   'dbo:PrimeMinister',
#   'dbo:City',
#   'dbo:Settlement'],
#  'dbpedia_17589': ['dbo:Person',
#   'dbo:Writer',
#   'dbo:MusicGenre',
#   'dbo:OfficeHolder',
#   'dbo:VideoGame',
#   'dbo:Band',
#   'dbo:RadioStation',
#   'dbo:Game',
#   'dbo:MusicalArtist'],
#  'dbpedia_10307': ['dbo:Company',
#   'dbo:Person',
#   'dbo:Software',
#   'dbo:Organisation',
#   'dbo:InformationAppliance'],
#  'dbpedia_15502': ['dbo:Scientist',
#   'dbo:Writer',
#   'dbo:ProgrammingLanguage',
#   'dbo:Sport',
#   'dbo:Language',
#   'dbo:VideoGame',
#   'dbo:Person',
#   'dbo:InformationAppliance',
#   'dbo:Disease',
#   'dbo:Organisation'],
#  'dbpedia_2096': ['dbo:City',
#   'dbo:Person',
#   'dbo:Game',
#   'dbo:Sport',
#   'dbo:Company',
#   'dbo:Scientist',
#   'dbo:Religious',
#   'dbo:Language',
#   'dbo:Monarch',
#   'dbo:Airline'],
#  'dbpedia_15898': ['dbo:ProgrammingLanguage',
#   'dbo:Scientist',
#   'dbo:Organisation',
#   'dbo:InformationAppliance',
#   'dbo:Disease',
#   'dbo:Software',
#   'dbo:Language'],
#  'dbpedia_18447': ['dbo:Country',
#   'dbo:Writer',
#   'dbo:Scientist',
#   'dbo:GovernmentAgency',
#   'dbo:Person',
#   'dbo:InformationAppliance',
#   'dbo:Film',
#   'dbo:Island',
#   'dbo:Artist'],
#  'dbpedia_21857': ['dbo:River',
#   'dbo:Settlement',
#   'dbo:Town',
#   'dbo:Disease',
#   'dbo:Organisation',
#   'dbo:Royalty',
#   'dbo:AdministrativeRegion',
#   'dbo:Language',
#   'dbo:Sport',
#   'dbo:Writer'],
#  'dbpedia_17145': ['dbo:Royalty',
#   'dbo:Monarch',
#   'dbo:MusicalArtist',
#   'dbo:Person',
#   'dbo:TelevisionShow',
#   'dbo:Album',
#   'dbo:InformationAppliance',
#   'dbo:Scientist',
#   'dbo:Beverage',
#   'dbo:ChristianBishop'],
#  'dbpedia_20450': ['dbo:Sport',
#   'dbo:Person',
#   'dbo:TelevisionShow',
#   'dbo:MusicalArtist',
#   'dbo:Company',
#   'dbo:Organisation',
#   'dbo:SoccerClub',
#   'dbo:MusicGenre',
#   'dbo:Airline',
#   'dbo:RadioStation'],
#  'dbpedia_18827': ['dbo:TelevisionShow',
#   'dbo:Person',
#   'dbo:Company',
#   'dbo:MusicalArtist',
#   'dbo:Writer',
#   'dbo:TelevisionStation'],
#  'dbpedia_6724': ['dbo:Person',
#   'dbo:Writer',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:OfficeHolder',
#   'dbo:Journalist',
#   'dbo:Aircraft',
#   'dbo:Mountain',
#   'dbo:MilitaryPerson',
#   'dbo:Film'],
#  'dbpedia_17542': ['dbo:Royalty',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Company',
#   'dbo:Monarch',
#   'dbo:Writer',
#   'dbo:Weapon',
#   'dbo:Organisation',
#   'dbo:Disease'],
#  'dbpedia_7166': ['dbo:Settlement',
#   'dbo:City',
#   'dbo:SoccerClub',
#   'dbo:AdministrativeRegion',
#   'dbo:MilitaryConflict',
#   'dbo:Mountain',
#   'dbo:RadioStation',
#   'dbo:Island',
#   'dbo:Holiday',
#   'dbo:Royalty'],
#  'dbpedia_15701': ['dbo:Settlement',
#   'dbo:University',
#   'dbo:City',
#   'dbo:Town',
#   'dbo:Mountain',
#   'dbo:Country',
#   'dbo:MilitaryConflict',
#   'dbo:ProgrammingLanguage',
#   'dbo:Writer',
#   'dbo:ArtificialSatellite'],
#  'dbpedia_2904': ['dbo:Person',
#   'dbo:Mineral',
#   'dbo:BaseballTeam',
#   'dbo:Company',
#   'dbo:Scientist',
#   'dbo:Game',
#   'dbo:RugbyClub',
#   'dbo:Organisation',
#   'dbo:University',
#   'dbo:Disease'],
#  'dbpedia_13035': ['dbo:Plant',
#   'dbo:EthnicGroup',
#   'dbo:Book',
#   'dbo:Constellation',
#   'dbo:Organisation',
#   'dbo:Software',
#   'dbo:GovernmentAgency',
#   'dbo:Museum',
#   'dbo:Film',
#   'dbo:MilitaryUnit'],
#  'dbpedia_3743': ['dbo:Royalty',
#   'dbo:Person',
#   'dbo:Settlement',
#   'dbo:MilitaryConflict',
#   'dbo:FictionalCharacter',
#   'dbo:Bird',
#   'dbo:Fish',
#   'dbo:Building',
#   'dbo:Constellation',
#   'dbo:Film'],
#  'dbpedia_11441': ['dbo:Plant',
#   'dbo:EthnicGroup',
#   'dbo:Person',
#   'dbo:Constellation',
#   'dbo:Company',
#   'dbo:Organisation',
#   'dbo:Software',
#   'dbo:Band',
#   'dbo:Film',
#   'dbo:Book'],
#  'dbpedia_2169': ['dbo:Writer',
#   'dbo:EthnicGroup',
#   'dbo:Film',
#   'dbo:Organisation',
#   'dbo:Band',
#   'dbo:Bird',
#   'dbo:Scientist',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:Mammal'],
#  'dbpedia_8309': ['dbo:ChemicalCompound',
#   'dbo:Scientist',
#   'dbo:Writer',
#   'dbo:MilitaryUnit',
#   'dbo:Royalty',
#   'dbo:Award',
#   'dbo:Philosopher',
#   'dbo:University',
#   'dbo:Person',
#   'dbo:Book'],
#  'dbpedia_14696': ['dbo:PoliticalParty',
#   'dbo:OfficeHolder',
#   'dbo:Politician',
#   'dbo:MilitaryConflict',
#   'dbo:Bird',
#   'dbo:PrimeMinister',
#   'dbo:ConcentrationCamp',
#   'dbo:AmericanFootballTeam',
#   'dbo:Medician',
#   'dbo:President'],
#  'dbpedia_20621': ['dbo:River',
#   'dbo:Town',
#   'dbo:Settlement',
#   'dbo:WorldHeritageSite',
#   'dbo:MilitaryUnit',
#   'dbo:Country',
#   'dbo:InformationAppliance',
#   'dbo:ArtificialSatellite',
#   'dbo:RadioStation',
#   'dbo:ChemicalCompound'],
#  'dbpedia_13081': ['dbo:Artist',
#   'dbo:Royalty',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:Disease',
#   'dbo:Painter',
#   'dbo:MusicalArtist',
#   'dbo:AmericanFootballTeam',
#   'dbo:Mineral',
#   'dbo:Mammal'],
#  'dbpedia_11342': ['dbo:Disease',
#   'dbo:Language',
#   'dbo:ProgrammingLanguage',
#   'dbo:Software',
#   'dbo:Person',
#   'dbo:Saint',
#   'dbo:Species',
#   'dbo:Settlement',
#   'dbo:Writer',
#   'dbo:OfficeHolder'],
#  'dbpedia_1610': ['dbo:OfficeHolder',
#   'dbo:Scientist',
#   'dbo:PoliticalParty',
#   'dbo:Writer',
#   'dbo:Election',
#   'dbo:Royalty',
#   'dbo:RugbyClub',
#   'dbo:Award',
#   'dbo:Politician',
#   'dbo:Disease'],
#  'dbpedia_5531': ['dbo:InformationAppliance',
#   'dbo:Weapon',
#   'dbo:Island',
#   'dbo:Band',
#   'dbo:Person',
#   'dbo:Language',
#   'dbo:TelevisionShow',
#   'dbo:Aircraft',
#   'dbo:AdministrativeRegion',
#   'dbo:MilitaryConflict'],
#  'dbpedia_22145': ['dbo:Royalty',
#   'dbo:Company',
#   'dbo:BaseballTeam',
#   'dbo:VideoGame',
#   'dbo:Religious',
#   'dbo:Fish',
#   'dbo:Sport',
#   'dbo:FormulaOneTeam',
#   'dbo:Award',
#   'dbo:AmericanFootballTeam'],
#  'dbpedia_5991': ['dbo:AnatomicalStructure',
#   'dbo:Settlement',
#   'dbo:City',
#   'dbo:Disease',
#   'dbo:Place',
#   'dbo:Sea',
#   'dbo:InformationAppliance',
#   'dbo:Band',
#   'dbo:Town',
#   'dbo:Lake'],
#  'dbpedia_9328': ['dbo:Royalty',
#   'dbo:Scientist',
#   'dbo:Settlement',
#   'dbo:Election',
#   'dbo:River',
#   'dbo:Saint',
#   'dbo:Monarch',
#   'dbo:Town',
#   'dbo:Film',
#   'dbo:Person'],
#  'dbpedia_17597': ['dbo:MilitaryUnit',
#   'dbo:MusicalArtist',
#   'dbo:Royalty',
#   'dbo:AmericanFootballTeam',
#   'dbo:OfficeHolder',
#   'dbo:InformationAppliance',
#   'dbo:Person',
#   'dbo:EthnicGroup',
#   'dbo:AmericanFootballPlayer',
#   'dbo:Anime'],
#  'dbpedia_21999': ['dbo:River',
#   'dbo:Fish',
#   'dbo:Bird',
#   'dbo:Town',
#   'dbo:Building',
#   'dbo:Settlement',
#   'dbo:Artist',
#   'dbo:Constellation',
#   'dbo:Person',
#   'dbo:TelevisionShow'],
#  'dbpedia_12376': ['dbo:Person'],
#  'dbpedia_18496': ['dbo:Album',
#   'dbo:Band',
#   'dbo:Person',
#   'dbo:AcademicJournal',
#   'dbo:ChemicalCompound',
#   'dbo:AnatomicalStructure',
#   'dbo:Scientist',
#   'dbo:Drug',
#   'dbo:Star',
#   'dbo:Disease'],
#  'dbpedia_19727': ['dbo:University',
#   'dbo:Scientist',
#   'dbo:Writer',
#   'dbo:City',
#   'dbo:MilitaryUnit',
#   'dbo:Person',
#   'dbo:Place',
#   'dbo:Aircraft',
#   'dbo:Company'],
#  'dbpedia_20944': ['dbo:AmericanFootballTeam',
#   'dbo:BaseballTeam',
#   'dbo:Sport',
#   'dbo:Game',
#   'dbo:InformationAppliance',
#   'dbo:VideoGame',
#   'dbo:Company',
#   'dbo:SoccerClub'],
#  'dbpedia_20180': ['dbo:Book',
#   'dbo:Writer',
#   'dbo:MusicalArtist',
#   'dbo:ComicsCharacter',
#   'dbo:Artist',
#   'dbo:Musical',
#   'dbo:Company',
#   'dbo:Saint',
#   'dbo:Award',
#   'dbo:Person'],
#  'dbpedia_8843': ['dbo:Person',
#   'dbo:Writer',
#   'dbo:Award',
#   'dbo:Scientist',
#   'dbo:Anime',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:AmericanFootballTeam',
#   'dbo:Band'],
#  'dbpedia_16217': ['dbo:City',
#   'dbo:Settlement',
#   'dbo:AdministrativeRegion',
#   'dbo:Building',
#   'dbo:Saint',
#   'dbo:Lake',
#   'dbo:Country',
#   'dbo:Writer',
#   'dbo:Island',
#   'dbo:BaseballTeam'],
#  'dbpedia_10394': ['dbo:Organisation',
#   'dbo:City',
#   'dbo:Constellation',
#   'dbo:Royalty',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Island',
#   'dbo:Philosopher',
#   'dbo:AnatomicalStructure'],
#  'dbpedia_20499': ['dbo:Writer',
#   'dbo:Constellation',
#   'dbo:Book',
#   'dbo:Fish',
#   'dbo:Bird',
#   'dbo:Building',
#   'dbo:Company',
#   'dbo:Legislature',
#   'dbo:MusicalArtist',
#   'dbo:Person'],
#  'dbpedia_1201': ['dbo:Constellation',
#   'dbo:Plant',
#   'dbo:Island',
#   'dbo:MilitaryPerson',
#   'dbo:Software',
#   'dbo:WorldHeritageSite',
#   'dbo:Film',
#   'dbo:GovernmentAgency',
#   'dbo:Game',
#   'dbo:Person'],
#  'dbpedia_18580': ['dbo:FictionalCharacter',
#   'dbo:Writer',
#   'dbo:Person',
#   'dbo:ComicsCharacter',
#   'dbo:Company',
#   'dbo:TelevisionShow',
#   'dbo:Monarch',
#   'dbo:Game',
#   'dbo:Film',
#   'dbo:Language'],
#  'dbpedia_3527': ['dbo:Building',
#   'dbo:Constellation',
#   'dbo:Star',
#   'dbo:Bird',
#   'dbo:Fish',
#   'dbo:Sport',
#   'dbo:Saint',
#   'dbo:Legislature',
#   'dbo:Book',
#   'dbo:Company'],
#  'dbpedia_15115': ['dbo:University',
#   'dbo:Organisation',
#   'dbo:City',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:Band',
#   'dbo:AmericanFootballTeam',
#   'dbo:AnatomicalStructure',
#   'dbo:OfficeHolder',
#   'dbo:President'],
#  'dbpedia_4528': ['dbo:Album',
#   'dbo:Company',
#   'dbo:Band',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:Book',
#   'dbo:InformationAppliance',
#   'dbo:MusicalArtist',
#   'dbo:Film',
#   'dbo:Organisation'],
#  'dbpedia_6357': ['dbo:Philosopher',
#   'dbo:Writer',
#   'dbo:Royalty',
#   'dbo:Person',
#   'dbo:Saint',
#   'dbo:AdministrativeRegion',
#   'dbo:Scientist',
#   'dbo:Disease',
#   'dbo:Economist',
#   'dbo:Planet'],
#  'dbpedia_12974': ['dbo:River',
#   'dbo:Island',
#   'dbo:Country',
#   'dbo:AdministrativeRegion',
#   'dbo:City',
#   'dbo:Settlement'],
#  'dbpedia_9367': ['dbo:River',
#   'dbo:Airline',
#   'dbo:Person',
#   'dbo:Weapon',
#   'dbo:Constellation',
#   'dbo:AdministrativeRegion',
#   'dbo:BodyOfWater',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Lake'],
#  'dbpedia_18939': ['dbo:Company',
#   'dbo:Scientist',
#   'dbo:Writer',
#   'dbo:Book',
#   'dbo:Monument',
#   'dbo:Monarch',
#   'dbo:Convention',
#   'dbo:SoccerClub',
#   'dbo:FormulaOneTeam',
#   'dbo:Person'],
#  'dbpedia_23201': ['dbo:Royalty',
#   'dbo:Disease',
#   'dbo:Saint',
#   'dbo:Species',
#   'dbo:Scientist',
#   'dbo:Mineral',
#   'dbo:Fish',
#   'dbo:Anime',
#   'dbo:Writer',
#   'dbo:Person'],
#  'dbpedia_6892': ['dbo:Royalty',
#   'dbo:Band',
#   'dbo:City',
#   'dbo:Mineral',
#   'dbo:Person',
#   'dbo:Star',
#   'dbo:Disease',
#   'dbo:Scientist',
#   'dbo:Monarch',
#   'dbo:MusicalArtist'],
#  'dbpedia_8002': ['dbo:Organisation',
#   'dbo:Settlement',
#   'dbo:Country',
#   'dbo:City',
#   'dbo:Artery',
#   'dbo:Language',
#   'dbo:Legislature',
#   'dbo:MilitaryConflict',
#   'dbo:PoliticalParty',
#   'dbo:ChemicalCompound'],
#  'dbpedia_18653': ['dbo:TelevisionShow',
#   'dbo:Person',
#   'dbo:OfficeHolder',
#   'dbo:Organisation',
#   'dbo:Band',
#   'dbo:TelevisionStation',
#   'dbo:Writer',
#   'dbo:Game',
#   'dbo:MilitaryUnit'],
#  'dbpedia_13276': ['dbo:Person',
#   'dbo:Disease',
#   'dbo:Royalty',
#   'dbo:SoccerManager',
#   'dbo:MusicalArtist',
#   'dbo:CollegeCoach',
#   'dbo:OfficeHolder',
#   'dbo:Saint',
#   'dbo:Species',
#   'dbo:MilitaryPerson'],
#  'dbpedia_4897': ['dbo:Company',
#   'dbo:Film',
#   'dbo:Person',
#   'dbo:Royalty',
#   'dbo:Beverage',
#   'dbo:AnatomicalStructure',
#   'dbo:Legislature',
#   'dbo:MilitaryUnit',
#   'dbo:Software',
#   'dbo:MusicalArtist'],
#  'dbpedia_21184': ['dbo:Disease', 'dbo:Person'],
#  'dbpedia_5424': ['dbo:AmericanFootballTeam',
#   'dbo:ChristianBishop',
#   'dbo:Settlement',
#   'dbo:Writer',
#   'dbo:Constellation',
#   'dbo:Island',
#   'dbo:Saint',
#   'dbo:Museum',
#   'dbo:Bird',
#   'dbo:Country'],
#  'dbpedia_12705': ['dbo:Scientist',
#   'dbo:Writer',
#   'dbo:Person',
#   'dbo:Book',
#   'dbo:Artist',
#   'dbo:Holiday',
#   'dbo:MusicalArtist',
#   'dbo:Award',
#   'dbo:Newspaper',
#   'dbo:Philosopher'],
#  'dbpedia_3240': ['dbo:Game',
#   'dbo:Crustacean',
#   'dbo:GreenAlga',
#   'dbo:Ship',
#   'dbo:Mountain',
#   'dbo:MountainRange',
#   'dbo:Philosopher',
#   'dbo:Enzyme',
#   'dbo:TelevisionShow',
#   'dbo:ChemicalCompound'],
#  'dbpedia_5736': ['dbo:ArtificialSatellite',
#   'dbo:Writer',
#   'dbo:Star',
#   'dbo:Scientist',
#   'dbo:Disease',
#   'dbo:InformationAppliance',
#   'dbo:Continent',
#   'dbo:Ship',
#   'dbo:Band',
#   'dbo:ChemicalCompound'],
#  'dbpedia_183': ['dbo:Country',
#   'dbo:City',
#   'dbo:Settlement',
#   'dbo:AdministrativeRegion',
#   'dbo:OfficeHolder',
#   'dbo:MilitaryUnit',
#   'dbo:PoliticalParty',
#   'dbo:Bird',
#   'dbo:AmericanFootballTeam',
#   'dbo:Island'],
#  'dbpedia_19905': ['dbo:Settlement',
#   'dbo:Island',
#   'dbo:MountainRange',
#   'dbo:Country',
#   'dbo:AmericanFootballPlayer',
#   'dbo:Person',
#   'dbo:Mountain',
#   'dbo:AdministrativeRegion',
#   'dbo:Rocket',
#   'dbo:Sport'],
#  'dbpedia_22987': ['dbo:Person',
#   'dbo:Writer',
#   'dbo:AmericanFootballPlayer',
#   'dbo:Company',
#   'dbo:MilitaryUnit',
#   'dbo:Island',
#   'dbo:Scientist',
#   'dbo:ComicsCharacter',
#   'dbo:Royalty',
#   'dbo:Settlement'],
#  'dbpedia_19549': ['dbo:AmericanFootballTeam',
#   'dbo:SoccerClub',
#   'dbo:Sport',
#   'dbo:BaseballTeam',
#   'dbo:AmericanFootballLeague',
#   'dbo:AmericanFootballPlayer',
#   'dbo:Settlement',
#   'dbo:AustralianFootballTeam',
#   'dbo:RugbyClub'],
#  'dbpedia_8646': ['dbo:Disease',
#   'dbo:Drug',
#   'dbo:Writer',
#   'dbo:GovernmentAgency',
#   'dbo:Plant',
#   'dbo:Species',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Person',
#   'dbo:Island'],
#  'dbpedia_1673': ['dbo:AnatomicalStructure',
#   'dbo:Disease',
#   'dbo:ChemicalCompound',
#   'dbo:Eukaryote',
#   'dbo:Plant',
#   'dbo:Drug',
#   'dbo:Enzyme',
#   'dbo:Person',
#   'dbo:Animal'],
#  'dbpedia_18238': ['dbo:TelevisionShow',
#   'dbo:Person',
#   'dbo:Film',
#   'dbo:Museum',
#   'dbo:Book',
#   'dbo:Software',
#   'dbo:Writer',
#   'dbo:Scientist',
#   'dbo:Disease',
#   'dbo:InformationAppliance'],
#  'dbpedia_14411': ['dbo:Royalty',
#   'dbo:Monarch',
#   'dbo:Settlement',
#   'dbo:Weapon',
#   'dbo:MusicalArtist',
#   'dbo:Person',
#   'dbo:Saint',
#   'dbo:MilitaryConflict',
#   'dbo:AdministrativeRegion',
#   'dbo:Airport'],
#  'dbpedia_8652': ['dbo:Film', 'dbo:Person', 'dbo:Royalty'],
#  'dbpedia_15760': ['dbo:Company',
#   'dbo:Game',
#   'dbo:Writer',
#   'dbo:AcademicJournal',
#   'dbo:Book',
#   'dbo:ComicsCharacter',
#   'dbo:Comic',
#   'dbo:ProgrammingLanguage',
#   'dbo:PoliticalParty',
#   'dbo:Scientist'],
#  'dbpedia_9621': ['dbo:Organisation',
#   'dbo:GovernmentAgency',
#   'dbo:InformationAppliance',
#   'dbo:AcademicJournal',
#   'dbo:Mineral',
#   'dbo:Bird',
#   'dbo:Sport',
#   'dbo:Airline',
#   'dbo:MilitaryUnit',
#   'dbo:Building'],
#  'dbpedia_3066': ['dbo:Language',
#   'dbo:Country',
#   'dbo:Writer',
#   'dbo:Saint',
#   'dbo:Person',
#   'dbo:Food',
#   'dbo:AdministrativeRegion',
#   'dbo:Software',
#   'dbo:Organisation',
#   'dbo:ChristianBishop'],
#  'dbpedia_10108': ['dbo:Scientist',
#   'dbo:Band',
#   'dbo:Book',
#   'dbo:Disease',
#   'dbo:Organisation',
#   'dbo:Writer',
#   'dbo:Philosopher',
#   'dbo:Album',
#   'dbo:ChemicalCompound',
#   'dbo:Saint'],
#  'dbpedia_11951': ['dbo:Band',
#   'dbo:City',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:Album',
#   'dbo:AmericanFootballTeam',
#   'dbo:Bacteria',
#   'dbo:Settlement',
#   'dbo:ChristianBishop',
#   'dbo:Building'],
#  'dbpedia_3529': ['dbo:Royalty',
#   'dbo:Philosopher',
#   'dbo:Monarch',
#   'dbo:Film',
#   'dbo:Saint',
#   'dbo:Disease',
#   'dbo:MusicalArtist',
#   'dbo:Person',
#   'dbo:Mineral',
#   'dbo:AdministrativeRegion'],
#  'dbpedia_12827': ['dbo:Constellation',
#   'dbo:Person',
#   'dbo:MilitaryPerson',
#   'dbo:InformationAppliance',
#   'dbo:Mineral',
#   'dbo:MusicalArtist',
#   'dbo:Plant',
#   'dbo:Software',
#   'dbo:Royalty',
#   'dbo:Film'],
#  'dbpedia_2452': ['dbo:ProgrammingLanguage',
#   'dbo:InformationAppliance',
#   'dbo:Person'],
#  'dbpedia_19213': ['dbo:PoliticalParty',
#   'dbo:OfficeHolder',
#   'dbo:Politician',
#   'dbo:FictionalCharacter',
#   'dbo:Settlement',
#   'dbo:PrimeMinister',
#   'dbo:Person'],
#  'dbpedia_23102': ['dbo:Company',
#   'dbo:Scientist',
#   'dbo:Settlement',
#   'dbo:ChristianBishop',
#   'dbo:Museum',
#   'dbo:Band',
#   'dbo:Disease',
#   'dbo:InformationAppliance',
#   'dbo:Aircraft',
#   'dbo:TelevisionStation'],
#  'dbpedia_20082': ['dbo:Sport',
#   'dbo:AmericanFootballTeam',
#   'dbo:BaseballTeam',
#   'dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:ProgrammingLanguage',
#   'dbo:FormulaOneTeam',
#   'dbo:Band'],
#  'dbpedia_15307': ['dbo:Person',
#   'dbo:SoccerClub',
#   'dbo:Drug',
#   'dbo:Mineral',
#   'dbo:BaseballTeam',
#   'dbo:Company',
#   'dbo:Game',
#   'dbo:RugbyClub',
#   'dbo:Organisation',
#   'dbo:University'],
#  'dbpedia_19674': ['dbo:MilitaryConflict',
#   'dbo:Settlement',
#   'dbo:Building',
#   'dbo:Bird',
#   'dbo:FigureSkater',
#   'dbo:Organisation',
#   'dbo:TennisPlayer',
#   'dbo:Monarch',
#   'dbo:City',
#   'dbo:AdministrativeRegion'],
#  'dbpedia_3815': ['dbo:Writer',
#   'dbo:Royalty',
#   'dbo:ArtificialSatellite',
#   'dbo:Aircraft',
#   'dbo:ComicsCharacter',
#   'dbo:Band',
#   'dbo:MusicalArtist',
#   'dbo:Company',
#   'dbo:Film',
#   'dbo:Award'],
#  'dbpedia_17575': ['dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:Book',
#   'dbo:Scientist',
#   'dbo:Film',
#   'dbo:SoccerManager',
#   'dbo:CollegeCoach',
#   'dbo:OfficeHolder',
#   'dbo:Holiday',
#   'dbo:MilitaryPerson'],
#  'dbpedia_19633': ['dbo:MilitaryConflict',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:Settlement',
#   'dbo:Film',
#   'dbo:InformationAppliance',
#   'dbo:Disease',
#   'dbo:Drug',
#   'dbo:Country',
#   'dbo:AdministrativeRegion'],
#  'dbpedia_14301': ['dbo:Person',
#   'dbo:BaseballTeam',
#   'dbo:Organisation',
#   'dbo:ProgrammingLanguage',
#   'dbo:Royalty',
#   'dbo:Scientist',
#   'dbo:Award',
#   'dbo:Philosopher',
#   'dbo:MusicalArtist',
#   'dbo:ArtificialSatellite'],
#  'dbpedia_21450': ['dbo:Writer',
#   'dbo:FictionalCharacter',
#   'dbo:Person',
#   'dbo:TelevisionShow',
#   'dbo:ComicsCharacter',
#   'dbo:MusicalArtist',
#   'dbo:Anime',
#   'dbo:Saint',
#   'dbo:Philosopher'],
#  'dbpedia_15086': ['dbo:Person',
#   'dbo:Scientist',
#   'dbo:Book',
#   'dbo:MusicalArtist',
#   'dbo:Award',
#   'dbo:MilitaryUnit',
#   'dbo:Disease',
#   'dbo:ArtificialSatellite',
#   'dbo:BroadcastNetwork',
#   'dbo:TelevisionShow'],
#  'dbpedia_13088': ['dbo:Organisation',
#   'dbo:Writer',
#   'dbo:Scientist',
#   'dbo:Aircraft',
#   'dbo:Band',
#   'dbo:EthnicGroup',
#   'dbo:Mammal',
#   'dbo:Newspaper',
#   'dbo:AdministrativeRegion',
#   'dbo:MilitaryConflict'],
#  'dbpedia_13022': ['dbo:Royalty',
#   'dbo:Settlement',
#   'dbo:Aircraft',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:Town',
#   'dbo:Company',
#   'dbo:Monarch',
#   'dbo:Painter',
#   'dbo:MusicalArtist'],
#  'dbpedia_7186': ['dbo:MilitaryConflict',
#   'dbo:Person',
#   'dbo:Language',
#   'dbo:Writer',
#   'dbo:Saint',
#   'dbo:Island',
#   'dbo:Royalty',
#   'dbo:Bird',
#   'dbo:Aircraft',
#   'dbo:ChristianBishop'],
#  'dbpedia_7787': ['dbo:MilitaryConflict',
#   'dbo:TennisPlayer',
#   'dbo:OfficeHolder',
#   'dbo:Company',
#   'dbo:WorldHeritageSite',
#   'dbo:Convention',
#   'dbo:Monarch',
#   'dbo:AmericanFootballTeam',
#   'dbo:Royalty',
#   'dbo:MusicalArtist'],
#  'dbpedia_9131': ['dbo:ArtificialSatellite',
#   'dbo:Building',
#   'dbo:Book',
#   'dbo:MilitaryUnit',
#   'dbo:Country',
#   'dbo:Ship',
#   'dbo:Town',
#   'dbo:Lake',
#   'dbo:Rocket',
#   'dbo:Aircraft'],
#  'dbpedia_624': ['dbo:Royalty',
#   'dbo:Person',
#   'dbo:Saint',
#   'dbo:AdministrativeRegion',
#   'dbo:Scientist',
#   'dbo:Planet',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:AmericanFootballTeam',
#   'dbo:Band'],
#  'dbpedia_22104': ['dbo:Scientist',
#   'dbo:Country',
#   'dbo:Sport',
#   'dbo:Person',
#   'dbo:FictionalCharacter',
#   'dbo:Royalty',
#   'dbo:Politician',
#   'dbo:MilitaryPerson',
#   'dbo:InformationAppliance',
#   'dbo:Disease'],
#  'dbpedia_15008': ['dbo:MilitaryConflict',
#   'dbo:InformationAppliance',
#   'dbo:Saint',
#   'dbo:Book',
#   'dbo:Settlement',
#   'dbo:Weapon',
#   'dbo:Band',
#   'dbo:Bird',
#   'dbo:Film',
#   'dbo:Monarch'],
#  'dbpedia_5033': ['dbo:Writer',
#   'dbo:Book',
#   'dbo:Band',
#   'dbo:Company',
#   'dbo:Constellation',
#   'dbo:MusicalArtist',
#   'dbo:ComicsCharacter',
#   'dbo:FictionalCharacter',
#   'dbo:Software',
#   'dbo:Musical'],
#  'dbpedia_17832': ['dbo:Person',
#   'dbo:Scientist',
#   'dbo:Royalty',
#   'dbo:Band',
#   'dbo:TelevisionShow',
#   'dbo:Philosopher',
#   'dbo:WorldHeritageSite',
#   'dbo:Religious',
#   'dbo:Writer',
#   'dbo:Monarch'],
#  'dbpedia_20589': ['dbo:Comedian',
#   'dbo:OfficeHolder',
#   'dbo:Noble',
#   'dbo:Painter',
#   'dbo:Writer',
#   'dbo:Film',
#   'dbo:Person'],
#  'dbpedia_14563': ['dbo:Company',
#   'dbo:Comic',
#   'dbo:Game',
#   'dbo:InformationAppliance',
#   'dbo:Writer',
#   'dbo:ProgrammingLanguage',
#   'dbo:Settlement',
#   'dbo:ComicsCharacter',
#   'dbo:Book',
#   'dbo:Scientist'],
#  'dbpedia_10964': ['dbo:Scientist',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:University',
#   'dbo:Band',
#   'dbo:Philosopher',
#   'dbo:Protein',
#   'dbo:Book'],
#  'dbpedia_20263': ['dbo:Person',
#   'dbo:MilitaryPerson',
#   'dbo:Film',
#   'dbo:InformationAppliance',
#   'dbo:Writer',
#   'dbo:FictionalCharacter',
#   'dbo:ChristianBishop',
#   'dbo:Royalty',
#   'dbo:Settlement',
#   'dbo:Scientist'],
#  'dbpedia_10652': ['dbo:Person',
#   'dbo:Film',
#   'dbo:Award',
#   'dbo:Album',
#   'dbo:MusicalArtist',
#   'dbo:TelevisionShow'],
#  'dbpedia_17518': ['dbo:Language',
#   'dbo:ProgrammingLanguage',
#   'dbo:Philosopher',
#   'dbo:Writer',
#   'dbo:Scientist',
#   'dbo:Organisation',
#   'dbo:EthnicGroup',
#   'dbo:Saint',
#   'dbo:Country'],
#  'dbpedia_19380': ['dbo:Person',
#   'dbo:Royalty',
#   'dbo:OfficeHolder',
#   'dbo:FictionalCharacter',
#   'dbo:VideoGame',
#   'dbo:Band',
#   'dbo:Star',
#   'dbo:Film',
#   'dbo:TelevisionShow',
#   'dbo:Scientist'],
#  'dbpedia_388': ['dbo:Scientist',
#   'dbo:Writer',
#   'dbo:MilitaryConflict',
#   'dbo:Settlement',
#   'dbo:Artist',
#   'dbo:Person',
#   'dbo:Holiday',
#   'dbo:Disease',
#   'dbo:InformationAppliance'],
#  'dbpedia_17932': ['dbo:City',
#   'dbo:Scientist',
#   'dbo:Company',
#   'dbo:Person',
#   'dbo:Organisation',
#   'dbo:Writer',
#   'dbo:University',
#   'dbo:Museum',
#   'dbo:Building',
#   'dbo:BaseballPlayer'],
#  'dbpedia_11988': ['dbo:Company',
#   'dbo:InformationAppliance',
#   'dbo:MilitaryUnit',
#   'dbo:City',
#   'dbo:Bank',
#   'dbo:Person'],
#  'dbpedia_22595': ['dbo:ProgrammingLanguage',
#   'dbo:Software',
#   'dbo:EthnicGroup',
#   'dbo:Scientist',
#   'dbo:Company'],
#  'dbpedia_12448': ['dbo:Settlement',
#   'dbo:AnatomicalStructure',
#   'dbo:Royalty',
#   'dbo:Scientist',
#   'dbo:Mountain',
#   'dbo:Holiday',
#   'dbo:Plant',
#   'dbo:Constellation',
#   'dbo:Monarch',
#   'dbo:Sport'],
#  'dbpedia_2745': ['dbo:Writer',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Disease',
#   'dbo:Island',
#   'dbo:Language'],
#  'dbpedia_5561': ['dbo:Person',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:Philosopher',
#   'dbo:Disease',
#   'dbo:Scientist',
#   'dbo:Mineral',
#   'dbo:Saint',
#   'dbo:AmericanFootballTeam',
#   'dbo:Band'],
#  'dbpedia_19930': ['dbo:Country',
#   'dbo:Settlement',
#   'dbo:Disease',
#   'dbo:Language',
#   'dbo:Painter',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Town',
#   'dbo:EthnicGroup',
#   'dbo:City'],
#  'dbpedia_4989': ['dbo:SoccerClub',
#   'dbo:Royalty',
#   'dbo:AmericanFootballTeam',
#   'dbo:Building',
#   'dbo:RugbyClub',
#   'dbo:Settlement',
#   'dbo:AustralianFootballTeam',
#   'dbo:Disease',
#   'dbo:BaseballTeam',
#   'dbo:Company'],
#  'dbpedia_21566': ['dbo:TelevisionShow',
#   'dbo:Person',
#   'dbo:Company',
#   'dbo:Writer',
#   'dbo:TelevisionStation',
#   'dbo:Newspaper',
#   'dbo:Bank',
#   'dbo:MilitaryUnit'],
#  'dbpedia_9117': ['dbo:Building',
#   'dbo:GovernmentAgency',
#   'dbo:Settlement',
#   'dbo:Organisation',
#   'dbo:Royalty',
#   'dbo:City',
#   'dbo:Company',
#   'dbo:InformationAppliance',
#   'dbo:AdministrativeRegion',
#   'dbo:Beverage'],
#  'dbpedia_18553': ['dbo:Writer',
#   'dbo:Disease',
#   'dbo:PoliticalParty',
#   'dbo:Holiday',
#   'dbo:SoccerClub',
#   'dbo:Religious',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Philosopher'],
#  'dbpedia_11474': ['dbo:FictionalCharacter',
#   'dbo:TelevisionShow',
#   'dbo:Film',
#   'dbo:Person',
#   'dbo:ComicsCharacter',
#   'dbo:Language',
#   'dbo:Book',
#   'dbo:Company',
#   'dbo:Royalty',
#   'dbo:MusicalArtist'],
#  'dbpedia_6558': ['dbo:Saint',
#   'dbo:Person',
#   'dbo:Royalty',
#   'dbo:Film',
#   'dbo:Monarch',
#   'dbo:ChristianBishop',
#   'dbo:Country',
#   'dbo:BaseballPlayer',
#   'dbo:Holiday'],
#  'dbpedia_20440': ['dbo:Island',
#   'dbo:Scientist',
#   'dbo:Writer',
#   'dbo:Constellation',
#   'dbo:Newspaper',
#   'dbo:Lake',
#   'dbo:Mollusca',
#   'dbo:Place',
#   'dbo:Settlement',
#   'dbo:Country'],
#  'dbpedia_6847': ['dbo:Settlement',
#   'dbo:ChemicalCompound',
#   'dbo:City',
#   'dbo:Building',
#   'dbo:Constellation',
#   'dbo:AdministrativeRegion',
#   'dbo:Bird',
#   'dbo:ProgrammingLanguage',
#   'dbo:MilitaryUnit',
#   'dbo:Band'],
#  'dbpedia_22037': ['dbo:Company',
#   'dbo:WorldHeritageSite',
#   'dbo:OfficeHolder',
#   'dbo:Newspaper',
#   'dbo:Scientist',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:BaseballTeam',
#   'dbo:BroadcastNetwork',
#   'dbo:Disease'],
#  'dbpedia_4801': ['dbo:Settlement',
#   'dbo:Star',
#   'dbo:Town',
#   'dbo:MilitaryConflict',
#   'dbo:OfficeHolder',
#   'dbo:Painter',
#   'dbo:AdministrativeRegion',
#   'dbo:Sport',
#   'dbo:Person'],
#  'dbpedia_4760': ['dbo:Disease',
#   'dbo:Person',
#   'dbo:Drug',
#   'dbo:Writer',
#   'dbo:Mineral',
#   'dbo:BaseballTeam',
#   'dbo:Organisation',
#   'dbo:University',
#   'dbo:Band',
#   'dbo:Scientist'],
#  'dbpedia_3519': ['dbo:Game',
#   'dbo:Book',
#   'dbo:Saint',
#   'dbo:AcademicJournal',
#   'dbo:Comic',
#   'dbo:Company',
#   'dbo:Person',
#   'dbo:Scientist'],
#  'dbpedia_18430': ['dbo:Film',
#   'dbo:Writer',
#   'dbo:InformationAppliance',
#   'dbo:Star',
#   'dbo:MilitaryConflict',
#   'dbo:Royalty',
#   'dbo:FormulaOneTeam',
#   'dbo:Scientist',
#   'dbo:Mammal',
#   'dbo:Disease'],
#  'dbpedia_6993': ['dbo:MusicGenre',
#   'dbo:Band',
#   'dbo:Writer',
#   'dbo:Musical',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:VideoGame',
#   'dbo:RadioStation',
#   'dbo:Person'],
#  'dbpedia_14516': ['dbo:Software',
#   'dbo:VideoGame',
#   'dbo:InformationAppliance',
#   'dbo:Disease',
#   'dbo:Language',
#   'dbo:TelevisionStation',
#   'dbo:River',
#   'dbo:Rocket',
#   'dbo:Weapon',
#   'dbo:Planet'],
#  'dbpedia_19117': ['dbo:Aircraft',
#   'dbo:MilitaryConflict',
#   'dbo:EthnicGroup',
#   'dbo:Monument',
#   'dbo:Artery',
#   'dbo:Island',
#   'dbo:Legislature',
#   'dbo:Scientist',
#   'dbo:AnatomicalStructure',
#   'dbo:AdministrativeRegion'],
#  'dbpedia_22787': ['dbo:Organisation',
#   'dbo:MilitaryConflict',
#   'dbo:Country',
#   'dbo:OfficeHolder',
#   'dbo:Writer',
#   'dbo:PoliticalParty',
#   'dbo:Religious',
#   'dbo:Language',
#   'dbo:Legislature',
#   'dbo:RugbyClub'],
#  'dbpedia_20306': ['dbo:Sport',
#   'dbo:Scientist',
#   'dbo:TennisPlayer',
#   'dbo:Award',
#   'dbo:AmericanFootballTeam',
#   'dbo:Person',
#   'dbo:Game',
#   'dbo:FormulaOneTeam',
#   'dbo:RugbyClub',
#   'dbo:TelevisionShow'],
#  'dbpedia_12859': ['dbo:Person',
#   'dbo:Film',
#   'dbo:Royalty',
#   'dbo:Book',
#   'dbo:Artery',
#   'dbo:OfficeHolder',
#   'dbo:MusicalArtist',
#   'dbo:Sport',
#   'dbo:Mineral',
#   'dbo:Bacteria'],
#  'dbpedia_8122': ['dbo:OfficeHolder',
#   'dbo:Organisation',
#   'dbo:City',
#   'dbo:ProgrammingLanguage',
#   'dbo:MilitaryUnit',
#   'dbo:Anime',
#   'dbo:WorldHeritageSite',
#   'dbo:Monarch',
#   'dbo:Island',
#   'dbo:Scientist'],
#  'dbpedia_2457': ['dbo:Organisation',
#   'dbo:Company',
#   'dbo:AmericanFootballTeam',
#   'dbo:City',
#   'dbo:GovernmentAgency',
#   'dbo:Building',
#   'dbo:BaseballTeam',
#   'dbo:AnatomicalStructure',
#   'dbo:Island'],
#  'dbpedia_14045': ['dbo:City',
#   'dbo:Settlement',
#   'dbo:Royalty',
#   'dbo:Monarch',
#   'dbo:Weapon',
#   'dbo:MilitaryConflict',
#   'dbo:AdministrativeRegion',
#   'dbo:Person',
#   'dbo:Tunnel'],
#  'dbpedia_18296': ['dbo:VideoGame',
#   'dbo:Constellation',
#   'dbo:Fish',
#   'dbo:Bird',
#   'dbo:Building',
#   'dbo:InformationAppliance',
#   'dbo:ProgrammingLanguage',
#   'dbo:Poem',
#   'dbo:Legislature',
#   'dbo:Book'],
#  'dbpedia_12959': ['dbo:InformationAppliance',
#   'dbo:Constellation',
#   'dbo:Company',
#   'dbo:ProgrammingLanguage',
#   'dbo:Plant',
#   'dbo:Software',
#   'dbo:WorldHeritageSite',
#   'dbo:TennisPlayer',
#   'dbo:FormulaOneTeam',
#   'dbo:AdministrativeRegion'],
#  'dbpedia_14915': ['dbo:Band',
#   'dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:Album',
#   'dbo:PoliticalParty',
#   'dbo:Wrestler',
#   'dbo:Star',
#   'dbo:Scientist'],
#  'dbpedia_19704': ['dbo:Organisation',
#   'dbo:University',
#   'dbo:Company',
#   'dbo:Royalty',
#   'dbo:Saint',
#   'dbo:AcademicJournal',
#   'dbo:GovernmentAgency',
#   'dbo:TelevisionStation',
#   'dbo:MilitaryUnit',
#   'dbo:Philosopher'],
#  'dbpedia_1999': ['dbo:Saint',
#   'dbo:Writer',
#   'dbo:Scientist',
#   'dbo:AmericanFootballTeam',
#   'dbo:MilitaryPerson',
#   'dbo:MilitaryConflict',
#   'dbo:City',
#   'dbo:InformationAppliance',
#   'dbo:Disease',
#   'dbo:Film'],
#  'dbpedia_19364': ['dbo:Writer',
#   'dbo:Book',
#   'dbo:OfficeHolder',
#   'dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:Scientist',
#   'dbo:FictionalCharacter',
#   'dbo:City',
#   'dbo:Philosopher',
#   'dbo:Game'],
#  'dbpedia_8664': ['dbo:Plant', 'dbo:Mammal', 'dbo:Person'],
#  'dbpedia_22194': ['dbo:Country',
#   'dbo:Settlement',
#   'dbo:Organisation',
#   'dbo:City',
#   'dbo:AdministrativeRegion',
#   'dbo:Sport',
#   'dbo:Plant',
#   'dbo:ProgrammingLanguage',
#   'dbo:Person',
#   'dbo:MusicGenre'],
#  'dbpedia_23548': ['dbo:Country',
#   'dbo:River',
#   'dbo:ChemicalCompound',
#   'dbo:Constellation',
#   'dbo:Building',
#   'dbo:Language',
#   'dbo:MilitaryUnit',
#   'dbo:Religious',
#   'dbo:Weapon',
#   'dbo:Band'],
#  'dbpedia_22137': ['dbo:MusicalArtist',
#   'dbo:Person',
#   'dbo:Saint',
#   'dbo:ChristianBishop',
#   'dbo:University',
#   'dbo:TelevisionShow',
#   'dbo:Fish',
#   'dbo:Bird',
#   'dbo:Building',
#   'dbo:Musical'],
#  'dbpedia_20711': ['dbo:TelevisionShow',
#   'dbo:TelevisionStation',
#   'dbo:MusicalArtist',
#   'dbo:Band',
#   'dbo:Scientist',
#   'dbo:Film',
#   'dbo:Software',
#   'dbo:FigureSkater',
#   'dbo:BroadcastNetwork',
#   'dbo:Cricketer'],
#  'dbpedia_10716': ['dbo:Country',
#   'dbo:OfficeHolder',
#   'dbo:AmericanFootballPlayer',
#   'dbo:City',
#   'dbo:Legislature',
#   'dbo:TelevisionShow',
#   'dbo:PoliticalParty',
#   'dbo:AdministrativeRegion',
#   'dbo:Bird',
#   'dbo:Language'],
#  'dbpedia_12820': ['dbo:Philosopher',
#   'dbo:Scientist',
#   'dbo:Writer',
#   'dbo:Person',
#   'dbo:Royalty',
#   'dbo:Politician',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:AmericanFootballTeam',
#   'dbo:Band'],
#  'dbpedia_5338': ['dbo:InformationAppliance',
#   'dbo:Software',
#   'dbo:ChemicalCompound',
#   'dbo:Constellation',
#   'dbo:Book',
#   'dbo:River',
#   'dbo:Aircraft',
#   'dbo:Language',
#   'dbo:Film',
#   'dbo:ProgrammingLanguage'],
#  'dbpedia_22226': ['dbo:River',
#   'dbo:Software',
#   'dbo:EthnicGroup',
#   'dbo:Person',
#   'dbo:Organisation',
#   'dbo:Town',
#   'dbo:Settlement',
#   'dbo:ChemicalCompound',
#   'dbo:MilitaryConflict'],
#  'dbpedia_13472': ['dbo:Person',
#   'dbo:Scientist',
#   'dbo:Aircraft',
#   'dbo:Company',
#   'dbo:Software',
#   'dbo:MilitaryPerson'],
#  'dbpedia_23390': ['dbo:InformationAppliance',
#   'dbo:VideoGame',
#   'dbo:Royalty',
#   'dbo:MilitaryConflict',
#   'dbo:Economist',
#   'dbo:ProgrammingLanguage',
#   'dbo:Software',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:Mineral'],
#  'dbpedia_21821': ['dbo:Company',
#   'dbo:City',
#   'dbo:Settlement',
#   'dbo:Person',
#   'dbo:Film',
#   'dbo:Writer'],
#  'dbpedia_18065': ['dbo:Person',
#   'dbo:Writer',
#   'dbo:Island',
#   'dbo:ChessPlayer',
#   'dbo:Museum',
#   'dbo:Game',
#   'dbo:Language',
#   'dbo:Mountain',
#   'dbo:Comic',
#   'dbo:Scientist'],
#  'dbpedia_7669': ['dbo:Person',
#   'dbo:FictionalCharacter',
#   'dbo:Royalty',
#   'dbo:TelevisionShow',
#   'dbo:Film',
#   'dbo:ComicsCharacter',
#   'dbo:Language',
#   'dbo:Book',
#   'dbo:Noble',
#   'dbo:Monarch'],
#  'dbpedia_13896': ['dbo:ArtificialSatellite',
#   'dbo:MilitaryUnit',
#   'dbo:MilitaryConflict',
#   'dbo:Software',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Disease',
#   'dbo:Writer'],
#  'dbpedia_8402': ['dbo:TelevisionShow',
#   'dbo:ChemicalCompound',
#   'dbo:Constellation',
#   'dbo:Crustacean',
#   'dbo:Organisation',
#   'dbo:AcademicJournal',
#   'dbo:Mineral',
#   'dbo:GovernmentAgency',
#   'dbo:University',
#   'dbo:River'],
#  'dbpedia_23074': ['dbo:River',
#   'dbo:Settlement',
#   'dbo:City',
#   'dbo:Town',
#   'dbo:Building',
#   'dbo:Scientist',
#   'dbo:Disease',
#   'dbo:Country'],
#  'dbpedia_3035': ['dbo:Game',
#   'dbo:VideoGame',
#   'dbo:Sport',
#   'dbo:InformationAppliance',
#   'dbo:Company',
#   'dbo:TennisPlayer',
#   'dbo:RugbyClub',
#   'dbo:Person'],
#  'dbpedia_13370': ['dbo:Award',
#   'dbo:Scientist',
#   'dbo:Book',
#   'dbo:Film',
#   'dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:Building',
#   'dbo:Disease',
#   'dbo:BaseballPlayer',
#   'dbo:TelevisionShow'],
#  'dbpedia_6434': ['dbo:Band',
#   'dbo:Person',
#   'dbo:Settlement',
#   'dbo:Album',
#   'dbo:Monarch',
#   'dbo:AmericanFootballTeam',
#   'dbo:Royalty',
#   'dbo:Cricketer',
#   'dbo:MusicalArtist',
#   'dbo:Building'],
#  'dbpedia_5897': ['dbo:Royalty',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:Disease',
#   'dbo:WorldHeritageSite',
#   'dbo:Film',
#   'dbo:Convention',
#   'dbo:Sport',
#   'dbo:InformationAppliance',
#   'dbo:Drug'],
#  'dbpedia_11496': ['dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:Musical',
#   'dbo:MusicGenre',
#   'dbo:Royalty',
#   'dbo:Language',
#   'dbo:Artist',
#   'dbo:Album',
#   'dbo:Band',
#   'dbo:Film'],
#  'dbpedia_21952': ['dbo:Writer',
#   'dbo:Philosopher',
#   'dbo:Scientist',
#   'dbo:Royalty',
#   'dbo:Person',
#   'dbo:Film',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:Saint',
#   'dbo:AmericanFootballTeam'],
#  'dbpedia_22498': ['dbo:Person',
#   'dbo:TelevisionShow',
#   'dbo:ChemicalCompound',
#   'dbo:ComicsCharacter',
#   'dbo:Anime',
#   'dbo:Writer',
#   'dbo:Venue',
#   'dbo:FictionalCharacter',
#   'dbo:Scientist',
#   'dbo:TennisPlayer'],
#  'dbpedia_14453': ['dbo:Disease',
#   'dbo:InformationAppliance',
#   'dbo:Scientist',
#   'dbo:Artery',
#   'dbo:Museum',
#   'dbo:Software',
#   'dbo:BroadcastNetwork',
#   'dbo:Mammal',
#   'dbo:Sea',
#   'dbo:Writer'],
#  'dbpedia_3644': ['dbo:Disease',
#   'dbo:Island',
#   'dbo:Writer',
#   'dbo:VideoGame',
#   'dbo:Film',
#   'dbo:Painter',
#   'dbo:TelevisionShow',
#   'dbo:Scientist',
#   'dbo:RugbyClub',
#   'dbo:InformationAppliance'],
#  'dbpedia_14436': ['dbo:Building',
#   'dbo:Scientist',
#   'dbo:Award',
#   'dbo:Mammal',
#   'dbo:Person',
#   'dbo:Film'],
#  'dbpedia_3070': ['dbo:Film',
#   'dbo:Person',
#   'dbo:Software',
#   'dbo:Organisation',
#   'dbo:Game',
#   'dbo:Settlement',
#   'dbo:Sport'],
#  'dbpedia_1127': ['dbo:Company',
#   'dbo:Organisation',
#   'dbo:TelevisionShow',
#   'dbo:BroadcastNetwork',
#   'dbo:City',
#   'dbo:RadioStation',
#   'dbo:MilitaryConflict',
#   'dbo:ProgrammingLanguage',
#   'dbo:Person'],
#  'dbpedia_9186': ['dbo:Royalty',
#   'dbo:Island',
#   'dbo:Holiday',
#   'dbo:Country',
#   'dbo:Building',
#   'dbo:Settlement',
#   'dbo:AmericanFootballPlayer',
#   'dbo:WorldHeritageSite',
#   'dbo:Person',
#   'dbo:Organisation'],
#  'dbpedia_1573': ['dbo:MusicalArtist',
#   'dbo:Royalty',
#   'dbo:MilitaryPerson',
#   'dbo:WorldHeritageSite',
#   'dbo:OfficeHolder',
#   'dbo:Film',
#   'dbo:Person',
#   'dbo:Building',
#   'dbo:ProgrammingLanguage',
#   'dbo:Mineral'],
#  'dbpedia_4373': ['dbo:Person'],
#  'dbpedia_10657': ['dbo:Person',
#   'dbo:Band',
#   'dbo:ComicsCharacter',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:PrimeMinister',
#   'dbo:TelevisionShow',
#   'dbo:Weapon',
#   'dbo:Software',
#   'dbo:Cricketer'],
#  'dbpedia_6322': ['dbo:Country',
#   'dbo:Sport',
#   'dbo:TelevisionShow',
#   'dbo:MusicGenre',
#   'dbo:Company',
#   'dbo:Game',
#   'dbo:Band',
#   'dbo:Person',
#   'dbo:Holiday'],
#  'dbpedia_10057': ['dbo:University',
#   'dbo:Scientist',
#   'dbo:City',
#   'dbo:Person',
#   'dbo:Organisation',
#   'dbo:Writer',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:Saint',
#   'dbo:President'],
#  'dbpedia_2223': ['dbo:Person'],
#  'dbpedia_22244': ['dbo:OfficeHolder',
#   'dbo:Band',
#   'dbo:Scientist',
#   'dbo:MilitaryUnit',
#   'dbo:MilitaryPerson',
#   'dbo:Economist',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:Person'],
#  'dbpedia_4619': ['dbo:PoliticalParty',
#   'dbo:Organisation',
#   'dbo:OfficeHolder',
#   'dbo:City',
#   'dbo:Film',
#   'dbo:University',
#   'dbo:Venue',
#   'dbo:Settlement',
#   'dbo:SoccerClub',
#   'dbo:Bank'],
#  'dbpedia_1583': ['dbo:Person',
#   'dbo:Film',
#   'dbo:Game',
#   'dbo:Royalty',
#   'dbo:AmericanFootballLeague',
#   'dbo:Award',
#   'dbo:TelevisionShow',
#   'dbo:Monarch',
#   'dbo:Writer',
#   'dbo:MusicalArtist'],
#  'dbpedia_13926': ['dbo:Band',
#   'dbo:InformationAppliance',
#   'dbo:TelevisionShow',
#   'dbo:Person',
#   'dbo:Religious',
#   'dbo:Album',
#   'dbo:Book',
#   'dbo:Food',
#   'dbo:Constellation',
#   'dbo:ChemicalCompound'],
#  'dbpedia_22521': ['dbo:Person',
#   'dbo:TelevisionShow',
#   'dbo:MilitaryPerson',
#   'dbo:Software',
#   'dbo:Plant',
#   'dbo:Holiday',
#   'dbo:PrimeMinister',
#   'dbo:Film',
#   'dbo:GovernmentAgency',
#   'dbo:Settlement'],
#  'dbpedia_7538': ['dbo:Settlement',
#   'dbo:MilitaryConflict',
#   'dbo:Royalty',
#   'dbo:City',
#   'dbo:Person',
#   'dbo:Mountain',
#   'dbo:Building',
#   'dbo:Town',
#   'dbo:Painter',
#   'dbo:Artist'],
#  'dbpedia_12469': ['dbo:Person',
#   'dbo:MilitaryConflict',
#   'dbo:Writer',
#   'dbo:Royalty',
#   'dbo:Book',
#   'dbo:Company',
#   'dbo:Artist',
#   'dbo:Game',
#   'dbo:HistoricPlace',
#   'dbo:MilitaryUnit'],
#  'dbpedia_14706': ['dbo:Country',
#   'dbo:Settlement',
#   'dbo:Island',
#   'dbo:AdministrativeRegion',
#   'dbo:City',
#   'dbo:MilitaryUnit',
#   'dbo:PoliticalParty',
#   'dbo:University'],
#  'dbpedia_14072': ['dbo:Person',
#   'dbo:Writer',
#   'dbo:Royalty',
#   'dbo:TelevisionShow',
#   'dbo:Scientist',
#   'dbo:Anime',
#   'dbo:ChristianBishop',
#   'dbo:MusicalArtist',
#   'dbo:Saint',
#   'dbo:Mineral'],
#  'dbpedia_9447': ['dbo:Person',
#   'dbo:Film',
#   'dbo:Astronaut',
#   'dbo:TelevisionShow',
#   'dbo:ChristianBishop',
#   'dbo:Writer',
#   'dbo:Airport',
#   'dbo:Scientist',
#   'dbo:BaseballPlayer'],
#  'dbpedia_19263': ['dbo:City',
#   'dbo:River',
#   'dbo:Settlement',
#   'dbo:Country',
#   'dbo:AdministrativeRegion',
#   'dbo:Town'],
#  'dbpedia_16962': ['dbo:Band',
#   'dbo:Person',
#   'dbo:Album',
#   'dbo:MusicalArtist',
#   'dbo:Film',
#   'dbo:Fish',
#   'dbo:Writer',
#   'dbo:TelevisionShow',
#   'dbo:OfficeHolder'],
#  'dbpedia_8784': ['dbo:Writer',
#   'dbo:Royalty',
#   'dbo:Colour',
#   'dbo:Artist',
#   'dbo:MusicGenre',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:AmericanFootballTeam',
#   'dbo:Person',
#   'dbo:Band'],
#  'dbpedia_2839': ['dbo:City',
#   'dbo:Lake',
#   'dbo:Writer',
#   'dbo:Settlement',
#   'dbo:BaseballTeam',
#   'dbo:MilitaryConflict',
#   'dbo:Airport',
#   'dbo:ChemicalCompound',
#   'dbo:Eukaryote',
#   'dbo:Person'],
#  'dbpedia_20717': ['dbo:Person',
#   'dbo:Film',
#   'dbo:Award',
#   'dbo:OfficeHolder',
#   'dbo:Saint',
#   'dbo:Monarch',
#   'dbo:Company',
#   'dbo:FictionalCharacter',
#   'dbo:Book',
#   'dbo:MusicalArtist'],
#  'dbpedia_21540': ['dbo:TelevisionShow',
#   'dbo:TelevisionStation',
#   'dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:WorldHeritageSite',
#   'dbo:AmericanFootballPlayer',
#   'dbo:Airline',
#   'dbo:Software',
#   'dbo:ConcentrationCamp',
#   'dbo:GovernmentAgency'],
#  'dbpedia_8589': ['dbo:Person',
#   'dbo:Band',
#   'dbo:Album',
#   'dbo:Award',
#   'dbo:AmericanFootballTeam',
#   'dbo:MusicalArtist',
#   'dbo:InformationAppliance',
#   'dbo:Writer',
#   'dbo:Settlement',
#   'dbo:Royalty'],
#  'dbpedia_9527': ['dbo:Book',
#   'dbo:FictionalCharacter',
#   'dbo:Royalty',
#   'dbo:Musical',
#   'dbo:Constellation',
#   'dbo:ComicsCharacter',
#   'dbo:Settlement',
#   'dbo:InformationAppliance',
#   'dbo:Company',
#   'dbo:Organisation'],
#  'dbpedia_15137': ['dbo:Saint',
#   'dbo:Writer',
#   'dbo:Album',
#   'dbo:Organisation',
#   'dbo:Scientist',
#   'dbo:Monarch',
#   'dbo:City',
#   'dbo:Royalty',
#   'dbo:Person',
#   'dbo:Band'],
#  'dbpedia_17651': ['dbo:Royalty',
#   'dbo:PoliticalParty',
#   'dbo:Town',
#   'dbo:Person',
#   'dbo:FictionalCharacter',
#   'dbo:Scientist',
#   'dbo:Politician',
#   'dbo:MilitaryPerson',
#   'dbo:PrimeMinister',
#   'dbo:MusicalArtist'],
#  'dbpedia_6855': ['dbo:Writer',
#   'dbo:ChemicalCompound',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Disease',
#   'dbo:Island',
#   'dbo:Language'],
#  'dbpedia_21691': ['dbo:TennisPlayer',
#   'dbo:Settlement',
#   'dbo:Film',
#   'dbo:FigureSkater',
#   'dbo:Book',
#   'dbo:Musical',
#   'dbo:Constellation',
#   'dbo:River',
#   'dbo:Plant',
#   'dbo:Holiday'],
#  'dbpedia_5646': ['dbo:Country',
#   'dbo:Settlement',
#   'dbo:City',
#   'dbo:Company',
#   'dbo:Person',
#   'dbo:Museum',
#   'dbo:Place',
#   'dbo:EthnicGroup',
#   'dbo:Continent'],
#  'dbpedia_7293': ['dbo:Person',
#   'dbo:Settlement',
#   'dbo:Royalty',
#   'dbo:Film',
#   'dbo:Mountain',
#   'dbo:AdministrativeRegion',
#   'dbo:Award',
#   'dbo:TelevisionShow',
#   'dbo:MusicalArtist',
#   'dbo:Place'],
#  'dbpedia_3924': ['dbo:City',
#   'dbo:Royalty',
#   'dbo:Saint',
#   'dbo:Person',
#   'dbo:University',
#   'dbo:AmericanFootballPlayer',
#   'dbo:RugbyClub',
#   'dbo:MusicalArtist',
#   'dbo:Philosopher',
#   'dbo:Mineral'],
#  'dbpedia_5602': ['dbo:Artist',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:Scientist',
#   'dbo:Philosopher',
#   'dbo:Band',
#   'dbo:MusicGenre',
#   'dbo:Architect'],
#  'dbpedia_13541': ['dbo:Constellation',
#   'dbo:Writer',
#   'dbo:InformationAppliance',
#   'dbo:Mineral',
#   'dbo:Game',
#   'dbo:Plant',
#   'dbo:Software',
#   'dbo:Mammal',
#   'dbo:Royalty',
#   'dbo:Organisation'],
#  'dbpedia_5048': ['dbo:Person',
#   'dbo:PoliticalParty',
#   'dbo:Artist',
#   'dbo:OfficeHolder',
#   'dbo:Constellation',
#   'dbo:Monument',
#   'dbo:Mineral',
#   'dbo:River',
#   'dbo:Royalty',
#   'dbo:Eukaryote'],
#  'dbpedia_2573': ['dbo:Person',
#   'dbo:InformationAppliance',
#   'dbo:Plant',
#   'dbo:Anime',
#   'dbo:TelevisionShow',
#   'dbo:ChemicalCompound',
#   'dbo:Crustacean',
#   'dbo:FictionalCharacter',
#   'dbo:Mammal',
#   'dbo:Bacteria'],
#  'dbpedia_17130': ['dbo:Saint',
#   'dbo:Settlement',
#   'dbo:Writer',
#   'dbo:City',
#   'dbo:AmericanFootballTeam',
#   'dbo:Building',
#   'dbo:Country',
#   'dbo:Scientist',
#   'dbo:Island',
#   'dbo:Disease'],
#  'dbpedia_17179': ['dbo:Company',
#   'dbo:Book',
#   'dbo:Film',
#   'dbo:Airline',
#   'dbo:AmericanFootballTeam',
#   'dbo:Country',
#   'dbo:Person',
#   'dbo:Writer'],
#  'dbpedia_23188': ['dbo:Writer',
#   'dbo:Scientist',
#   'dbo:Philosopher',
#   'dbo:MilitaryPerson',
#   'dbo:Person',
#   'dbo:Constellation',
#   'dbo:ChemicalCompound',
#   'dbo:Award',
#   'dbo:Newspaper',
#   'dbo:Medician'],
#  'dbpedia_3632': ['dbo:University',
#   'dbo:City',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:Band',
#   'dbo:Film',
#   'dbo:Book',
#   'dbo:AmericanFootballTeam',
#   'dbo:PoliticalParty'],
#  'dbpedia_6540': ['dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:AmericanFootballTeam',
#   'dbo:Band'],
#  'dbpedia_2922': ['dbo:Royalty',
#   'dbo:Person',
#   'dbo:Museum',
#   'dbo:Writer',
#   'dbo:Monument',
#   'dbo:Painter',
#   'dbo:Monarch',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Disease'],
#  'dbpedia_12554': ['dbo:Award',
#   'dbo:Writer',
#   'dbo:Person',
#   'dbo:WorldHeritageSite',
#   'dbo:Band',
#   'dbo:Artist',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:Newspaper',
#   'dbo:ProgrammingLanguage'],
#  'dbpedia_14851': ['dbo:Film',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:Organisation',
#   'dbo:Mammal'],
#  'dbpedia_19073': ['dbo:Building',
#   'dbo:Royalty',
#   'dbo:AdministrativeRegion',
#   'dbo:Settlement',
#   'dbo:Election',
#   'dbo:MilitaryPerson',
#   'dbo:MusicGenre',
#   'dbo:Place',
#   'dbo:Road',
#   'dbo:Politician'],
#  'dbpedia_7901': ['dbo:MilitaryConflict',
#   'dbo:Settlement',
#   'dbo:Ship',
#   'dbo:Person'],
#  'dbpedia_17840': ['dbo:Person',
#   'dbo:Royalty',
#   'dbo:Film',
#   'dbo:Philosopher',
#   'dbo:WorldHeritageSite',
#   'dbo:Scientist',
#   'dbo:AcademicJournal',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:BaseballPlayer'],
#  'dbpedia_19210': ['dbo:InformationAppliance',
#   'dbo:Person',
#   'dbo:Company',
#   'dbo:Scientist',
#   'dbo:Writer',
#   'dbo:PoliticalParty',
#   'dbo:MusicalArtist',
#   'dbo:EthnicGroup',
#   'dbo:AcademicJournal',
#   'dbo:Saint'],
#  'dbpedia_8534': ['dbo:Holiday',
#   'dbo:Disease',
#   'dbo:River',
#   'dbo:Country',
#   'dbo:Mammal',
#   'dbo:ChemicalCompound',
#   'dbo:Religious',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:MilitaryConflict'],
#  'dbpedia_5093': ['dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:Comedian',
#   'dbo:SoccerManager',
#   'dbo:CollegeCoach',
#   'dbo:OfficeHolder',
#   'dbo:Book',
#   'dbo:MilitaryPerson',
#   'dbo:Anime',
#   'dbo:Company'],
#  'dbpedia_5509': ['dbo:River',
#   'dbo:Town',
#   'dbo:Writer',
#   'dbo:Settlement',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Disease',
#   'dbo:Island',
#   'dbo:Language'],
#  'dbpedia_19203': ['dbo:Sport',
#   'dbo:University',
#   'dbo:City',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:Museum',
#   'dbo:Book',
#   'dbo:BaseballPlayer',
#   'dbo:AmericanFootballTeam'],
#  'dbpedia_15605': ['dbo:Settlement',
#   'dbo:Royalty',
#   'dbo:Election',
#   'dbo:WorldHeritageSite',
#   'dbo:MilitaryUnit',
#   'dbo:OfficeHolder',
#   'dbo:Airline',
#   'dbo:MusicalArtist',
#   'dbo:Building',
#   'dbo:Mineral'],
#  'dbpedia_12393': ['dbo:Award',
#   'dbo:Person',
#   'dbo:Film',
#   'dbo:MusicalArtist',
#   'dbo:Book',
#   'dbo:BaseballPlayer',
#   'dbo:TelevisionShow',
#   'dbo:Writer'],
#  'dbpedia_4902': ['dbo:MilitaryUnit',
#   'dbo:MusicalArtist',
#   'dbo:Royalty',
#   'dbo:AmericanFootballTeam',
#   'dbo:OfficeHolder',
#   'dbo:InformationAppliance',
#   'dbo:Person',
#   'dbo:EthnicGroup',
#   'dbo:AmericanFootballPlayer',
#   'dbo:Anime'],
#  'dbpedia_22434': ['dbo:Film',
#   'dbo:Person',
#   'dbo:InformationAppliance',
#   'dbo:Band',
#   'dbo:Writer',
#   'dbo:AcademicJournal',
#   'dbo:AdministrativeRegion',
#   'dbo:Settlement',
#   'dbo:RugbyClub',
#   'dbo:Scientist'],
#  'dbpedia_7375': ['dbo:InformationAppliance',
#   'dbo:Company',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:Software',
#   'dbo:Organisation',
#   'dbo:ProgrammingLanguage',
#   'dbo:Disease',
#   'dbo:Writer'],
#  'dbpedia_20611': ['dbo:Writer',
#   'dbo:Person',
#   'dbo:Plant',
#   'dbo:Monarch',
#   'dbo:Organisation',
#   'dbo:Band',
#   'dbo:EthnicGroup',
#   'dbo:Newspaper',
#   'dbo:TelevisionShow',
#   'dbo:Planet'],
#  'dbpedia_19854': ['dbo:TelevisionShow',
#   'dbo:TelevisionStation',
#   'dbo:City',
#   'dbo:MusicalArtist',
#   'dbo:AmericanFootballPlayer',
#   'dbo:Newspaper',
#   'dbo:Writer',
#   'dbo:BroadcastNetwork',
#   'dbo:Airport',
#   'dbo:Constellation'],
#  'dbpedia_6314': ['dbo:Person',
#   'dbo:Scientist',
#   'dbo:Artist',
#   'dbo:Organisation',
#   'dbo:AmericanFootballPlayer',
#   'dbo:FictionalCharacter',
#   'dbo:ChristianBishop',
#   'dbo:Island',
#   'dbo:Award',
#   'dbo:Venue'],
#  'dbpedia_3920': ['dbo:MusicalArtist',
#   'dbo:Artery',
#   'dbo:Disease',
#   'dbo:PoliticalParty',
#   'dbo:Band',
#   'dbo:President'],
#  'dbpedia_3109': ['dbo:Sport',
#   'dbo:Settlement',
#   'dbo:Constellation',
#   'dbo:MilitaryUnit',
#   'dbo:Museum',
#   'dbo:Airline',
#   'dbo:Venue',
#   'dbo:BodyOfWater',
#   'dbo:Writer',
#   'dbo:Person'],
#  'dbpedia_5827': ['dbo:AcademicJournal',
#   'dbo:Disease',
#   'dbo:Book',
#   'dbo:Comic',
#   'dbo:Person',
#   'dbo:Company',
#   'dbo:ComicsCharacter',
#   'dbo:Game',
#   'dbo:Software',
#   'dbo:Album'],
#  'dbpedia_16906': ['dbo:ArtificialSatellite',
#   'dbo:OfficeHolder',
#   'dbo:Country',
#   'dbo:Legislature',
#   'dbo:Planet',
#   'dbo:Language',
#   'dbo:PoliticalParty',
#   'dbo:AdministrativeRegion',
#   'dbo:Person'],
#  'dbpedia_14899': ['dbo:Artist',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:MusicalArtist',
#   'dbo:ComicsCharacter',
#   'dbo:MusicGenre',
#   'dbo:Company',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Disease'],
#  'dbpedia_12364': ['dbo:Saint',
#   'dbo:EthnicGroup',
#   'dbo:ChemicalCompound',
#   'dbo:City',
#   'dbo:AmericanFootballTeam',
#   'dbo:Band',
#   'dbo:Writer',
#   'dbo:Language',
#   'dbo:Convention',
#   'dbo:Bank'],
#  'dbpedia_1272': ['dbo:City',
#   'dbo:AdministrativeRegion',
#   'dbo:GovernmentAgency',
#   'dbo:TelevisionStation',
#   'dbo:Software',
#   'dbo:Beverage',
#   'dbo:Game',
#   'dbo:Organisation',
#   'dbo:Weapon',
#   'dbo:Scientist'],
#  'dbpedia_17271': ['dbo:InformationAppliance',
#   'dbo:Company',
#   'dbo:Writer',
#   'dbo:Scientist',
#   'dbo:Person',
# ...
#   'dbo:City',
#   'dbo:University',
#   'dbo:MusicalArtist',
#   'dbo:MilitaryPerson',
#   'dbo:WorldHeritageSite',
#   'dbo:Artist',
#   'dbo:RugbyClub'],
#  'dbpedia_23447': ['dbo:Country',
#   'dbo:Person',
#   'dbo:Fish',
#   'dbo:EthnicGroup',
#   'dbo:Settlement',
#   'dbo:Reptile',
#   'dbo:Bird',
#   'dbo:PoliticalParty',
#   'dbo:Language',
#   'dbo:River'],
#  'dbpedia_20822': ['dbo:ChemicalCompound',
#   'dbo:Aircraft',
#   'dbo:Constellation',
#   'dbo:AnatomicalStructure',
#   'dbo:Sea',
#   'dbo:Settlement',
#   'dbo:River',
#   'dbo:Organisation',
#   'dbo:Artery',
#   'dbo:Language'],
#  'dbpedia_6745': ['dbo:ChemicalCompound',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:InformationAppliance',
#   'dbo:Company',
#   'dbo:TelevisionStation',
#   'dbo:EthnicGroup',
#   'dbo:Disease',
#   'dbo:MilitaryUnit',
#   'dbo:Organisation'],
#  'dbpedia_9679': ['dbo:Software',
#   'dbo:Constellation',
#   'dbo:Writer',
#   'dbo:Aircraft',
#   'dbo:Scientist',
#   'dbo:Plant',
#   'dbo:Star',
#   'dbo:Film',
#   'dbo:WorldHeritageSite',
#   'dbo:ProgrammingLanguage'],
#  'dbpedia_17538': ['dbo:Award',
#   'dbo:Person',
#   'dbo:Film',
#   'dbo:Holiday',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:Band',
#   'dbo:BaseballPlayer',
#   'dbo:TelevisionShow',
#   'dbo:Book'],
#  'dbpedia_13313': ['dbo:TelevisionShow',
#   'dbo:InformationAppliance',
#   'dbo:TelevisionStation',
#   'dbo:VideoGame',
#   'dbo:FictionalCharacter',
#   'dbo:Aircraft',
#   'dbo:RugbyClub',
#   'dbo:Anime',
#   'dbo:Film',
#   'dbo:Comic'],
#  'dbpedia_14785': ['dbo:Holiday',
#   'dbo:Religious',
#   'dbo:Saint',
#   'dbo:ComicsCharacter',
#   'dbo:SoccerClub',
#   'dbo:Book',
#   'dbo:Company',
#   'dbo:Monarch',
#   'dbo:Settlement',
#   'dbo:MilitaryConflict'],
#  'dbpedia_10255': ['dbo:Royalty',
#   'dbo:Person',
#   'dbo:Company',
#   'dbo:Aircraft',
#   'dbo:Artist',
#   'dbo:MusicGenre',
#   'dbo:Monarch',
#   'dbo:MusicalArtist',
#   'dbo:BaseballTeam',
#   'dbo:BroadcastNetwork'],
#  'dbpedia_13851': ['dbo:Writer',
#   'dbo:Book',
#   'dbo:VideoGame',
#   'dbo:Person',
#   'dbo:Airline',
#   'dbo:MusicalArtist',
#   'dbo:Scientist',
#   'dbo:FictionalCharacter',
#   'dbo:OfficeHolder',
#   'dbo:ChemicalCompound'],
#  'dbpedia_3786': ['dbo:ProgrammingLanguage',
#   'dbo:Software',
#   'dbo:Scientist',
#   'dbo:WorldHeritageSite',
#   'dbo:InformationAppliance',
#   'dbo:Constellation',
#   'dbo:Island',
#   'dbo:Language'],
#  'dbpedia_20671': ['dbo:Company',
#   'dbo:InformationAppliance',
#   'dbo:BroadcastNetwork',
#   'dbo:TelevisionStation',
#   'dbo:Bank'],
#  'dbpedia_8935': ['dbo:AnatomicalStructure',
#   'dbo:Mammal',
#   'dbo:Plant',
#   'dbo:Company',
#   'dbo:Disease',
#   'dbo:Person',
#   'dbo:Mountain',
#   'dbo:Settlement',
#   'dbo:Royalty',
#   'dbo:Fish'],
#  'dbpedia_11049': ['dbo:MusicalArtist',
#   'dbo:Royalty',
#   'dbo:Scientist',
#   'dbo:Writer',
#   'dbo:Artist',
#   'dbo:Mineral',
#   'dbo:Settlement',
#   'dbo:AdministrativeRegion',
#   'dbo:AmericanFootballTeam',
#   'dbo:Language'],
#  'dbpedia_21480': ['dbo:Award',
#   'dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:Company',
#   'dbo:ComicsCharacter',
#   'dbo:Royalty',
#   'dbo:BroadcastNetwork',
#   'dbo:TelevisionStation',
#   'dbo:Writer'],
#  'dbpedia_8644': ['dbo:Settlement',
#   'dbo:City',
#   'dbo:Town',
#   'dbo:InformationAppliance',
#   'dbo:Sport',
#   'dbo:SoccerClub',
#   'dbo:VideoGame'],
#  'dbpedia_8879': ['dbo:Band',
#   'dbo:ChemicalCompound',
#   'dbo:EthnicGroup',
#   'dbo:Species',
#   'dbo:Reptile',
#   'dbo:AdministrativeRegion',
#   'dbo:Language',
#   'dbo:Island',
#   'dbo:Bank',
#   'dbo:City'],
#  'dbpedia_12458': ['dbo:Game',
#   'dbo:Writer',
#   'dbo:Person',
#   'dbo:MilitaryPerson',
#   'dbo:InformationAppliance',
#   'dbo:ChemicalCompound',
#   'dbo:Software',
#   'dbo:Company',
#   'dbo:Royalty',
#   'dbo:PrimeMinister'],
#  'dbpedia_20708': ['dbo:Person',
#   'dbo:AcademicJournal',
#   'dbo:Film',
#   'dbo:FictionalCharacter',
#   'dbo:Company',
#   'dbo:OfficeHolder',
#   'dbo:Mineral',
#   'dbo:Monarch',
#   'dbo:MilitaryConflict',
#   'dbo:Writer'],
#  'dbpedia_14582': ['dbo:VideoGame',
#   'dbo:Person',
#   'dbo:InformationAppliance',
#   'dbo:Company',
#   'dbo:Game',
#   'dbo:FictionalCharacter'],
#  'dbpedia_17224': ['dbo:University',
#   'dbo:City',
#   'dbo:Scientist',
#   'dbo:Building',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:River',
#   'dbo:Album',
#   'dbo:ArtificialSatellite'],
#  'dbpedia_13369': ['dbo:Sport',
#   'dbo:BaseballTeam',
#   'dbo:Royalty',
#   'dbo:Disease',
#   'dbo:Writer',
#   'dbo:Colour',
#   'dbo:EthnicGroup',
#   'dbo:Organisation',
#   'dbo:MusicalArtist',
#   'dbo:Company'],
#  'dbpedia_23472': ['dbo:Person',
#   'dbo:Building',
#   'dbo:Mountain',
#   'dbo:Settlement',
#   'dbo:ChessPlayer',
#   'dbo:BaseballPlayer'],
#  'dbpedia_18511': ['dbo:OfficeHolder',
#   'dbo:Band',
#   'dbo:Scientist',
#   'dbo:Royalty',
#   'dbo:MilitaryPerson',
#   'dbo:Economist',
#   'dbo:MusicalArtist',
#   'dbo:Settlement',
#   'dbo:Religious',
#   'dbo:Mineral'],
#  'dbpedia_22683': ['dbo:Band',
#   'dbo:Writer',
#   'dbo:Album',
#   'dbo:Plant',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:Mammal',
#   'dbo:Company',
#   'dbo:Island',
#   'dbo:MusicalArtist'],
#  'dbpedia_20542': ['dbo:Sport',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:Film',
#   'dbo:Band',
#   'dbo:Comic',
#   'dbo:MusicalArtist',
#   'dbo:BaseballPlayer'],
#  'dbpedia_23292': ['dbo:TelevisionShow',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:FictionalCharacter',
#   'dbo:MusicalArtist',
#   'dbo:Anime',
#   'dbo:TelevisionStation',
#   'dbo:GovernmentAgency'],
#  'dbpedia_5188': ['dbo:Saint',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:TelevisionStation',
#   'dbo:Software',
#   'dbo:Game',
#   'dbo:Organisation',
#   'dbo:Weapon',
#   'dbo:Aircraft',
#   'dbo:GovernmentAgency'],
#  'dbpedia_15282': ['dbo:MusicalArtist',
#   'dbo:Person',
#   'dbo:Game',
#   'dbo:OfficeHolder',
#   'dbo:Scientist',
#   'dbo:MilitaryConflict',
#   'dbo:Philosopher',
#   'dbo:University',
#   'dbo:TelevisionShow',
#   'dbo:PrimeMinister'],
#  'dbpedia_22902': ['dbo:Scientist',
#   'dbo:Organisation',
#   'dbo:Disease',
#   'dbo:Game',
#   'dbo:Beverage',
#   'dbo:ProgrammingLanguage',
#   'dbo:Poem',
#   'dbo:Venue',
#   'dbo:TelevisionShow',
#   'dbo:Philosopher'],
#  'dbpedia_23075': ['dbo:Writer',
#   'dbo:Book',
#   'dbo:Saint',
#   'dbo:Scientist',
#   'dbo:Company',
#   'dbo:Building',
#   'dbo:MusicalArtist',
#   'dbo:Philosopher',
#   'dbo:Disease',
#   'dbo:Person'],
#  'dbpedia_19776': ['dbo:Person',
#   'dbo:Company',
#   'dbo:Film',
#   'dbo:Writer',
#   'dbo:Beverage',
#   'dbo:MusicalArtist',
#   'dbo:Book',
#   'dbo:AnatomicalStructure',
#   'dbo:ChemicalCompound',
#   'dbo:InformationAppliance'],
#  'dbpedia_7752': ['dbo:Settlement',
#   'dbo:Band',
#   'dbo:Royalty',
#   'dbo:Organisation',
#   'dbo:Building',
#   'dbo:EthnicGroup',
#   'dbo:Bird',
#   'dbo:Newspaper',
#   'dbo:Writer',
#   'dbo:City'],
#  'dbpedia_8937': ['dbo:Person', 'dbo:Royalty', 'dbo:TelevisionStation'],
#  'dbpedia_15791': ['dbo:Writer',
#   'dbo:Book',
#   'dbo:Museum',
#   'dbo:Musical',
#   'dbo:Film',
#   'dbo:Play',
#   'dbo:Scientist',
#   'dbo:Person',
#   'dbo:Disease',
#   'dbo:InformationAppliance'],
#  'dbpedia_5009': ['dbo:Writer',
#   'dbo:AdministrativeRegion',
#   'dbo:Band',
#   'dbo:Person',
#   'dbo:Constellation',
#   'dbo:Mineral',
#   'dbo:Language',
#   'dbo:InformationAppliance',
#   'dbo:River',
#   'dbo:Royalty'],
#  'dbpedia_19474': ['dbo:MilitaryUnit',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:Aircraft',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:OfficeHolder',
#   'dbo:Journalist',
#   'dbo:Award'],
#  'dbpedia_6085': ['dbo:MusicalArtist',
#   'dbo:Person',
#   'dbo:VideoGame',
#   'dbo:Band',
#   'dbo:Royalty',
#   'dbo:Film',
#   'dbo:Writer',
#   'dbo:Mineral',
#   'dbo:AmericanFootballTeam'],
#  'dbpedia_10241': ['dbo:Country',
#   'dbo:Organisation',
#   'dbo:Settlement',
#   'dbo:Language',
#   'dbo:Legislature',
#   'dbo:MilitaryConflict',
#   'dbo:PoliticalParty',
#   'dbo:ChemicalCompound',
#   'dbo:AdministrativeRegion',
#   'dbo:Royalty'],
#  'dbpedia_20229': ['dbo:Company',
#   'dbo:University',
#   'dbo:Organisation',
#   'dbo:Comic',
#   'dbo:City',
#   'dbo:Bank',
#   'dbo:Person'],
#  'dbpedia_22914': ['dbo:SoccerClub',
#   'dbo:AmericanFootballTeam',
#   'dbo:Game',
#   'dbo:Sport',
#   'dbo:Holiday',
#   'dbo:AustralianFootballTeam',
#   'dbo:MusicalArtist',
#   'dbo:BaseballTeam'],
#  'dbpedia_17520': ['dbo:Weapon',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:Aircraft',
#   'dbo:TelevisionStation',
#   'dbo:Software',
#   'dbo:Game',
#   'dbo:Organisation',
#   'dbo:Disease',
#   'dbo:GovernmentAgency'],
#  'dbpedia_59': ['dbo:Award',
#   'dbo:Person',
#   'dbo:Writer',
#   'dbo:Scientist',
#   'dbo:MusicalArtist',
#   'dbo:Newspaper',
#   'dbo:Philosopher',
#   'dbo:Royalty',
#   'dbo:Medician',
#   'dbo:Building'],
#  'dbpedia_2767': ['dbo:Settlement',
#   'dbo:City',
#   'dbo:Country',
#   'dbo:Royalty',
#   'dbo:MilitaryConflict',
#   'dbo:Person',
#   'dbo:Saint',
#   'dbo:Drug',
#   'dbo:Mammal',
#   'dbo:AdministrativeRegion'],
#  'dbpedia_4361': ['dbo:Person',
#   'dbo:Settlement',
#   'dbo:Band',
#   'dbo:Album',
#   'dbo:Building',
#   'dbo:Election',
#   'dbo:AmericanFootballTeam',
#   'dbo:Cricketer',
#   'dbo:MilitaryConflict',
#   'dbo:Saint'],
#  'dbpedia_3879': ['dbo:Settlement',
#   'dbo:AdministrativeRegion',
#   'dbo:City',
#   'dbo:MilitaryPerson',
#   'dbo:Organisation',
#   'dbo:Writer',
#   'dbo:ChristianBishop',
#   'dbo:Royalty',
#   'dbo:MilitaryConflict',
#   'dbo:Person'],
#  'dbpedia_21236': ['dbo:OfficeHolder',
#   'dbo:PrimeMinister',
#   'dbo:Company',
#   'dbo:Saint',
#   'dbo:Museum',
#   'dbo:Royalty',
#   'dbo:Settlement',
#   'dbo:Religious',
#   'dbo:ChristianBishop',
#   'dbo:PoliticalParty'],
#  'dbpedia_22129': ['dbo:Language',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:EthnicGroup',
#   'dbo:Fish',
#   'dbo:Bird',
#   'dbo:Monument',
#   'dbo:Building',
#   'dbo:Island',
#   'dbo:Constellation'],
#  'dbpedia_1896': ['dbo:Royalty',
#   'dbo:Sport',
#   'dbo:MusicalArtist',
#   'dbo:Artist',
#   'dbo:Town',
#   'dbo:Mineral',
#   'dbo:AmericanFootballTeam',
#   'dbo:Band',
#   'dbo:Medician'],
#  'dbpedia_4255': ['dbo:Film',
#   'dbo:Person',
#   'dbo:TelevisionShow',
#   'dbo:Band',
#   'dbo:Company',
#   'dbo:AdministrativeRegion',
#   'dbo:Star',
#   'dbo:MilitaryUnit'],
#  'dbpedia_9931': ['dbo:Saint',
#   'dbo:ChristianBishop',
#   'dbo:University',
#   'dbo:MilitaryUnit',
#   'dbo:Organisation',
#   'dbo:WorldHeritageSite',
#   'dbo:OfficeHolder',
#   'dbo:Settlement',
#   'dbo:Writer',
#   'dbo:AmericanFootballTeam'],
#  'dbpedia_11815': ['dbo:Company',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:InformationAppliance',
#   'dbo:Aircraft'],
#  'dbpedia_1171': ['dbo:Company',
#   'dbo:TelevisionShow',
#   'dbo:TelevisionStation',
#   'dbo:FictionalCharacter',
#   'dbo:Person',
#   'dbo:InformationAppliance',
#   'dbo:Software',
#   'dbo:BroadcastNetwork',
#   'dbo:Bank',
#   'dbo:ProgrammingLanguage'],
#  'dbpedia_5729': ['dbo:Writer',
#   'dbo:Game',
#   'dbo:Book',
#   'dbo:AcademicJournal',
#   'dbo:Comic',
#   'dbo:Company',
#   'dbo:Scientist',
#   'dbo:Award',
#   'dbo:Disease',
#   'dbo:InformationAppliance'],
#  'dbpedia_6659': ['dbo:Person',
#   'dbo:Disease',
#   'dbo:Band',
#   'dbo:Book',
#   'dbo:Organisation',
#   'dbo:TelevisionShow',
#   'dbo:Language',
#   'dbo:Royalty',
#   'dbo:MilitaryConflict',
#   'dbo:Album'],
#  'dbpedia_14840': ['dbo:Person',
#   'dbo:Royalty',
#   'dbo:ChessPlayer',
#   'dbo:Book',
#   'dbo:Country',
#   'dbo:Game',
#   'dbo:Monarch',
#   'dbo:AdministrativeRegion',
#   'dbo:Film'],
#  'dbpedia_4658': ['dbo:Royalty',
#   'dbo:Monarch',
#   'dbo:Saint',
#   'dbo:MilitaryConflict',
#   'dbo:MusicalArtist'],
#  'dbpedia_8736': ['dbo:AmericanFootballTeam',
#   'dbo:SoccerClub',
#   'dbo:BaseballTeam',
#   'dbo:RugbyClub',
#   'dbo:AustralianFootballTeam',
#   'dbo:Sport'],
#  'dbpedia_1220': ['dbo:Sport',
#   'dbo:Band',
#   'dbo:Constellation',
#   'dbo:Mountain',
#   'dbo:Philosopher',
#   'dbo:Language',
#   'dbo:Game',
#   'dbo:Museum',
#   'dbo:MountainRange',
#   'dbo:Weapon'],
#  'dbpedia_21728': ['dbo:BaseballTeam',
#   'dbo:AmericanFootballTeam',
#   'dbo:SoccerClub',
#   'dbo:Sport'],
#  'dbpedia_14639': ['dbo:Person',
#   'dbo:Settlement',
#   'dbo:Company',
#   'dbo:Election',
#   'dbo:WorldHeritageSite',
#   'dbo:OfficeHolder',
#   'dbo:Airline',
#   'dbo:Weapon',
#   'dbo:Award',
#   'dbo:InformationAppliance'],
#  'dbpedia_9326': ['dbo:MusicalArtist',
#   'dbo:Person',
#   'dbo:Award',
#   'dbo:Writer',
#   'dbo:TelevisionShow',
#   'dbo:Band',
#   'dbo:Book',
#   'dbo:Film'],
#  'dbpedia_12177': ['dbo:ChemicalCompound',
#   'dbo:Scientist',
#   'dbo:Constellation',
#   'dbo:Artery',
#   'dbo:Disease',
#   'dbo:InformationAppliance',
#   'dbo:Writer',
#   'dbo:Country',
#   'dbo:Settlement',
#   'dbo:Bacteria'],
#  'dbpedia_13480': ['dbo:Organisation',
#   'dbo:ProgrammingLanguage',
#   'dbo:Book',
#   'dbo:RugbyClub',
#   'dbo:MilitaryUnit',
#   'dbo:TennisPlayer',
#   'dbo:OfficeHolder',
#   'dbo:ChemicalCompound',
#   'dbo:MilitaryConflict',
#   'dbo:Royalty'],
#  'dbpedia_1644': ['dbo:Plant',
#   'dbo:Fish',
#   'dbo:Disease',
#   'dbo:Organisation',
#   'dbo:Bird',
#   'dbo:Royalty',
#   'dbo:Software',
#   'dbo:ProgrammingLanguage',
#   'dbo:Bacteria',
#   'dbo:EthnicGroup'],
#  'dbpedia_17541': ['dbo:ArtificialSatellite',
#   'dbo:Person',
#   'dbo:Scientist',
#   'dbo:Book',
#   'dbo:Disease',
#   'dbo:Artery',
#   'dbo:Museum',
#   'dbo:GovernmentAgency',
#   'dbo:ChemicalCompound',
#   'dbo:Game'],
#  'dbpedia_4122': ['dbo:Person',
#   'dbo:Award',
#   'dbo:Film',
#   'dbo:MusicalArtist',
#   'dbo:Book',
#   'dbo:Writer'],
#  'dbpedia_4504': ['dbo:Settlement',
#   'dbo:Person',
#   'dbo:Film',
#   'dbo:Country',
#   'dbo:University',
#   'dbo:Mountain',
#   'dbo:Venue',
#   'dbo:Award',
#   'dbo:Star',
#   'dbo:City'],
#  'dbpedia_9332': ['dbo:InformationAppliance',
#   'dbo:Person',
#   'dbo:MusicalArtist',
#   'dbo:Royalty',
#   'dbo:EthnicGroup',
#   'dbo:Saint',
#   'dbo:Monarch',
#   'dbo:Disease',
#   'dbo:Company',
#   'dbo:Software'],
#  'dbpedia_18385': ['dbo:Band',
#   'dbo:MusicalArtist',
#   'dbo:Mineral',
#   'dbo:Person',
#   'dbo:Game',
#   'dbo:Book',
#   'dbo:Politician',
#   'dbo:RadioStation',
#   'dbo:MusicGenre',
#   'dbo:Company'],
#  'dbpedia_2781': ['dbo:Royalty',
#   'dbo:Person',
#   'dbo:Philosopher',
#   'dbo:MilitaryPerson',
#   'dbo:Book',
#   'dbo:FigureSkater',
#   'dbo:Disease',
#   'dbo:MusicalArtist',
#   'dbo:Ship',
#   'dbo:Mineral'],
#  'dbpedia_3137': ['dbo:River',
#   'dbo:City',
#   'dbo:Town',
#   'dbo:Settlement',
#   'dbo:AdministrativeRegion',
#   'dbo:Building',
#   'dbo:MilitaryConflict'],
#  'dbpedia_21354': ['dbo:Organisation',
#   'dbo:TelevisionStation',
#   'dbo:Band',
#   'dbo:InformationAppliance',
#   'dbo:Company',
#   'dbo:Person',
#   'dbo:University',
#   'dbo:PoliticalParty',
#   'dbo:Game',
#   'dbo:TennisPlayer'],
#  'dbpedia_14391': ['dbo:Person',
#   'dbo:Band',
#   'dbo:Disease',
#   'dbo:Language',
#   'dbo:Writer',
#   'dbo:Book',
#   'dbo:Scientist',
#   'dbo:Organisation',
#   'dbo:TelevisionShow',
#   'dbo:Settlement'],
#  'dbpedia_1526': ['dbo:Film',
#   'dbo:Scientist',
#   'dbo:Sport',
#   'dbo:Election',
#   'dbo:ComicsCharacter',
#   'dbo:Comic',
#   'dbo:Building',
#   'dbo:Play',
#   'dbo:Island',
#   'dbo:AdministrativeRegion'],
#  'dbpedia_5644': ['dbo:Film',
#   'dbo:Person',
#   'dbo:ArtificialSatellite',
#   'dbo:Band',
#   'dbo:Organisation',
#   'dbo:Royalty',
#   'dbo:MusicalArtist',
#   'dbo:Writer',
#   'dbo:Mineral',
#   'dbo:AmericanFootballTeam'],
#  'dbpedia_6121': ['dbo:Person', 'dbo:Monarch', 'dbo:MilitaryConflict'],
#  'dbpedia_13286': ['dbo:Settlement',
#   'dbo:Royalty',
#   'dbo:River',
#   'dbo:AcademicJournal',
#   'dbo:Place',
#   'dbo:City',
#   'dbo:AdministrativeRegion',
#   'dbo:Island',
#   'dbo:MusicalArtist',
#   'dbo:Mineral'],
#  'dbpedia_20931': ['dbo:Constellation',
#   'dbo:Organisation',
#   'dbo:Plant',
#   'dbo:Company',
#   'dbo:InformationAppliance',
#   'dbo:Mineral',
#   'dbo:VideoGame',
#   'dbo:Person',
#   'dbo:Artery',
#   'dbo:Software'],
#  'dbpedia_9063': ['dbo:Person',
#   'dbo:Film',
#   'dbo:Band',
#   'dbo:MusicalArtist',
#   'dbo:MusicGenre',
#   'dbo:Writer',
#   'dbo:FictionalCharacter',
#   'dbo:ChristianBishop',
#   'dbo:Religious',
#   'dbo:Ship'],
#  'dbpedia_4664': ['dbo:Royalty',
#   'dbo:Mineral',
#   'dbo:Person',
#   'dbo:ProgrammingLanguage',
#   'dbo:Philosopher',
#   'dbo:Organisation',
#   'dbo:Software',
#   'dbo:University',
#   'dbo:Disease',
#   'dbo:MusicalArtist'],
#  'dbpedia_19961': ['dbo:City', 'dbo:Settlement', 'dbo:AdministrativeRegion'],
#  'dbpedia_8715': ['dbo:Royalty',
#   'dbo:Monarch',
#   'dbo:Scientist',
#   'dbo:Person',
#   'dbo:Country',
#   'dbo:Company',
#   'dbo:TelevisionShow',
#   'dbo:Band',
#   'dbo:FictionalCharacter',
#   'dbo:Saint'],
#  'dbpedia_23035': ['dbo:Person',
#   'dbo:AmericanFootballTeam',
#   'dbo:Writer',
#   'dbo:FictionalCharacter',
#   'dbo:ComicsCharacter',
#   'dbo:SoccerClub',
#   'dbo:Sport',
#   'dbo:Painter',
#   'dbo:Band',
#   'dbo:Scientist'],
#  ...}

# %%
def save_test_results(test_res, test):
    all_test_queries = {}
    for x in test:
        all_test_queries.update({x['id']:{
                                    'id': x['id'],
                                    'category': x['category'],
                                    'type': x['type']}
                                })
    
    for key, _ in all_test_queries.items():
        try:
            all_test_queries[key]['type'] = test_res[key]['type']
        except:
            continue

    f = open(f"results/advanced_es_system_output.json", "w")
    json.dump(list(all_test_queries.values()), f)
    f.close()

# %%
save_test_results(test_advanced_pointwise, test)

# %%
from evaluate import load_ground_truth, load_system_output, evaluate

type_hierarchy, max_depth = load_type_hierarchy('evaluation/dbpedia/dbpedia_types.tsv')
ground_truth = load_ground_truth('datasets/DBpedia/smarttask_dbpedia_test.json', type_hierarchy)
system_output = load_system_output('results/advanced_es_system_output.json')
evaluate(system_output, ground_truth, type_hierarchy, max_depth)
# Out:
# Loading type hierarchy from evaluation/dbpedia/dbpedia_types.tsv... 761 types loaded (max depth: 7)
# Loading ground truth from datasets/DBpedia/smarttask_dbpedia_test.json...
#    4369 questions loaded
# Loading system predictions from results/advanced_es_system_output.json...
#    4369 predictions loaded
#
#
# Evaluation results:
# -------------------
# Category prediction (based on 4369 questions)
#   Accuracy: 0.925
# Type ranking (based on 4369 questions)
#   NDCG@5:  0.383
#   NDCG@10: 0.383
